# %% [markdown]
# # CSCI 567 — Pre-final: Temporally Robust and Fair Credit Risk Prediction
# **LendingClub 2007–2018**
#
# - Exp 1: Temporal Robustness — temporal vs random split AUC drop
# - Exp 2: Model Design Effects — hyperparameter sweep
# - Exp 3: Fairness Analysis — credit history group + income group
# - Exp 4: Robustness–Fairness Trade-off
# - Exp 5: Neural Network
# - Annual AUC trend (2015, 2016, 2017, 2018)

# %% [markdown]
# ## 0. Setup Environment & Data Load

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/CSCI567/lendingclub/archive.zip" /content/
# !unzip -q /content/archive.zip -d /content/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('/content/accepted_2007_to_2018Q4.csv.gz', low_memory=False)
# df = pd.read_csv(
#     '/content/drive/MyDrive/Colab Notebooks/CSCI567/accepted_2007_to_2018Q4.csv',
#     low_memory=False
# )

print(f'Raw shape: {df.shape}')
# Out:
# Raw shape: (2260701, 151)

# %%
# !pip install optuna -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 12.7 MB/s eta 0:00:00

# %% [markdown]
# ## 1. Preprocessing

# %%
# ── Target Creation ──────────────────────────────────────────────────────────
default_labels = ['Charged Off', 'Default',
                  'Does not meet the credit policy. Status:Charged Off']
df['target'] = df['loan_status'].isin(default_labels).astype(int)

# ── Date Parsing ──────────────────────────────────────────────────────────
df['issue_d']  = pd.to_datetime(df['issue_d'],         format='%b-%Y')
df['issue_year'] = df['issue_d'].dt.year
df['age_proxy'] = pd.to_datetime(df['earliest_cr_line'], format='%b-%Y')
df['credit_history_years'] = (df['issue_d'] - df['age_proxy']).dt.days / 365

# ── Feature Selection ──────────────────────────────────────────────────────────
FEATURES = ['loan_amnt', 'int_rate', 'installment', 'annual_inc',
            'dti', 'delinq_2yrs', 'fico_range_low', 'open_acc',
            'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
            'mort_acc', 'pub_rec_bankruptcies']

# ── Sampling (Colab) ──────────────────────────────────────────────
df_sample = df.sample(n=200000, random_state=42).copy()
# df_sample = df.copy()
print(f'Sample shape: {df_sample.shape}')
print(f'Default rate: {df_sample["target"].mean():.3f}')
# Out:
# Sample shape: (200000, 155)
# Default rate: 0.119

# %%
# Fairness groups will be created after splitting so the cutoffs are learned
# from the temporal training data only.
print('Fairness groups will be built after the split step.')
# Out:
# Fairness groups will be built after the split step.

# %% [markdown]
# ## 2. Data Splitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# ── Temporal split: train / val / test ───────────────────────────────────────
train_t = df_sample[df_sample['issue_year'] <= 2013].copy()
val_t   = df_sample[(df_sample['issue_year'] >= 2014) & (df_sample['issue_year'] <= 2015)].copy()
test_t  = df_sample[df_sample['issue_year'] >= 2016].copy()

# ── Random split: train / val / test ─────────────────────────────────────────
rand_train_df, rand_temp_df = train_test_split(
    df_sample, test_size=0.30, random_state=42, stratify=df_sample['target'])

rand_val_df, rand_test_df = train_test_split(
    rand_temp_df, test_size=0.50, random_state=42, stratify=rand_temp_df['target'])

# ── Imputation: learn medians from training splits only ──────────────────────
temporal_fill = train_t[FEATURES + ['credit_history_years']].median()
random_fill   = rand_train_df[FEATURES + ['credit_history_years']].median()

for split_df in [train_t, val_t, test_t]:
    split_df[FEATURES + ['credit_history_years']] = split_df[FEATURES + ['credit_history_years']].fillna(temporal_fill)

for split_df in [rand_train_df, rand_val_df, rand_test_df]:
    split_df[FEATURES + ['credit_history_years']] = split_df[FEATURES + ['credit_history_years']].fillna(random_fill)

# ── Fairness groups: learn cutoffs from temporal train only ──────────────────
credit_bins = pd.qcut(train_t['credit_history_years'], q=3, retbins=True, duplicates='drop')[1]
income_clip_top = train_t['annual_inc'].quantile(0.99)
income_bins = pd.qcut(train_t['annual_inc'].clip(upper=income_clip_top), q=3, retbins=True, duplicates='drop')[1]

credit_bins[0] = -np.inf
credit_bins[-1] = np.inf
income_bins[0] = -np.inf
income_bins[-1] = np.inf

for split_df in [train_t, val_t, test_t, rand_train_df, rand_val_df, rand_test_df]:
    split_df['credit_group'] = pd.cut(split_df['credit_history_years'], bins=credit_bins, labels=['short', 'mid', 'long'], include_lowest=True)
    split_df['income_group'] = pd.cut(split_df['annual_inc'].clip(upper=income_clip_top), bins=income_bins, labels=['low', 'mid', 'high'], include_lowest=True)

X_train_t = train_t[FEATURES]
y_train_t = train_t['target']
X_val_t   = val_t[FEATURES]
y_val_t   = val_t['target']
X_test_t  = test_t[FEATURES]
y_test_t  = test_t['target']

X_rand_tr  = rand_train_df[FEATURES]
y_rand_tr  = rand_train_df['target']
X_rand_val = rand_val_df[FEATURES]
y_rand_val = rand_val_df['target']
X_rand_te  = rand_test_df[FEATURES]
y_rand_te  = rand_test_df['target']

# ── Scaling: fit each scaler on its own training split only ──────────────────
scaler_t = StandardScaler()
X_train_t_sc = scaler_t.fit_transform(X_train_t)
X_val_t_sc   = scaler_t.transform(X_val_t)
X_test_t_sc  = scaler_t.transform(X_test_t)

scaler_r = StandardScaler()
X_rand_tr_sc  = scaler_r.fit_transform(X_rand_tr)
X_rand_val_sc = scaler_r.transform(X_rand_val)
X_rand_te_sc  = scaler_r.transform(X_rand_te)

print('Temporal split')
print(f'  Train (<=2013):   {len(X_train_t):,}')
print(f'  Val (2014-2015):  {len(X_val_t):,}')
print(f'  Test (>=2016):    {len(X_test_t):,}')

print('\nRandom split')
print(f'  Train: {len(X_rand_tr):,}')
print(f'  Val:   {len(X_rand_val):,}')
print(f'  Test:  {len(X_rand_te):,}')

print('\nTemporal-train fairness group distribution')
print(train_t['credit_group'].value_counts())
print(train_t['income_group'].value_counts())

print('\nYearly default count')
for yr in sorted(df_sample['issue_year'].unique()):
    sub = df_sample[df_sample['issue_year'] == yr]
    print(f'  {yr}: total={len(sub):,}  default={sub["target"].sum():,}  default_rate={sub["target"].mean():.3f}')
# Out:
# Temporal split
#   Train (<=2013):   20,286
#   Val (2014-2015):  58,114
#   Test (>=2016):    121,596
#
# Random split
#   Train: 140,000
#   Val:   30,000
#   Test:  30,000
#
# Temporal-train fairness group distribution
# credit_group
# mid      6775
# short    6764
# long     6747
# Name: count, dtype: int64
# income_group
# low     7220
# high    6728
# mid     6338
# Name: count, dtype: int64
#
# Yearly default count
#   2007.0: total=46  default=10  default_rate=0.217
#   2008.0: total=206  default=37  default_rate=0.180
#   2009.0: total=488  default=66  default_rate=0.135
#   2010.0: total=1,121  default=176  default_rate=0.157
#   2011.0: total=1,946  default=284  default_rate=0.146
#   2012.0: total=4,597  default=725  default_rate=0.158
#   2013.0: total=11,882  default=1,838  default_rate=0.155
#   2014.0: total=20,956  default=3,676  default_rate=0.175
#   2015.0: total=37,158  default=6,797  default_rate=0.183
#   2016.0: total=38,347  default=5,976  default_rate=0.156
#   2017.0: total=39,269  default=3,521  default_rate=0.090
#   2018.0: total=43,980  default=746  default_rate=0.017
#   nan: total=0  default=0  default_rate=nan

# %%
# ── By year temporal test sets (AUC over time) ──────────────────────────────
yearly_tests = {}
for yr in [2016, 2017, 2018]:
    sub = df_sample[df_sample['issue_year'] == yr].copy()
    if len(sub) > 0:
        sub[FEATURES + ['credit_history_years']] = sub[FEATURES + ['credit_history_years']].fillna(temporal_fill)
        sub['credit_group'] = pd.cut(sub['credit_history_years'], bins=credit_bins, labels=['short', 'mid', 'long'], include_lowest=True)
        sub['income_group'] = pd.cut(sub['annual_inc'].clip(upper=income_clip_top), bins=income_bins, labels=['low', 'mid', 'high'], include_lowest=True)
        yearly_tests[yr] = (sub[FEATURES], sub['target'], scaler_t.transform(sub[FEATURES]), sub)
        print(f'{yr}: {len(sub):,} samples, default rate={sub["target"].mean():.3f}')
# Out:
# 2016: 38,347 samples, default rate=0.156
# 2017: 39,269 samples, default rate=0.090
# 2018: 43,980 samples, default rate=0.017

# %% [markdown]
# ## 3. Model Definition — Full Model + Hyperparameter Sweep

# %%
# Reusable evaluation helpers for any model family
from sklearn.base import clone
from sklearn.metrics import roc_auc_score, accuracy_score, brier_score_loss
from sklearn.metrics import recall_score, f1_score, precision_score
import time

def evaluate_model_configs(model_configs):
    eval_results = {}
    for name, (model, input_type) in model_configs.items():
        t0 = time.time()
        temporal_model = clone(model)
        random_model   = clone(model)

        if input_type == 'scaled':
            Xtr_t, Xva_t, Xte_t = X_train_t_sc, X_val_t_sc, X_test_t_sc
            Xtr_r, Xva_r, Xte_r = X_rand_tr_sc, X_rand_val_sc, X_rand_te_sc
        else:
            Xtr_t, Xva_t, Xte_t = X_train_t, X_val_t, X_test_t
            Xtr_r, Xva_r, Xte_r = X_rand_tr, X_rand_val, X_rand_te

        temporal_model.fit(Xtr_t, y_train_t)
        random_model.fit(Xtr_r, y_rand_tr)

        y_prob_t_val = temporal_model.predict_proba(Xva_t)[:, 1]
        y_prob_t = temporal_model.predict_proba(Xte_t)[:, 1]
        # y_pred_t_val = temporal_model.predict(Xva_t)
        # y_pred_t = temporal_model.predict(Xte_t)

        y_prob_r_val = random_model.predict_proba(Xva_r)[:, 1]
        y_prob_r = random_model.predict_proba(Xte_r)[:, 1]
        # y_pred_r_val = random_model.predict(Xva_r)
        # y_pred_r = random_model.predict(Xte_r)

        # val set optimal threshold
        thresholds = np.arange(0.05, 0.50, 0.01)
        best_thr_t = max(thresholds, key=lambda t: f1_score(y_val_t, (y_prob_t_val >= t).astype(int), zero_division=0))
        best_thr_r = max(thresholds, key=lambda t: f1_score(y_rand_val, (y_prob_r_val >= t).astype(int), zero_division=0))

        # apply threshold
        y_pred_t_val = (y_prob_t_val >= best_thr_t).astype(int)
        y_pred_t = (y_prob_t >= best_thr_t).astype(int)
        y_pred_r_val = (y_prob_r_val >= best_thr_r).astype(int)
        y_pred_r = (y_prob_r >= best_thr_r).astype(int)

        eval_results[name] = {
            'temporal': {
                'val_y_prob': y_prob_t_val,
                'val_y_pred': y_pred_t_val,
                'val_auc': roc_auc_score(y_val_t, y_prob_t_val),
                'val_acc': accuracy_score(y_val_t, y_pred_t_val),
                'val_brier': brier_score_loss(y_val_t, y_prob_t_val),
                'val_recall': recall_score(y_val_t, y_pred_t_val, zero_division=0),
                'val_precision': precision_score(y_val_t, y_pred_t_val, zero_division=0),
                'val_f1': f1_score(y_val_t, y_pred_t_val, zero_division=0),
                'y_pred': y_pred_t,
                'y_prob': y_prob_t,
                'auc': roc_auc_score(y_test_t, y_prob_t),
                'acc': accuracy_score(y_test_t, y_pred_t),
                'brier': brier_score_loss(y_test_t, y_prob_t),
                'recall': recall_score(y_test_t, y_pred_t, zero_division=0),
                'precision': precision_score(y_test_t, y_pred_t, zero_division=0),
                'f1': f1_score(y_test_t, y_pred_t, zero_division=0),
                'threshold': best_thr_t,
                'model': temporal_model,
            },
            'random': {
                'val_y_prob': y_prob_r_val,
                'val_y_pred': y_pred_r_val,
                'val_auc': roc_auc_score(y_rand_val, y_prob_r_val),
                'val_acc': accuracy_score(y_rand_val, y_pred_r_val),
                'val_brier': brier_score_loss(y_rand_val, y_prob_r_val),
                'val_recall': recall_score(y_rand_val, y_pred_r_val, zero_division=0),
                'val_precision': precision_score(y_rand_val, y_pred_r_val, zero_division=0),
                'val_f1': f1_score(y_rand_val, y_pred_r_val, zero_division=0),
                'y_prob': y_prob_r,
                'y_pred': y_pred_r,
                'auc': roc_auc_score(y_rand_te, y_prob_r),
                'acc': accuracy_score(y_rand_te, y_pred_r),
                'brier': brier_score_loss(y_rand_te, y_prob_r),
                'recall': recall_score(y_rand_te, y_pred_r, zero_division=0),
                'precision': precision_score(y_rand_te, y_pred_r, zero_division=0),
                'f1': f1_score(y_rand_te, y_pred_r, zero_division=0),
                'threshold': best_thr_r,
                'model': random_model,
            },
            'yearly': {}
        }

        for yr, (X_yr, y_yr, X_yr_sc, _) in yearly_tests.items():
            X_in = X_yr_sc if input_type == 'scaled' else X_yr
            yp = temporal_model.predict_proba(X_in)[:, 1]
            eval_results[name]['yearly'][yr] = roc_auc_score(y_yr, yp)

        eval_results[name]['auc_drop'] = eval_results[name]['random']['auc'] - eval_results[name]['temporal']['auc']
        eval_results[name]['val_auc_drop'] = eval_results[name]['random']['val_auc'] - eval_results[name]['temporal']['val_auc']
    return eval_results

# %%
def print_selection_table(eval_results, sort_key='val_auc', reverse=True, title=None, mode='val'):
    if title:
        print(f'\n=== {title} ===')

    if mode == 'val':
        key_fn = {
            'val_auc': lambda x: x[1]['temporal']['val_auc'],
            'val_auc_drop': lambda x: x[1]['val_auc_drop'],
            'val_recall': lambda x: x[1]['temporal']['val_recall'],
            'val_precision': lambda x: x[1]['temporal']['val_precision'],
            'val_f1': lambda x: x[1]['temporal']['val_f1'],
        }.get(sort_key, lambda x: x[1]['temporal']['val_auc'])

        for name, res in sorted(eval_results.items(), key=key_fn, reverse=reverse):
            print(f"{name:20s}  "
                  f"temp_val_AUC={res['temporal']['val_auc']:.4f}  "
                  f"rand_val_AUC={res['random']['val_auc']:.4f}  "
                  f"val_AUC_drop={res['val_auc_drop']:.4f}  "
                  f"val_Recall={res['temporal']['val_recall']:.4f}  "
                  f"val_Precision={res['temporal']['val_precision']:.4f}  "
                  f"val_F1={res['temporal']['val_f1']:.4f}  "
                  f"threshold={res['temporal']['threshold']:.2f}")

    elif mode == 'test':
        key_fn = {
            'test_auc': lambda x: x[1]['temporal']['auc'],
            'test_auc_drop': lambda x: x[1]['auc_drop'],
            'recall': lambda x: x[1]['temporal']['recall'],
            'precision': lambda x: x[1]['temporal']['precision'],
            'f1': lambda x: x[1]['temporal']['f1'],
        }.get(sort_key, lambda x: x[1]['temporal']['auc'])

        for name, res in sorted(eval_results.items(), key=key_fn, reverse=reverse):
            print(f"{name:20s}  "
                  f"temp_test_AUC={res['temporal']['auc']:.4f}  "
                  f"random_test_AUC={res['random']['auc']:.4f}  "
                  f"test_AUC_drop={res['auc_drop']:.4f}  "
                  f"Recall={res['temporal']['recall']:.4f}  "
                  f"Precision={res['temporal']['precision']:.4f}  "
                  f"F1={res['temporal']['f1']:.4f}  "
                  f"threshold={res['temporal']['threshold']:.2f}")

# %%
def print_best_summary(eval_results, prefix=None, title=None):
    # prefix filtering (ex: 'XGB_', 'LR_', 'RF_')
    filtered = {k: v for k, v in eval_results.items()
                if (k.startswith(prefix) if prefix else True)}

    best_val      = max(filtered.items(), key=lambda x: x[1]['temporal']['val_auc'])
    best_robust   = min(filtered.items(), key=lambda x: x[1]['auc_drop'])
    best_balanced = max(filtered.items(), key=lambda x: x[1]['temporal']['val_auc'] - x[1]['auc_drop'])

    if title:
        print(f'=== {title} ===')

    print(f"Best by temporal val AUC: {best_val[0]}")
    print(f"  val_AUC={best_val[1]['temporal']['val_auc']:.4f}  test_AUC={best_val[1]['temporal']['auc']:.4f}  AUC_drop={best_val[1]['auc_drop']:.4f}")
    print()
    print(f"Best by robustness (smallest AUC drop): {best_robust[0]}")
    print(f"  val_AUC={best_robust[1]['temporal']['val_auc']:.4f}  test_AUC={best_robust[1]['temporal']['auc']:.4f}  AUC_drop={best_robust[1]['auc_drop']:.4f}")
    print()
    print(f"Best balanced (val_AUC - AUC_drop): {best_balanced[0]}")
    print(f"  val_AUC={best_balanced[1]['temporal']['val_auc']:.4f}  test_AUC={best_balanced[1]['temporal']['auc']:.4f}  AUC_drop={best_balanced[1]['auc_drop']:.4f}")

# %%
def print_optuna_results(study, top_trials, title='Optuna Results'):
    print(f'\n=== {title} ===')
    print(f'Best score: {study.best_value:.4f}')
    print(f'\nBest params:')
    for k, v in study.best_params.items():
        print(f'  {k:20s}: {v}')

    print(f'\n=== Top {len(top_trials)} Trials ===')
    for i, t in enumerate(top_trials):
        print(f'\n[{i+1}] score={t.value:.4f}')
        for k, v in t.params.items():
            print(f'  {k:20s}: {v}')

# %%
import optuna
from optuna.samplers import TPESampler

w_robustness = 0.35
w_performance = 0.15
w_recall = 0.50
w_f1 = 0.50

# %% [markdown]
# ## 3.1 XGBoost Test Code (Find Best)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

# ── All Model Definitions ─────────────────────────────────────────────────────
# LR: C Value sweep (regularization strength)
# Tree: max_depth sweep
# RF: n_estimators x max_depth
# XGB: learning_rate x max_depth
# NN: hidden layer size x alpha (L2)

XGB_MODEL_CONFIGS = {
    # Baseline
    'XGB_base':         (XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=4, eval_metric='logloss', random_state=42), 'raw'),

    # learning_rate sweep
    'XGB_lr0.005':       (XGBClassifier(n_estimators=100, learning_rate=0.005, max_depth=4, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=4, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=4, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_lr0.3':        (XGBClassifier(n_estimators=100, learning_rate=0.3,  max_depth=4, eval_metric='logloss', random_state=42), 'raw'),

    # max_depth sweep
    'XGB_d3_lr0.01':           (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d6_lr0.01':           (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d8_lr0.01':           (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d3_lr0.03':           (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d6_lr0.03':           (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d8_lr0.03':           (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d3_lr0.05':           (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d6_lr0.05':           (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_d8_lr0.05':           (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=8, eval_metric='logloss', random_state=42), 'raw'),

    # min_child_weight sweep
    'XGB_mcw3_lr0.01':         (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3,  eval_metric='logloss', random_state=42), 'raw'),
    'XGB_mcw5_lr0.01':         (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=5,  eval_metric='logloss', random_state=42), 'raw'),
    'XGB_mcw10_lr0.01':        (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=10, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_mcw3_lr0.03':         (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3,  eval_metric='logloss', random_state=42), 'raw'),
    'XGB_mcw5_lr0.03':         (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=5,  eval_metric='logloss', random_state=42), 'raw'),
    'XGB_mcw10_lr0.03':        (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=10, eval_metric='logloss', random_state=42), 'raw'),

    # subsample sweep
    'XGB_sub0.6_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, subsample=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.7_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.8_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, subsample=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.6_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, subsample=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.7_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.8_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, subsample=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.6_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, subsample=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.7_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_sub0.8_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, subsample=0.8, eval_metric='logloss', random_state=42), 'raw'),

    # colsample_bytree sweep
    'XGB_col0.6_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.6_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.6_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, subsample=0.7, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),

    # colsample_bytree sweep
    'XGB_col0.6_lr0.01_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.01_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.01_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.6_lr0.03_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.03_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.03_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.6_lr0.05_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.05_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.05_rmsub':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),

    # colsample_bytree sweep
    'XGB_col0.6_lr0.01_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, subsample=0.7, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.01_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, subsample=0.7, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.01_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, subsample=0.7, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.6_lr0.03_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, subsample=0.7, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.03_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, subsample=0.7, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.03_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, subsample=0.7, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.6_lr0.05_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, subsample=0.7, colsample_bytree=0.6, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.7_lr0.05_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, subsample=0.7, colsample_bytree=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_col0.8_lr0.05_rmmcw':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, subsample=0.7, colsample_bytree=0.8, eval_metric='logloss', random_state=42), 'raw'),

    # subsample sweep
    'XGB_gamma1_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma3_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma5_lr0.01':       (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma1_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma3_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma5_lr0.03':       (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma1_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma3_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_gamma5_lr0.05':       (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    # L1 (reg_alpha) + gamma + lr 조합
    'XGB_L1_1_g1_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g1_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g1_lr0.01': (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_1_g3_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g3_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g3_lr0.01': (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_1_g5_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g5_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g5_lr0.01': (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    'XGB_L1_1_g1_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g1_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g1_lr0.03': (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_1_g3_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g3_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g3_lr0.03': (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_1_g5_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g5_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g5_lr0.03': (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    'XGB_L1_1_g1_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g1_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g1_lr0.05': (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_1_g3_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g3_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g3_lr0.05': (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_1_g5_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_5_g5_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L1_10_g5_lr0.05': (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_alpha=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    # L2 (reg_lambda) + gamma + lr (27)
    # 'XGB_L2_1_g1_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g1_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g1_lr0.01': (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_1_g3_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g3_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g3_lr0.01': (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_1_g5_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g5_lr0.01':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g5_lr0.01': (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    # 'XGB_L2_1_g1_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g1_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g1_lr0.03': (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_1_g3_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g3_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g3_lr0.03': (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_1_g5_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g5_lr0.03':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g5_lr0.03': (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    # 'XGB_L2_1_g1_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g1_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g1_lr0.05': (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_1_g3_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g3_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g3_lr0.05': (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_1_g5_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_5_g5_lr0.05':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=5.0,  subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    # 'XGB_L2_10_g5_lr0.05': (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=10.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),

    'XGB_L2(1)_g1_lr0.01_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.01_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.01_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.03_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.03_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.03_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.05_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.05_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g1_lr0.05_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=1, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.01_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.01_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.01_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.03_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.03_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.03_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.05_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.05_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g3_lr0.05_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=3, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.01_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.01_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.01_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.03_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.03_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.03_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.03, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.05_n50':   (XGBClassifier(n_estimators=50,  learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.05_n75':   (XGBClassifier(n_estimators=75,  learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
    'XGB_L2(1)_g5_lr0.05_n100':  (XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, min_child_weight=3, gamma=5, reg_lambda=1.0, subsample=0.7, eval_metric='logloss', random_state=42), 'raw'),
}

print(f'Total model configs: {len(XGB_MODEL_CONFIGS)}')
# Out:
# Total model configs: 119

# %%
# xgb_results = evaluate_model_configs(XGB_MODEL_CONFIGS)

# # (val set)
# print_selection_table(xgb_results, sort_key='val_auc', reverse=True, title='XGB - Val Set', mode='val')
# print_selection_table(xgb_results, sort_key='val_auc_drop', reverse=False, title='XGB - Val Robustness', mode='val')

# # (test set)
# print_selection_table(xgb_results, sort_key='test_auc', reverse=True, title='XGB - Test Set (Final)', mode='test')
# print_selection_table(xgb_results, sort_key='test_auc_drop', reverse=False, title='XGB - Test Robustness (Final)', mode='test')

# # (best summary)
# print_best_summary(xgb_results, prefix='XGB_', title='XGBoost Selection Summary')
# Out:
# === XGB - Val Set ===
# XGB_col0.7_lr0.03     temp_val_AUC=0.6837  rand_val_AUC=0.7006  val_AUC_drop=0.0169
# XGB_col0.6_lr0.03     temp_val_AUC=0.6837  rand_val_AUC=0.7008  val_AUC_drop=0.0171
# XGB_col0.6_lr0.03_rmmcw  temp_val_AUC=0.6837  rand_val_AUC=0.7008  val_AUC_drop=0.0171
# XGB_col0.7_lr0.05_rmmcw  temp_val_AUC=0.6836  rand_val_AUC=0.7058  val_AUC_drop=0.0222
# XGB_col0.7_lr0.05     temp_val_AUC=0.6836  rand_val_AUC=0.7058  val_AUC_drop=0.0222
# XGB_col0.7_lr0.03_rmmcw  temp_val_AUC=0.6836  rand_val_AUC=0.7006  val_AUC_drop=0.0170
# XGB_col0.6_lr0.05     temp_val_AUC=0.6835  rand_val_AUC=0.7057  val_AUC_drop=0.0222
# XGB_col0.6_lr0.05_rmmcw  temp_val_AUC=0.6833  rand_val_AUC=0.7057  val_AUC_drop=0.0224
# XGB_col0.7_lr0.01     temp_val_AUC=0.6832  rand_val_AUC=0.6959  val_AUC_drop=0.0127
# XGB_col0.7_lr0.01_rmmcw  temp_val_AUC=0.6832  rand_val_AUC=0.6959  val_AUC_drop=0.0127
# XGB_col0.8_lr0.03_rmmcw  temp_val_AUC=0.6829  rand_val_AUC=0.7011  val_AUC_drop=0.0182
# XGB_L1_1_g1_lr0.05    temp_val_AUC=0.6829  rand_val_AUC=0.7046  val_AUC_drop=0.0217
# XGB_col0.6_lr0.03_rmsub  temp_val_AUC=0.6829  rand_val_AUC=0.7001  val_AUC_drop=0.0172
# XGB_col0.8_lr0.03     temp_val_AUC=0.6829  rand_val_AUC=0.7011  val_AUC_drop=0.0182
# XGB_col0.6_lr0.05_rmsub  temp_val_AUC=0.6828  rand_val_AUC=0.7054  val_AUC_drop=0.0225
# XGB_sub0.6_lr0.03     temp_val_AUC=0.6828  rand_val_AUC=0.7008  val_AUC_drop=0.0180
# XGB_L1_1_g5_lr0.05    temp_val_AUC=0.6828  rand_val_AUC=0.7045  val_AUC_drop=0.0217
# XGB_col0.7_lr0.05_rmsub  temp_val_AUC=0.6828  rand_val_AUC=0.7046  val_AUC_drop=0.0219
# XGB_col0.6_lr0.01_rmmcw  temp_val_AUC=0.6828  rand_val_AUC=0.6958  val_AUC_drop=0.0130
# XGB_gamma1_lr0.05     temp_val_AUC=0.6827  rand_val_AUC=0.7046  val_AUC_drop=0.0218
# XGB_L2(1)_g1_lr0.05_n100  temp_val_AUC=0.6827  rand_val_AUC=0.7046  val_AUC_drop=0.0218
# XGB_sub0.7_lr0.05     temp_val_AUC=0.6827  rand_val_AUC=0.7046  val_AUC_drop=0.0218
# XGB_col0.6_lr0.01     temp_val_AUC=0.6827  rand_val_AUC=0.6958  val_AUC_drop=0.0131
# XGB_gamma5_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0175
# XGB_L2(1)_g5_lr0.03_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0175
# XGB_gamma3_lr0.05     temp_val_AUC=0.6826  rand_val_AUC=0.7044  val_AUC_drop=0.0218
# XGB_L2(1)_g3_lr0.05_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7044  val_AUC_drop=0.0218
# XGB_sub0.7_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_gamma1_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L2(1)_g1_lr0.03_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_sub0.6_lr0.05     temp_val_AUC=0.6826  rand_val_AUC=0.7039  val_AUC_drop=0.0213
# XGB_L1_1_g3_lr0.05    temp_val_AUC=0.6826  rand_val_AUC=0.7046  val_AUC_drop=0.0220
# XGB_gamma3_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L2(1)_g3_lr0.03_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L1_1_g5_lr0.03    temp_val_AUC=0.6825  rand_val_AUC=0.6996  val_AUC_drop=0.0171
# XGB_col0.8_lr0.05_rmmcw  temp_val_AUC=0.6825  rand_val_AUC=0.7053  val_AUC_drop=0.0228
# XGB_col0.8_lr0.05     temp_val_AUC=0.6825  rand_val_AUC=0.7053  val_AUC_drop=0.0228
# XGB_gamma5_lr0.05     temp_val_AUC=0.6824  rand_val_AUC=0.7045  val_AUC_drop=0.0221
# XGB_L2(1)_g5_lr0.05_n100  temp_val_AUC=0.6824  rand_val_AUC=0.7045  val_AUC_drop=0.0221
# XGB_col0.7_lr0.03_rmsub  temp_val_AUC=0.6824  rand_val_AUC=0.7009  val_AUC_drop=0.0185
# XGB_L1_5_g5_lr0.05    temp_val_AUC=0.6824  rand_val_AUC=0.7048  val_AUC_drop=0.0224
# XGB_L1_5_g1_lr0.05    temp_val_AUC=0.6824  rand_val_AUC=0.7049  val_AUC_drop=0.0225
# XGB_L1_5_g3_lr0.05    temp_val_AUC=0.6824  rand_val_AUC=0.7047  val_AUC_drop=0.0223
# XGB_L1_1_g1_lr0.03    temp_val_AUC=0.6824  rand_val_AUC=0.6996  val_AUC_drop=0.0172
# XGB_L1_1_g3_lr0.03    temp_val_AUC=0.6824  rand_val_AUC=0.6996  val_AUC_drop=0.0173
# XGB_L2(1)_g3_lr0.05_n75  temp_val_AUC=0.6823  rand_val_AUC=0.7024  val_AUC_drop=0.0201
# XGB_col0.8_lr0.01_rmmcw  temp_val_AUC=0.6823  rand_val_AUC=0.6963  val_AUC_drop=0.0140
# XGB_col0.8_lr0.01     temp_val_AUC=0.6823  rand_val_AUC=0.6963  val_AUC_drop=0.0140
# XGB_L2(1)_g5_lr0.05_n75  temp_val_AUC=0.6823  rand_val_AUC=0.7023  val_AUC_drop=0.0200
# XGB_col0.8_lr0.03_rmsub  temp_val_AUC=0.6822  rand_val_AUC=0.7002  val_AUC_drop=0.0179
# XGB_col0.8_lr0.05_rmsub  temp_val_AUC=0.6822  rand_val_AUC=0.7044  val_AUC_drop=0.0222
# XGB_L2(1)_g1_lr0.05_n75  temp_val_AUC=0.6822  rand_val_AUC=0.7024  val_AUC_drop=0.0202
# XGB_L1_5_g3_lr0.03    temp_val_AUC=0.6822  rand_val_AUC=0.6993  val_AUC_drop=0.0172
# XGB_L1_5_g5_lr0.03    temp_val_AUC=0.6821  rand_val_AUC=0.6993  val_AUC_drop=0.0172
# XGB_L1_10_g3_lr0.05   temp_val_AUC=0.6821  rand_val_AUC=0.7042  val_AUC_drop=0.0221
# XGB_L2(1)_g5_lr0.05_n50  temp_val_AUC=0.6821  rand_val_AUC=0.6990  val_AUC_drop=0.0169
# XGB_sub0.8_lr0.03     temp_val_AUC=0.6821  rand_val_AUC=0.7005  val_AUC_drop=0.0184
# XGB_L2(1)_g1_lr0.03_n75  temp_val_AUC=0.6820  rand_val_AUC=0.6981  val_AUC_drop=0.0161
# XGB_L1_10_g1_lr0.05   temp_val_AUC=0.6820  rand_val_AUC=0.7043  val_AUC_drop=0.0222
# XGB_L1_5_g1_lr0.03    temp_val_AUC=0.6820  rand_val_AUC=0.6994  val_AUC_drop=0.0173
# XGB_L2(1)_g3_lr0.03_n75  temp_val_AUC=0.6820  rand_val_AUC=0.6981  val_AUC_drop=0.0161
# XGB_L2(1)_g3_lr0.05_n50  temp_val_AUC=0.6819  rand_val_AUC=0.6990  val_AUC_drop=0.0170
# XGB_sub0.8_lr0.05     temp_val_AUC=0.6819  rand_val_AUC=0.7046  val_AUC_drop=0.0226
# XGB_L2(1)_g1_lr0.05_n50  temp_val_AUC=0.6819  rand_val_AUC=0.6990  val_AUC_drop=0.0171
# XGB_L2(1)_g5_lr0.03_n75  temp_val_AUC=0.6819  rand_val_AUC=0.6981  val_AUC_drop=0.0162
# XGB_L1_10_g5_lr0.05   temp_val_AUC=0.6818  rand_val_AUC=0.7041  val_AUC_drop=0.0222
# XGB_col0.7_lr0.01_rmsub  temp_val_AUC=0.6817  rand_val_AUC=0.6947  val_AUC_drop=0.0129
# XGB_L2(1)_g5_lr0.03_n50  temp_val_AUC=0.6817  rand_val_AUC=0.6968  val_AUC_drop=0.0151
# XGB_L2(1)_g3_lr0.03_n50  temp_val_AUC=0.6817  rand_val_AUC=0.6968  val_AUC_drop=0.0151
# XGB_L2(1)_g1_lr0.03_n50  temp_val_AUC=0.6817  rand_val_AUC=0.6968  val_AUC_drop=0.0152
# XGB_col0.6_lr0.01_rmsub  temp_val_AUC=0.6817  rand_val_AUC=0.6945  val_AUC_drop=0.0128
# XGB_mcw3_lr0.03       temp_val_AUC=0.6815  rand_val_AUC=0.6995  val_AUC_drop=0.0181
# XGB_L1_10_g5_lr0.03   temp_val_AUC=0.6815  rand_val_AUC=0.6990  val_AUC_drop=0.0175
# XGB_d3_lr0.03         temp_val_AUC=0.6814  rand_val_AUC=0.6995  val_AUC_drop=0.0181
# XGB_L1_10_g3_lr0.03   temp_val_AUC=0.6814  rand_val_AUC=0.6990  val_AUC_drop=0.0176
# XGB_L1_10_g1_lr0.03   temp_val_AUC=0.6814  rand_val_AUC=0.6990  val_AUC_drop=0.0177
# XGB_mcw10_lr0.03      temp_val_AUC=0.6813  rand_val_AUC=0.6994  val_AUC_drop=0.0180
# XGB_mcw5_lr0.03       temp_val_AUC=0.6813  rand_val_AUC=0.6995  val_AUC_drop=0.0183
# XGB_d3_lr0.05         temp_val_AUC=0.6812  rand_val_AUC=0.7037  val_AUC_drop=0.0225
# XGB_sub0.6_lr0.01     temp_val_AUC=0.6810  rand_val_AUC=0.6964  val_AUC_drop=0.0154
# XGB_col0.8_lr0.01_rmsub  temp_val_AUC=0.6807  rand_val_AUC=0.6947  val_AUC_drop=0.0140
# XGB_L1_1_g5_lr0.01    temp_val_AUC=0.6806  rand_val_AUC=0.6960  val_AUC_drop=0.0154
# XGB_gamma5_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L2(1)_g5_lr0.01_n100  temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_sub0.7_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_gamma1_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_gamma3_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L2(1)_g1_lr0.01_n100  temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L2(1)_g3_lr0.01_n100  temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L1_1_g3_lr0.01    temp_val_AUC=0.6806  rand_val_AUC=0.6960  val_AUC_drop=0.0154
# XGB_L1_1_g1_lr0.01    temp_val_AUC=0.6805  rand_val_AUC=0.6960  val_AUC_drop=0.0155
# XGB_L1_5_g5_lr0.01    temp_val_AUC=0.6803  rand_val_AUC=0.6959  val_AUC_drop=0.0156
# XGB_sub0.8_lr0.01     temp_val_AUC=0.6802  rand_val_AUC=0.6959  val_AUC_drop=0.0157
# XGB_L1_5_g1_lr0.01    temp_val_AUC=0.6802  rand_val_AUC=0.6959  val_AUC_drop=0.0157
# XGB_L1_5_g3_lr0.01    temp_val_AUC=0.6802  rand_val_AUC=0.6959  val_AUC_drop=0.0157
# XGB_L2(1)_g5_lr0.01_n75  temp_val_AUC=0.6800  rand_val_AUC=0.6962  val_AUC_drop=0.0162
# XGB_L2(1)_g1_lr0.01_n75  temp_val_AUC=0.6800  rand_val_AUC=0.6962  val_AUC_drop=0.0162
# XGB_L2(1)_g3_lr0.01_n75  temp_val_AUC=0.6800  rand_val_AUC=0.6962  val_AUC_drop=0.0162
# XGB_L1_10_g5_lr0.01   temp_val_AUC=0.6796  rand_val_AUC=0.6956  val_AUC_drop=0.0160
# XGB_lr0.05            temp_val_AUC=0.6796  rand_val_AUC=0.7098  val_AUC_drop=0.0302
# XGB_L1_10_g3_lr0.01   temp_val_AUC=0.6795  rand_val_AUC=0.6957  val_AUC_drop=0.0162
# XGB_L2(1)_g1_lr0.01_n50  temp_val_AUC=0.6795  rand_val_AUC=0.6958  val_AUC_drop=0.0163
# XGB_L2(1)_g3_lr0.01_n50  temp_val_AUC=0.6795  rand_val_AUC=0.6958  val_AUC_drop=0.0163
# XGB_L2(1)_g5_lr0.01_n50  temp_val_AUC=0.6795  rand_val_AUC=0.6958  val_AUC_drop=0.0163
# XGB_L1_10_g1_lr0.01   temp_val_AUC=0.6794  rand_val_AUC=0.6957  val_AUC_drop=0.0164
# XGB_d3_lr0.01         temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0165
# XGB_mcw10_lr0.01      temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0166
# XGB_mcw3_lr0.01       temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0166
# XGB_mcw5_lr0.01       temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0166
# XGB_lr0.01            temp_val_AUC=0.6781  rand_val_AUC=0.6987  val_AUC_drop=0.0207
# XGB_base              temp_val_AUC=0.6767  rand_val_AUC=0.7126  val_AUC_drop=0.0359
# XGB_lr0.005           temp_val_AUC=0.6761  rand_val_AUC=0.6967  val_AUC_drop=0.0207
# XGB_d6_lr0.03         temp_val_AUC=0.6751  rand_val_AUC=0.7174  val_AUC_drop=0.0423
# XGB_d6_lr0.01         temp_val_AUC=0.6737  rand_val_AUC=0.7096  val_AUC_drop=0.0358
# XGB_d6_lr0.05         temp_val_AUC=0.6727  rand_val_AUC=0.7199  val_AUC_drop=0.0471
# XGB_d8_lr0.03         temp_val_AUC=0.6688  rand_val_AUC=0.7236  val_AUC_drop=0.0547
# XGB_d8_lr0.01         temp_val_AUC=0.6676  rand_val_AUC=0.7147  val_AUC_drop=0.0472
# XGB_d8_lr0.05         temp_val_AUC=0.6671  rand_val_AUC=0.7238  val_AUC_drop=0.0568
# XGB_lr0.3             temp_val_AUC=0.6593  rand_val_AUC=0.7265  val_AUC_drop=0.0672
#
# === XGB - Val Robustness ===
# XGB_col0.7_lr0.01     temp_val_AUC=0.6832  rand_val_AUC=0.6959  val_AUC_drop=0.0127
# XGB_col0.7_lr0.01_rmmcw  temp_val_AUC=0.6832  rand_val_AUC=0.6959  val_AUC_drop=0.0127
# XGB_col0.6_lr0.01_rmsub  temp_val_AUC=0.6817  rand_val_AUC=0.6945  val_AUC_drop=0.0128
# XGB_col0.7_lr0.01_rmsub  temp_val_AUC=0.6817  rand_val_AUC=0.6947  val_AUC_drop=0.0129
# XGB_col0.6_lr0.01_rmmcw  temp_val_AUC=0.6828  rand_val_AUC=0.6958  val_AUC_drop=0.0130
# XGB_col0.6_lr0.01     temp_val_AUC=0.6827  rand_val_AUC=0.6958  val_AUC_drop=0.0131
# XGB_col0.8_lr0.01_rmmcw  temp_val_AUC=0.6823  rand_val_AUC=0.6963  val_AUC_drop=0.0140
# XGB_col0.8_lr0.01     temp_val_AUC=0.6823  rand_val_AUC=0.6963  val_AUC_drop=0.0140
# XGB_col0.8_lr0.01_rmsub  temp_val_AUC=0.6807  rand_val_AUC=0.6947  val_AUC_drop=0.0140
# XGB_L2(1)_g5_lr0.03_n50  temp_val_AUC=0.6817  rand_val_AUC=0.6968  val_AUC_drop=0.0151
# XGB_L2(1)_g3_lr0.03_n50  temp_val_AUC=0.6817  rand_val_AUC=0.6968  val_AUC_drop=0.0151
# XGB_L2(1)_g1_lr0.03_n50  temp_val_AUC=0.6817  rand_val_AUC=0.6968  val_AUC_drop=0.0152
# XGB_L1_1_g5_lr0.01    temp_val_AUC=0.6806  rand_val_AUC=0.6960  val_AUC_drop=0.0154
# XGB_L1_1_g3_lr0.01    temp_val_AUC=0.6806  rand_val_AUC=0.6960  val_AUC_drop=0.0154
# XGB_sub0.6_lr0.01     temp_val_AUC=0.6810  rand_val_AUC=0.6964  val_AUC_drop=0.0154
# XGB_L1_1_g1_lr0.01    temp_val_AUC=0.6805  rand_val_AUC=0.6960  val_AUC_drop=0.0155
# XGB_L1_5_g5_lr0.01    temp_val_AUC=0.6803  rand_val_AUC=0.6959  val_AUC_drop=0.0156
# XGB_gamma5_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L2(1)_g5_lr0.01_n100  temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_sub0.7_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_gamma1_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_gamma3_lr0.01     temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L2(1)_g1_lr0.01_n100  temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_L2(1)_g3_lr0.01_n100  temp_val_AUC=0.6806  rand_val_AUC=0.6962  val_AUC_drop=0.0156
# XGB_sub0.8_lr0.01     temp_val_AUC=0.6802  rand_val_AUC=0.6959  val_AUC_drop=0.0157
# XGB_L1_5_g1_lr0.01    temp_val_AUC=0.6802  rand_val_AUC=0.6959  val_AUC_drop=0.0157
# XGB_L1_5_g3_lr0.01    temp_val_AUC=0.6802  rand_val_AUC=0.6959  val_AUC_drop=0.0157
# XGB_L1_10_g5_lr0.01   temp_val_AUC=0.6796  rand_val_AUC=0.6956  val_AUC_drop=0.0160
# XGB_L2(1)_g1_lr0.03_n75  temp_val_AUC=0.6820  rand_val_AUC=0.6981  val_AUC_drop=0.0161
# XGB_L2(1)_g3_lr0.03_n75  temp_val_AUC=0.6820  rand_val_AUC=0.6981  val_AUC_drop=0.0161
# XGB_L1_10_g3_lr0.01   temp_val_AUC=0.6795  rand_val_AUC=0.6957  val_AUC_drop=0.0162
# XGB_L2(1)_g5_lr0.01_n75  temp_val_AUC=0.6800  rand_val_AUC=0.6962  val_AUC_drop=0.0162
# XGB_L2(1)_g5_lr0.03_n75  temp_val_AUC=0.6819  rand_val_AUC=0.6981  val_AUC_drop=0.0162
# XGB_L2(1)_g1_lr0.01_n75  temp_val_AUC=0.6800  rand_val_AUC=0.6962  val_AUC_drop=0.0162
# XGB_L2(1)_g3_lr0.01_n75  temp_val_AUC=0.6800  rand_val_AUC=0.6962  val_AUC_drop=0.0162
# XGB_L2(1)_g1_lr0.01_n50  temp_val_AUC=0.6795  rand_val_AUC=0.6958  val_AUC_drop=0.0163
# XGB_L2(1)_g3_lr0.01_n50  temp_val_AUC=0.6795  rand_val_AUC=0.6958  val_AUC_drop=0.0163
# XGB_L2(1)_g5_lr0.01_n50  temp_val_AUC=0.6795  rand_val_AUC=0.6958  val_AUC_drop=0.0163
# XGB_L1_10_g1_lr0.01   temp_val_AUC=0.6794  rand_val_AUC=0.6957  val_AUC_drop=0.0164
# XGB_d3_lr0.01         temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0165
# XGB_mcw10_lr0.01      temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0166
# XGB_mcw3_lr0.01       temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0166
# XGB_mcw5_lr0.01       temp_val_AUC=0.6791  rand_val_AUC=0.6957  val_AUC_drop=0.0166
# XGB_col0.7_lr0.03     temp_val_AUC=0.6837  rand_val_AUC=0.7006  val_AUC_drop=0.0169
# XGB_L2(1)_g5_lr0.05_n50  temp_val_AUC=0.6821  rand_val_AUC=0.6990  val_AUC_drop=0.0169
# XGB_col0.7_lr0.03_rmmcw  temp_val_AUC=0.6836  rand_val_AUC=0.7006  val_AUC_drop=0.0170
# XGB_L2(1)_g3_lr0.05_n50  temp_val_AUC=0.6819  rand_val_AUC=0.6990  val_AUC_drop=0.0170
# XGB_L1_1_g5_lr0.03    temp_val_AUC=0.6825  rand_val_AUC=0.6996  val_AUC_drop=0.0171
# XGB_L2(1)_g1_lr0.05_n50  temp_val_AUC=0.6819  rand_val_AUC=0.6990  val_AUC_drop=0.0171
# XGB_col0.6_lr0.03     temp_val_AUC=0.6837  rand_val_AUC=0.7008  val_AUC_drop=0.0171
# XGB_col0.6_lr0.03_rmmcw  temp_val_AUC=0.6837  rand_val_AUC=0.7008  val_AUC_drop=0.0171
# XGB_col0.6_lr0.03_rmsub  temp_val_AUC=0.6829  rand_val_AUC=0.7001  val_AUC_drop=0.0172
# XGB_L1_5_g3_lr0.03    temp_val_AUC=0.6822  rand_val_AUC=0.6993  val_AUC_drop=0.0172
# XGB_L1_5_g5_lr0.03    temp_val_AUC=0.6821  rand_val_AUC=0.6993  val_AUC_drop=0.0172
# XGB_L1_1_g1_lr0.03    temp_val_AUC=0.6824  rand_val_AUC=0.6996  val_AUC_drop=0.0172
# XGB_L1_1_g3_lr0.03    temp_val_AUC=0.6824  rand_val_AUC=0.6996  val_AUC_drop=0.0173
# XGB_L1_5_g1_lr0.03    temp_val_AUC=0.6820  rand_val_AUC=0.6994  val_AUC_drop=0.0173
# XGB_L1_10_g5_lr0.03   temp_val_AUC=0.6815  rand_val_AUC=0.6990  val_AUC_drop=0.0175
# XGB_gamma5_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0175
# XGB_L2(1)_g5_lr0.03_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0175
# XGB_sub0.7_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_gamma1_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L2(1)_g1_lr0.03_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L1_10_g3_lr0.03   temp_val_AUC=0.6814  rand_val_AUC=0.6990  val_AUC_drop=0.0176
# XGB_gamma3_lr0.03     temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L2(1)_g3_lr0.03_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7002  val_AUC_drop=0.0176
# XGB_L1_10_g1_lr0.03   temp_val_AUC=0.6814  rand_val_AUC=0.6990  val_AUC_drop=0.0177
# XGB_col0.8_lr0.03_rmsub  temp_val_AUC=0.6822  rand_val_AUC=0.7002  val_AUC_drop=0.0179
# XGB_sub0.6_lr0.03     temp_val_AUC=0.6828  rand_val_AUC=0.7008  val_AUC_drop=0.0180
# XGB_mcw10_lr0.03      temp_val_AUC=0.6813  rand_val_AUC=0.6994  val_AUC_drop=0.0180
# XGB_mcw3_lr0.03       temp_val_AUC=0.6815  rand_val_AUC=0.6995  val_AUC_drop=0.0181
# XGB_d3_lr0.03         temp_val_AUC=0.6814  rand_val_AUC=0.6995  val_AUC_drop=0.0181
# XGB_col0.8_lr0.03_rmmcw  temp_val_AUC=0.6829  rand_val_AUC=0.7011  val_AUC_drop=0.0182
# XGB_col0.8_lr0.03     temp_val_AUC=0.6829  rand_val_AUC=0.7011  val_AUC_drop=0.0182
# XGB_mcw5_lr0.03       temp_val_AUC=0.6813  rand_val_AUC=0.6995  val_AUC_drop=0.0183
# XGB_sub0.8_lr0.03     temp_val_AUC=0.6821  rand_val_AUC=0.7005  val_AUC_drop=0.0184
# XGB_col0.7_lr0.03_rmsub  temp_val_AUC=0.6824  rand_val_AUC=0.7009  val_AUC_drop=0.0185
# XGB_L2(1)_g5_lr0.05_n75  temp_val_AUC=0.6823  rand_val_AUC=0.7023  val_AUC_drop=0.0200
# XGB_L2(1)_g3_lr0.05_n75  temp_val_AUC=0.6823  rand_val_AUC=0.7024  val_AUC_drop=0.0201
# XGB_L2(1)_g1_lr0.05_n75  temp_val_AUC=0.6822  rand_val_AUC=0.7024  val_AUC_drop=0.0202
# XGB_lr0.01            temp_val_AUC=0.6781  rand_val_AUC=0.6987  val_AUC_drop=0.0207
# XGB_lr0.005           temp_val_AUC=0.6761  rand_val_AUC=0.6967  val_AUC_drop=0.0207
# XGB_sub0.6_lr0.05     temp_val_AUC=0.6826  rand_val_AUC=0.7039  val_AUC_drop=0.0213
# XGB_L1_1_g1_lr0.05    temp_val_AUC=0.6829  rand_val_AUC=0.7046  val_AUC_drop=0.0217
# XGB_L1_1_g5_lr0.05    temp_val_AUC=0.6828  rand_val_AUC=0.7045  val_AUC_drop=0.0217
# XGB_gamma1_lr0.05     temp_val_AUC=0.6827  rand_val_AUC=0.7046  val_AUC_drop=0.0218
# XGB_L2(1)_g1_lr0.05_n100  temp_val_AUC=0.6827  rand_val_AUC=0.7046  val_AUC_drop=0.0218
# XGB_gamma3_lr0.05     temp_val_AUC=0.6826  rand_val_AUC=0.7044  val_AUC_drop=0.0218
# XGB_L2(1)_g3_lr0.05_n100  temp_val_AUC=0.6826  rand_val_AUC=0.7044  val_AUC_drop=0.0218
# XGB_sub0.7_lr0.05     temp_val_AUC=0.6827  rand_val_AUC=0.7046  val_AUC_drop=0.0218
# XGB_col0.7_lr0.05_rmsub  temp_val_AUC=0.6828  rand_val_AUC=0.7046  val_AUC_drop=0.0219
# XGB_L1_1_g3_lr0.05    temp_val_AUC=0.6826  rand_val_AUC=0.7046  val_AUC_drop=0.0220
# XGB_gamma5_lr0.05     temp_val_AUC=0.6824  rand_val_AUC=0.7045  val_AUC_drop=0.0221
# XGB_L2(1)_g5_lr0.05_n100  temp_val_AUC=0.6824  rand_val_AUC=0.7045  val_AUC_drop=0.0221
# XGB_L1_10_g3_lr0.05   temp_val_AUC=0.6821  rand_val_AUC=0.7042  val_AUC_drop=0.0221
# XGB_col0.7_lr0.05_rmmcw  temp_val_AUC=0.6836  rand_val_AUC=0.7058  val_AUC_drop=0.0222
# XGB_col0.8_lr0.05_rmsub  temp_val_AUC=0.6822  rand_val_AUC=0.7044  val_AUC_drop=0.0222
# XGB_col0.7_lr0.05     temp_val_AUC=0.6836  rand_val_AUC=0.7058  val_AUC_drop=0.0222
# XGB_col0.6_lr0.05     temp_val_AUC=0.6835  rand_val_AUC=0.7057  val_AUC_drop=0.0222
# XGB_L1_10_g5_lr0.05   temp_val_AUC=0.6818  rand_val_AUC=0.7041  val_AUC_drop=0.0222
# XGB_L1_10_g1_lr0.05   temp_val_AUC=0.6820  rand_val_AUC=0.7043  val_AUC_drop=0.0222
# XGB_L1_5_g3_lr0.05    temp_val_AUC=0.6824  rand_val_AUC=0.7047  val_AUC_drop=0.0223
# XGB_L1_5_g5_lr0.05    temp_val_AUC=0.6824  rand_val_AUC=0.7048  val_AUC_drop=0.0224
# XGB_col0.6_lr0.05_rmmcw  temp_val_AUC=0.6833  rand_val_AUC=0.7057  val_AUC_drop=0.0224
# XGB_L1_5_g1_lr0.05    temp_val_AUC=0.6824  rand_val_AUC=0.7049  val_AUC_drop=0.0225
# XGB_d3_lr0.05         temp_val_AUC=0.6812  rand_val_AUC=0.7037  val_AUC_drop=0.0225
# XGB_col0.6_lr0.05_rmsub  temp_val_AUC=0.6828  rand_val_AUC=0.7054  val_AUC_drop=0.0225
# XGB_sub0.8_lr0.05     temp_val_AUC=0.6819  rand_val_AUC=0.7046  val_AUC_drop=0.0226
# XGB_col0.8_lr0.05_rmmcw  temp_val_AUC=0.6825  rand_val_AUC=0.7053  val_AUC_drop=0.0228
# XGB_col0.8_lr0.05     temp_val_AUC=0.6825  rand_val_AUC=0.7053  val_AUC_drop=0.0228
# XGB_lr0.05            temp_val_AUC=0.6796  rand_val_AUC=0.7098  val_AUC_drop=0.0302
# XGB_d6_lr0.01         temp_val_AUC=0.6737  rand_val_AUC=0.7096  val_AUC_drop=0.0358
# XGB_base              temp_val_AUC=0.6767  rand_val_AUC=0.7126  val_AUC_drop=0.0359
# XGB_d6_lr0.03         temp_val_AUC=0.6751  rand_val_AUC=0.7174  val_AUC_drop=0.0423
# XGB_d6_lr0.05         temp_val_AUC=0.6727  rand_val_AUC=0.7199  val_AUC_drop=0.0471
# XGB_d8_lr0.01         temp_val_AUC=0.6676  rand_val_AUC=0.7147  val_AUC_drop=0.0472
# XGB_d8_lr0.03         temp_val_AUC=0.6688  rand_val_AUC=0.7236  val_AUC_drop=0.0547
# XGB_d8_lr0.05         temp_val_AUC=0.6671  rand_val_AUC=0.7238  val_AUC_drop=0.0568
# XGB_lr0.3             temp_val_AUC=0.6593  rand_val_AUC=0.7265  val_AUC_drop=0.0672
#
# === XGB - Test Set (Final) ===
# XGB_col0.7_lr0.01_rmmcw  temp_test_AUC=0.6832  random_test_AUC=0.7006  test_AUC_drop=0.0174
# XGB_col0.7_lr0.01     temp_test_AUC=0.6832  random_test_AUC=0.7006  test_AUC_drop=0.0174
# XGB_col0.6_lr0.01_rmmcw  temp_test_AUC=0.6830  random_test_AUC=0.7010  test_AUC_drop=0.0181
# XGB_col0.6_lr0.01     temp_test_AUC=0.6829  random_test_AUC=0.7010  test_AUC_drop=0.0181
# XGB_col0.6_lr0.03_rmmcw  temp_test_AUC=0.6827  random_test_AUC=0.7066  test_AUC_drop=0.0239
# XGB_col0.6_lr0.03     temp_test_AUC=0.6826  random_test_AUC=0.7066  test_AUC_drop=0.0240
# XGB_col0.8_lr0.01     temp_test_AUC=0.6824  random_test_AUC=0.6997  test_AUC_drop=0.0173
# XGB_col0.8_lr0.01_rmmcw  temp_test_AUC=0.6823  random_test_AUC=0.6997  test_AUC_drop=0.0174
# XGB_col0.8_lr0.03     temp_test_AUC=0.6823  random_test_AUC=0.7056  test_AUC_drop=0.0234
# XGB_col0.8_lr0.03_rmmcw  temp_test_AUC=0.6822  random_test_AUC=0.7056  test_AUC_drop=0.0234
# XGB_col0.6_lr0.05_rmmcw  temp_test_AUC=0.6820  random_test_AUC=0.7105  test_AUC_drop=0.0284
# XGB_col0.6_lr0.03_rmsub  temp_test_AUC=0.6820  random_test_AUC=0.7061  test_AUC_drop=0.0241
# XGB_col0.7_lr0.03_rmmcw  temp_test_AUC=0.6819  random_test_AUC=0.7058  test_AUC_drop=0.0239
# XGB_col0.7_lr0.03     temp_test_AUC=0.6819  random_test_AUC=0.7058  test_AUC_drop=0.0240
# XGB_col0.6_lr0.05     temp_test_AUC=0.6819  random_test_AUC=0.7105  test_AUC_drop=0.0287
# XGB_col0.7_lr0.05_rmmcw  temp_test_AUC=0.6817  random_test_AUC=0.7104  test_AUC_drop=0.0286
# XGB_col0.7_lr0.05     temp_test_AUC=0.6816  random_test_AUC=0.7103  test_AUC_drop=0.0287
# XGB_L2(1)_g5_lr0.05_n50  temp_test_AUC=0.6816  random_test_AUC=0.7035  test_AUC_drop=0.0219
# XGB_L2(1)_g5_lr0.05_n75  temp_test_AUC=0.6816  random_test_AUC=0.7069  test_AUC_drop=0.0254
# XGB_L2(1)_g1_lr0.05_n50  temp_test_AUC=0.6815  random_test_AUC=0.7035  test_AUC_drop=0.0220
# XGB_L2(1)_g1_lr0.05_n75  temp_test_AUC=0.6815  random_test_AUC=0.7070  test_AUC_drop=0.0255
# XGB_col0.7_lr0.03_rmsub  temp_test_AUC=0.6815  random_test_AUC=0.7059  test_AUC_drop=0.0244
# XGB_L2(1)_g3_lr0.05_n50  temp_test_AUC=0.6814  random_test_AUC=0.7035  test_AUC_drop=0.0221
# XGB_L2(1)_g5_lr0.03_n50  temp_test_AUC=0.6814  random_test_AUC=0.6997  test_AUC_drop=0.0183
# XGB_col0.8_lr0.03_rmsub  temp_test_AUC=0.6813  random_test_AUC=0.7052  test_AUC_drop=0.0240
# XGB_col0.8_lr0.05_rmmcw  temp_test_AUC=0.6812  random_test_AUC=0.7106  test_AUC_drop=0.0293
# XGB_col0.6_lr0.01_rmsub  temp_test_AUC=0.6812  random_test_AUC=0.7005  test_AUC_drop=0.0193
# XGB_L2(1)_g3_lr0.05_n75  temp_test_AUC=0.6812  random_test_AUC=0.7070  test_AUC_drop=0.0258
# XGB_L2(1)_g3_lr0.03_n50  temp_test_AUC=0.6812  random_test_AUC=0.6997  test_AUC_drop=0.0186
# XGB_L2(1)_g1_lr0.03_n50  temp_test_AUC=0.6811  random_test_AUC=0.6997  test_AUC_drop=0.0186
# XGB_L1_1_g5_lr0.03    temp_test_AUC=0.6811  random_test_AUC=0.7042  test_AUC_drop=0.0231
# XGB_col0.8_lr0.05_rmsub  temp_test_AUC=0.6811  random_test_AUC=0.7095  test_AUC_drop=0.0284
# XGB_col0.7_lr0.05_rmsub  temp_test_AUC=0.6811  random_test_AUC=0.7097  test_AUC_drop=0.0287
# XGB_col0.8_lr0.05     temp_test_AUC=0.6811  random_test_AUC=0.7106  test_AUC_drop=0.0295
# XGB_L2(1)_g5_lr0.03_n75  temp_test_AUC=0.6810  random_test_AUC=0.7022  test_AUC_drop=0.0211
# XGB_gamma5_lr0.03     temp_test_AUC=0.6810  random_test_AUC=0.7047  test_AUC_drop=0.0237
# XGB_L2(1)_g5_lr0.03_n100  temp_test_AUC=0.6810  random_test_AUC=0.7047  test_AUC_drop=0.0237
# XGB_L2(1)_g1_lr0.03_n75  temp_test_AUC=0.6810  random_test_AUC=0.7022  test_AUC_drop=0.0212
# XGB_L1_1_g3_lr0.03    temp_test_AUC=0.6810  random_test_AUC=0.7042  test_AUC_drop=0.0233
# XGB_gamma5_lr0.05     temp_test_AUC=0.6810  random_test_AUC=0.7093  test_AUC_drop=0.0283
# XGB_L2(1)_g5_lr0.05_n100  temp_test_AUC=0.6810  random_test_AUC=0.7093  test_AUC_drop=0.0283
# XGB_L1_1_g1_lr0.03    temp_test_AUC=0.6809  random_test_AUC=0.7043  test_AUC_drop=0.0233
# XGB_col0.7_lr0.01_rmsub  temp_test_AUC=0.6809  random_test_AUC=0.6999  test_AUC_drop=0.0190
# XGB_L2(1)_g3_lr0.03_n75  temp_test_AUC=0.6809  random_test_AUC=0.7022  test_AUC_drop=0.0213
# XGB_L1_5_g5_lr0.05    temp_test_AUC=0.6809  random_test_AUC=0.7095  test_AUC_drop=0.0286
# XGB_gamma1_lr0.05     temp_test_AUC=0.6809  random_test_AUC=0.7092  test_AUC_drop=0.0283
# XGB_L2(1)_g1_lr0.05_n100  temp_test_AUC=0.6809  random_test_AUC=0.7092  test_AUC_drop=0.0283
# XGB_sub0.7_lr0.05     temp_test_AUC=0.6809  random_test_AUC=0.7092  test_AUC_drop=0.0283
# XGB_sub0.7_lr0.03     temp_test_AUC=0.6808  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_gamma1_lr0.03     temp_test_AUC=0.6808  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_L2(1)_g1_lr0.03_n100  temp_test_AUC=0.6808  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_gamma3_lr0.03     temp_test_AUC=0.6807  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_L2(1)_g3_lr0.03_n100  temp_test_AUC=0.6807  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_L1_1_g3_lr0.05    temp_test_AUC=0.6807  random_test_AUC=0.7093  test_AUC_drop=0.0286
# XGB_sub0.6_lr0.03     temp_test_AUC=0.6807  random_test_AUC=0.7049  test_AUC_drop=0.0242
# XGB_L1_10_g5_lr0.05   temp_test_AUC=0.6807  random_test_AUC=0.7085  test_AUC_drop=0.0278
# XGB_col0.6_lr0.05_rmsub  temp_test_AUC=0.6806  random_test_AUC=0.7110  test_AUC_drop=0.0304
# XGB_gamma3_lr0.05     temp_test_AUC=0.6806  random_test_AUC=0.7092  test_AUC_drop=0.0285
# XGB_L2(1)_g3_lr0.05_n100  temp_test_AUC=0.6806  random_test_AUC=0.7092  test_AUC_drop=0.0285
# XGB_L1_5_g5_lr0.03    temp_test_AUC=0.6806  random_test_AUC=0.7035  test_AUC_drop=0.0229
# XGB_L1_1_g1_lr0.05    temp_test_AUC=0.6806  random_test_AUC=0.7093  test_AUC_drop=0.0287
# XGB_L1_1_g5_lr0.05    temp_test_AUC=0.6806  random_test_AUC=0.7092  test_AUC_drop=0.0286
# XGB_mcw3_lr0.03       temp_test_AUC=0.6804  random_test_AUC=0.7043  test_AUC_drop=0.0239
# XGB_L1_5_g3_lr0.03    temp_test_AUC=0.6804  random_test_AUC=0.7035  test_AUC_drop=0.0231
# XGB_L1_10_g3_lr0.05   temp_test_AUC=0.6803  random_test_AUC=0.7087  test_AUC_drop=0.0283
# XGB_sub0.8_lr0.03     temp_test_AUC=0.6803  random_test_AUC=0.7048  test_AUC_drop=0.0245
# XGB_L1_5_g3_lr0.05    temp_test_AUC=0.6803  random_test_AUC=0.7091  test_AUC_drop=0.0288
# XGB_d3_lr0.03         temp_test_AUC=0.6803  random_test_AUC=0.7043  test_AUC_drop=0.0241
# XGB_L1_5_g1_lr0.03    temp_test_AUC=0.6802  random_test_AUC=0.7035  test_AUC_drop=0.0233
# XGB_mcw5_lr0.03       temp_test_AUC=0.6802  random_test_AUC=0.7043  test_AUC_drop=0.0241
# XGB_L1_10_g1_lr0.05   temp_test_AUC=0.6801  random_test_AUC=0.7087  test_AUC_drop=0.0285
# XGB_mcw10_lr0.03      temp_test_AUC=0.6801  random_test_AUC=0.7041  test_AUC_drop=0.0240
# XGB_sub0.6_lr0.01     temp_test_AUC=0.6801  random_test_AUC=0.6977  test_AUC_drop=0.0176
# XGB_sub0.6_lr0.05     temp_test_AUC=0.6800  random_test_AUC=0.7088  test_AUC_drop=0.0288
# XGB_L1_5_g1_lr0.05    temp_test_AUC=0.6800  random_test_AUC=0.7090  test_AUC_drop=0.0290
# XGB_L1_10_g5_lr0.03   temp_test_AUC=0.6799  random_test_AUC=0.7030  test_AUC_drop=0.0231
# XGB_col0.8_lr0.01_rmsub  temp_test_AUC=0.6799  random_test_AUC=0.6990  test_AUC_drop=0.0192
# XGB_L1_10_g1_lr0.03   temp_test_AUC=0.6798  random_test_AUC=0.7031  test_AUC_drop=0.0233
# XGB_L1_10_g3_lr0.03   temp_test_AUC=0.6797  random_test_AUC=0.7030  test_AUC_drop=0.0233
# XGB_d3_lr0.05         temp_test_AUC=0.6796  random_test_AUC=0.7084  test_AUC_drop=0.0288
# XGB_L2(1)_g5_lr0.01_n75  temp_test_AUC=0.6795  random_test_AUC=0.6968  test_AUC_drop=0.0172
# XGB_L2(1)_g1_lr0.01_n75  temp_test_AUC=0.6795  random_test_AUC=0.6968  test_AUC_drop=0.0173
# XGB_L2(1)_g3_lr0.01_n75  temp_test_AUC=0.6795  random_test_AUC=0.6968  test_AUC_drop=0.0173
# XGB_gamma5_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g5_lr0.01_n100  temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L1_1_g5_lr0.01    temp_test_AUC=0.6794  random_test_AUC=0.6974  test_AUC_drop=0.0180
# XGB_sub0.7_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_gamma1_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_gamma3_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g1_lr0.01_n100  temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g3_lr0.01_n100  temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L1_1_g3_lr0.01    temp_test_AUC=0.6794  random_test_AUC=0.6974  test_AUC_drop=0.0181
# XGB_L2(1)_g5_lr0.01_n50  temp_test_AUC=0.6793  random_test_AUC=0.6964  test_AUC_drop=0.0171
# XGB_L2(1)_g1_lr0.01_n50  temp_test_AUC=0.6793  random_test_AUC=0.6964  test_AUC_drop=0.0171
# XGB_L2(1)_g3_lr0.01_n50  temp_test_AUC=0.6793  random_test_AUC=0.6964  test_AUC_drop=0.0171
# XGB_L1_1_g1_lr0.01    temp_test_AUC=0.6793  random_test_AUC=0.6974  test_AUC_drop=0.0181
# XGB_sub0.8_lr0.05     temp_test_AUC=0.6789  random_test_AUC=0.7096  test_AUC_drop=0.0307
# XGB_sub0.8_lr0.01     temp_test_AUC=0.6786  random_test_AUC=0.6972  test_AUC_drop=0.0186
# XGB_L1_5_g5_lr0.01    temp_test_AUC=0.6783  random_test_AUC=0.6971  test_AUC_drop=0.0188
# XGB_L1_5_g1_lr0.01    temp_test_AUC=0.6782  random_test_AUC=0.6971  test_AUC_drop=0.0189
# XGB_L1_5_g3_lr0.01    temp_test_AUC=0.6782  random_test_AUC=0.6971  test_AUC_drop=0.0189
# XGB_lr0.05            temp_test_AUC=0.6775  random_test_AUC=0.7148  test_AUC_drop=0.0373
# XGB_mcw10_lr0.01      temp_test_AUC=0.6773  random_test_AUC=0.6968  test_AUC_drop=0.0195
# XGB_mcw3_lr0.01       temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_mcw5_lr0.01       temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_d3_lr0.01         temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_L1_10_g5_lr0.01   temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_L1_10_g3_lr0.01   temp_test_AUC=0.6768  random_test_AUC=0.6968  test_AUC_drop=0.0200
# XGB_L1_10_g1_lr0.01   temp_test_AUC=0.6766  random_test_AUC=0.6968  test_AUC_drop=0.0202
# XGB_lr0.01            temp_test_AUC=0.6758  random_test_AUC=0.7022  test_AUC_drop=0.0264
# XGB_lr0.005           temp_test_AUC=0.6745  random_test_AUC=0.6997  test_AUC_drop=0.0253
# XGB_d6_lr0.03         temp_test_AUC=0.6732  random_test_AUC=0.7214  test_AUC_drop=0.0482
# XGB_base              temp_test_AUC=0.6726  random_test_AUC=0.7175  test_AUC_drop=0.0449
# XGB_d6_lr0.01         temp_test_AUC=0.6711  random_test_AUC=0.7121  test_AUC_drop=0.0410
# XGB_d6_lr0.05         temp_test_AUC=0.6700  random_test_AUC=0.7244  test_AUC_drop=0.0544
# XGB_d8_lr0.03         temp_test_AUC=0.6645  random_test_AUC=0.7266  test_AUC_drop=0.0621
# XGB_d8_lr0.01         temp_test_AUC=0.6641  random_test_AUC=0.7177  test_AUC_drop=0.0536
# XGB_d8_lr0.05         temp_test_AUC=0.6621  random_test_AUC=0.7276  test_AUC_drop=0.0656
# XGB_lr0.3             temp_test_AUC=0.6536  random_test_AUC=0.7309  test_AUC_drop=0.0773
#
# === XGB - Test Robustness (Final) ===
# XGB_L2(1)_g5_lr0.01_n50  temp_test_AUC=0.6793  random_test_AUC=0.6964  test_AUC_drop=0.0171
# XGB_L2(1)_g1_lr0.01_n50  temp_test_AUC=0.6793  random_test_AUC=0.6964  test_AUC_drop=0.0171
# XGB_L2(1)_g3_lr0.01_n50  temp_test_AUC=0.6793  random_test_AUC=0.6964  test_AUC_drop=0.0171
# XGB_L2(1)_g5_lr0.01_n75  temp_test_AUC=0.6795  random_test_AUC=0.6968  test_AUC_drop=0.0172
# XGB_L2(1)_g1_lr0.01_n75  temp_test_AUC=0.6795  random_test_AUC=0.6968  test_AUC_drop=0.0173
# XGB_L2(1)_g3_lr0.01_n75  temp_test_AUC=0.6795  random_test_AUC=0.6968  test_AUC_drop=0.0173
# XGB_col0.8_lr0.01     temp_test_AUC=0.6824  random_test_AUC=0.6997  test_AUC_drop=0.0173
# XGB_col0.8_lr0.01_rmmcw  temp_test_AUC=0.6823  random_test_AUC=0.6997  test_AUC_drop=0.0174
# XGB_col0.7_lr0.01_rmmcw  temp_test_AUC=0.6832  random_test_AUC=0.7006  test_AUC_drop=0.0174
# XGB_col0.7_lr0.01     temp_test_AUC=0.6832  random_test_AUC=0.7006  test_AUC_drop=0.0174
# XGB_sub0.6_lr0.01     temp_test_AUC=0.6801  random_test_AUC=0.6977  test_AUC_drop=0.0176
# XGB_L1_1_g5_lr0.01    temp_test_AUC=0.6794  random_test_AUC=0.6974  test_AUC_drop=0.0180
# XGB_L1_1_g3_lr0.01    temp_test_AUC=0.6794  random_test_AUC=0.6974  test_AUC_drop=0.0181
# XGB_col0.6_lr0.01_rmmcw  temp_test_AUC=0.6830  random_test_AUC=0.7010  test_AUC_drop=0.0181
# XGB_gamma5_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g5_lr0.01_n100  temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_col0.6_lr0.01     temp_test_AUC=0.6829  random_test_AUC=0.7010  test_AUC_drop=0.0181
# XGB_L1_1_g1_lr0.01    temp_test_AUC=0.6793  random_test_AUC=0.6974  test_AUC_drop=0.0181
# XGB_sub0.7_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_gamma1_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_gamma3_lr0.01     temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g1_lr0.01_n100  temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g3_lr0.01_n100  temp_test_AUC=0.6794  random_test_AUC=0.6976  test_AUC_drop=0.0181
# XGB_L2(1)_g5_lr0.03_n50  temp_test_AUC=0.6814  random_test_AUC=0.6997  test_AUC_drop=0.0183
# XGB_L2(1)_g3_lr0.03_n50  temp_test_AUC=0.6812  random_test_AUC=0.6997  test_AUC_drop=0.0186
# XGB_sub0.8_lr0.01     temp_test_AUC=0.6786  random_test_AUC=0.6972  test_AUC_drop=0.0186
# XGB_L2(1)_g1_lr0.03_n50  temp_test_AUC=0.6811  random_test_AUC=0.6997  test_AUC_drop=0.0186
# XGB_L1_5_g5_lr0.01    temp_test_AUC=0.6783  random_test_AUC=0.6971  test_AUC_drop=0.0188
# XGB_L1_5_g1_lr0.01    temp_test_AUC=0.6782  random_test_AUC=0.6971  test_AUC_drop=0.0189
# XGB_L1_5_g3_lr0.01    temp_test_AUC=0.6782  random_test_AUC=0.6971  test_AUC_drop=0.0189
# XGB_col0.7_lr0.01_rmsub  temp_test_AUC=0.6809  random_test_AUC=0.6999  test_AUC_drop=0.0190
# XGB_col0.8_lr0.01_rmsub  temp_test_AUC=0.6799  random_test_AUC=0.6990  test_AUC_drop=0.0192
# XGB_col0.6_lr0.01_rmsub  temp_test_AUC=0.6812  random_test_AUC=0.7005  test_AUC_drop=0.0193
# XGB_mcw10_lr0.01      temp_test_AUC=0.6773  random_test_AUC=0.6968  test_AUC_drop=0.0195
# XGB_L1_10_g5_lr0.01   temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_mcw3_lr0.01       temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_mcw5_lr0.01       temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_d3_lr0.01         temp_test_AUC=0.6772  random_test_AUC=0.6968  test_AUC_drop=0.0196
# XGB_L1_10_g3_lr0.01   temp_test_AUC=0.6768  random_test_AUC=0.6968  test_AUC_drop=0.0200
# XGB_L1_10_g1_lr0.01   temp_test_AUC=0.6766  random_test_AUC=0.6968  test_AUC_drop=0.0202
# XGB_L2(1)_g5_lr0.03_n75  temp_test_AUC=0.6810  random_test_AUC=0.7022  test_AUC_drop=0.0211
# XGB_L2(1)_g1_lr0.03_n75  temp_test_AUC=0.6810  random_test_AUC=0.7022  test_AUC_drop=0.0212
# XGB_L2(1)_g3_lr0.03_n75  temp_test_AUC=0.6809  random_test_AUC=0.7022  test_AUC_drop=0.0213
# XGB_L2(1)_g5_lr0.05_n50  temp_test_AUC=0.6816  random_test_AUC=0.7035  test_AUC_drop=0.0219
# XGB_L2(1)_g1_lr0.05_n50  temp_test_AUC=0.6815  random_test_AUC=0.7035  test_AUC_drop=0.0220
# XGB_L2(1)_g3_lr0.05_n50  temp_test_AUC=0.6814  random_test_AUC=0.7035  test_AUC_drop=0.0221
# XGB_L1_5_g5_lr0.03    temp_test_AUC=0.6806  random_test_AUC=0.7035  test_AUC_drop=0.0229
# XGB_L1_10_g5_lr0.03   temp_test_AUC=0.6799  random_test_AUC=0.7030  test_AUC_drop=0.0231
# XGB_L1_1_g5_lr0.03    temp_test_AUC=0.6811  random_test_AUC=0.7042  test_AUC_drop=0.0231
# XGB_L1_5_g3_lr0.03    temp_test_AUC=0.6804  random_test_AUC=0.7035  test_AUC_drop=0.0231
# XGB_L1_5_g1_lr0.03    temp_test_AUC=0.6802  random_test_AUC=0.7035  test_AUC_drop=0.0233
# XGB_L1_1_g3_lr0.03    temp_test_AUC=0.6810  random_test_AUC=0.7042  test_AUC_drop=0.0233
# XGB_L1_10_g1_lr0.03   temp_test_AUC=0.6798  random_test_AUC=0.7031  test_AUC_drop=0.0233
# XGB_L1_1_g1_lr0.03    temp_test_AUC=0.6809  random_test_AUC=0.7043  test_AUC_drop=0.0233
# XGB_L1_10_g3_lr0.03   temp_test_AUC=0.6797  random_test_AUC=0.7030  test_AUC_drop=0.0233
# XGB_col0.8_lr0.03     temp_test_AUC=0.6823  random_test_AUC=0.7056  test_AUC_drop=0.0234
# XGB_col0.8_lr0.03_rmmcw  temp_test_AUC=0.6822  random_test_AUC=0.7056  test_AUC_drop=0.0234
# XGB_gamma5_lr0.03     temp_test_AUC=0.6810  random_test_AUC=0.7047  test_AUC_drop=0.0237
# XGB_L2(1)_g5_lr0.03_n100  temp_test_AUC=0.6810  random_test_AUC=0.7047  test_AUC_drop=0.0237
# XGB_col0.6_lr0.03_rmmcw  temp_test_AUC=0.6827  random_test_AUC=0.7066  test_AUC_drop=0.0239
# XGB_sub0.7_lr0.03     temp_test_AUC=0.6808  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_gamma1_lr0.03     temp_test_AUC=0.6808  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_L2(1)_g1_lr0.03_n100  temp_test_AUC=0.6808  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_col0.7_lr0.03_rmmcw  temp_test_AUC=0.6819  random_test_AUC=0.7058  test_AUC_drop=0.0239
# XGB_mcw3_lr0.03       temp_test_AUC=0.6804  random_test_AUC=0.7043  test_AUC_drop=0.0239
# XGB_gamma3_lr0.03     temp_test_AUC=0.6807  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_L2(1)_g3_lr0.03_n100  temp_test_AUC=0.6807  random_test_AUC=0.7047  test_AUC_drop=0.0239
# XGB_col0.8_lr0.03_rmsub  temp_test_AUC=0.6813  random_test_AUC=0.7052  test_AUC_drop=0.0240
# XGB_col0.7_lr0.03     temp_test_AUC=0.6819  random_test_AUC=0.7058  test_AUC_drop=0.0240
# XGB_mcw10_lr0.03      temp_test_AUC=0.6801  random_test_AUC=0.7041  test_AUC_drop=0.0240
# XGB_col0.6_lr0.03     temp_test_AUC=0.6826  random_test_AUC=0.7066  test_AUC_drop=0.0240
# XGB_d3_lr0.03         temp_test_AUC=0.6803  random_test_AUC=0.7043  test_AUC_drop=0.0241
# XGB_col0.6_lr0.03_rmsub  temp_test_AUC=0.6820  random_test_AUC=0.7061  test_AUC_drop=0.0241
# XGB_mcw5_lr0.03       temp_test_AUC=0.6802  random_test_AUC=0.7043  test_AUC_drop=0.0241
# XGB_sub0.6_lr0.03     temp_test_AUC=0.6807  random_test_AUC=0.7049  test_AUC_drop=0.0242
# XGB_col0.7_lr0.03_rmsub  temp_test_AUC=0.6815  random_test_AUC=0.7059  test_AUC_drop=0.0244
# XGB_sub0.8_lr0.03     temp_test_AUC=0.6803  random_test_AUC=0.7048  test_AUC_drop=0.0245
# XGB_lr0.005           temp_test_AUC=0.6745  random_test_AUC=0.6997  test_AUC_drop=0.0253
# XGB_L2(1)_g5_lr0.05_n75  temp_test_AUC=0.6816  random_test_AUC=0.7069  test_AUC_drop=0.0254
# XGB_L2(1)_g1_lr0.05_n75  temp_test_AUC=0.6815  random_test_AUC=0.7070  test_AUC_drop=0.0255
# XGB_L2(1)_g3_lr0.05_n75  temp_test_AUC=0.6812  random_test_AUC=0.7070  test_AUC_drop=0.0258
# XGB_lr0.01            temp_test_AUC=0.6758  random_test_AUC=0.7022  test_AUC_drop=0.0264
# XGB_L1_10_g5_lr0.05   temp_test_AUC=0.6807  random_test_AUC=0.7085  test_AUC_drop=0.0278
# XGB_gamma1_lr0.05     temp_test_AUC=0.6809  random_test_AUC=0.7092  test_AUC_drop=0.0283
# XGB_L2(1)_g1_lr0.05_n100  temp_test_AUC=0.6809  random_test_AUC=0.7092  test_AUC_drop=0.0283
# XGB_sub0.7_lr0.05     temp_test_AUC=0.6809  random_test_AUC=0.7092  test_AUC_drop=0.0283
# XGB_L1_10_g3_lr0.05   temp_test_AUC=0.6803  random_test_AUC=0.7087  test_AUC_drop=0.0283
# XGB_gamma5_lr0.05     temp_test_AUC=0.6810  random_test_AUC=0.7093  test_AUC_drop=0.0283
# XGB_L2(1)_g5_lr0.05_n100  temp_test_AUC=0.6810  random_test_AUC=0.7093  test_AUC_drop=0.0283
# XGB_col0.8_lr0.05_rmsub  temp_test_AUC=0.6811  random_test_AUC=0.7095  test_AUC_drop=0.0284
# XGB_col0.6_lr0.05_rmmcw  temp_test_AUC=0.6820  random_test_AUC=0.7105  test_AUC_drop=0.0284
# XGB_L1_10_g1_lr0.05   temp_test_AUC=0.6801  random_test_AUC=0.7087  test_AUC_drop=0.0285
# XGB_gamma3_lr0.05     temp_test_AUC=0.6806  random_test_AUC=0.7092  test_AUC_drop=0.0285
# XGB_L2(1)_g3_lr0.05_n100  temp_test_AUC=0.6806  random_test_AUC=0.7092  test_AUC_drop=0.0285
# XGB_L1_1_g3_lr0.05    temp_test_AUC=0.6807  random_test_AUC=0.7093  test_AUC_drop=0.0286
# XGB_L1_5_g5_lr0.05    temp_test_AUC=0.6809  random_test_AUC=0.7095  test_AUC_drop=0.0286
# XGB_col0.7_lr0.05_rmmcw  temp_test_AUC=0.6817  random_test_AUC=0.7104  test_AUC_drop=0.0286
# XGB_L1_1_g5_lr0.05    temp_test_AUC=0.6806  random_test_AUC=0.7092  test_AUC_drop=0.0286
# XGB_col0.6_lr0.05     temp_test_AUC=0.6819  random_test_AUC=0.7105  test_AUC_drop=0.0287
# XGB_col0.7_lr0.05_rmsub  temp_test_AUC=0.6811  random_test_AUC=0.7097  test_AUC_drop=0.0287
# XGB_col0.7_lr0.05     temp_test_AUC=0.6816  random_test_AUC=0.7103  test_AUC_drop=0.0287
# XGB_L1_1_g1_lr0.05    temp_test_AUC=0.6806  random_test_AUC=0.7093  test_AUC_drop=0.0287
# XGB_sub0.6_lr0.05     temp_test_AUC=0.6800  random_test_AUC=0.7088  test_AUC_drop=0.0288
# XGB_d3_lr0.05         temp_test_AUC=0.6796  random_test_AUC=0.7084  test_AUC_drop=0.0288
# XGB_L1_5_g3_lr0.05    temp_test_AUC=0.6803  random_test_AUC=0.7091  test_AUC_drop=0.0288
# XGB_L1_5_g1_lr0.05    temp_test_AUC=0.6800  random_test_AUC=0.7090  test_AUC_drop=0.0290
# XGB_col0.8_lr0.05_rmmcw  temp_test_AUC=0.6812  random_test_AUC=0.7106  test_AUC_drop=0.0293
# XGB_col0.8_lr0.05     temp_test_AUC=0.6811  random_test_AUC=0.7106  test_AUC_drop=0.0295
# XGB_col0.6_lr0.05_rmsub  temp_test_AUC=0.6806  random_test_AUC=0.7110  test_AUC_drop=0.0304
# XGB_sub0.8_lr0.05     temp_test_AUC=0.6789  random_test_AUC=0.7096  test_AUC_drop=0.0307
# XGB_lr0.05            temp_test_AUC=0.6775  random_test_AUC=0.7148  test_AUC_drop=0.0373
# XGB_d6_lr0.01         temp_test_AUC=0.6711  random_test_AUC=0.7121  test_AUC_drop=0.0410
# XGB_base              temp_test_AUC=0.6726  random_test_AUC=0.7175  test_AUC_drop=0.0449
# XGB_d6_lr0.03         temp_test_AUC=0.6732  random_test_AUC=0.7214  test_AUC_drop=0.0482
# XGB_d8_lr0.01         temp_test_AUC=0.6641  random_test_AUC=0.7177  test_AUC_drop=0.0536
# XGB_d6_lr0.05         temp_test_AUC=0.6700  random_test_AUC=0.7244  test_AUC_drop=0.0544
# XGB_d8_lr0.03         temp_test_AUC=0.6645  random_test_AUC=0.7266  test_AUC_drop=0.0621
# XGB_d8_lr0.05         temp_test_AUC=0.6621  random_test_AUC=0.7276  test_AUC_drop=0.0656
# XGB_lr0.3             temp_test_AUC=0.6536  random_test_AUC=0.7309  test_AUC_drop=0.0773
# === XGBoost Selection Summary ===
# Best by temporal val AUC: XGB_col0.7_lr0.03
#   val_AUC=0.6837  test_AUC=0.6819  AUC_drop=0.0240
#
# Best by robustness (smallest AUC drop): XGB_L2(1)_g5_lr0.01_n50
#   val_AUC=0.6795  test_AUC=0.6793  AUC_drop=0.0171
#
# Best balanced (val_AUC - AUC_drop): XGB_col0.7_lr0.01_rmmcw
#   val_AUC=0.6832  test_AUC=0.6832  AUC_drop=0.0174

# %%
def objective_xgb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 150),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.05, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 4),
        'subsample': trial.suggest_float('subsample', 0.6, 0.85),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 1.0, 3.0),
        'scale_pos_weight': trial.suggest_categorical('scale_pos_weight', [1, 5, 8]),
    }

    model = XGBClassifier(**params, eval_metric='logloss', random_state=42)
    model.fit(X_train_t, y_train_t)
    model_r = XGBClassifier(**params, eval_metric='logloss', random_state=42)
    model_r.fit(X_rand_tr, y_rand_tr)

    val_auc = roc_auc_score(y_val_t, model.predict_proba(X_val_t)[:, 1])
    rand_auc = roc_auc_score(y_rand_val, model_r.predict_proba(X_rand_val)[:, 1])
    auc_drop = rand_auc - val_auc

    y_prob_val = model.predict_proba(X_val_t)[:, 1]
    thresholds = np.arange(0.05, 0.50, 0.01)
    best_thr = max(thresholds, key=lambda t: f1_score(y_val_t, (y_prob_val >= t).astype(int), zero_division=0))
    val_f1 = f1_score(y_val_t, (y_prob_val >= best_thr).astype(int), zero_division=0)

    return w_performance * val_auc - w_robustness * auc_drop + w_f1 * val_f1

study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_xgb.optimize(objective_xgb, n_trials=60, show_progress_bar=True)
# Out:
# [I 2026-05-07 02:42:54,715] A new study created in memory with name: no-name-ccc65e92-a7cc-461a-8520-fc5fae4d1bd0
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-05-07 02:42:56,776] Trial 0 finished with value: 0.2805542901415071 and parameters: {'n_estimators': 87, 'learning_rate': 0.046187109390049115, 'max_depth': 4, 'subsample': 0.7496646210492591, 'gamma': 0.7800932022121826, 'reg_lambda': 1.3119890406724053, 'scale_pos_weight': 5}. Best is trial 0 with value: 0.2805542901415071.
# [I 2026-05-07 02:42:58,841] Trial 1 finished with value: 0.2738092696737117 and parameters: {'n_estimators': 121, 'learning_rate': 0.010336843570697411, 'max_depth': 4, 'subsample': 0.8081106602001054, 'gamma': 1.0616955533913808, 'reg_lambda': 1.3636499344142012, 'scale_pos_weight': 8}. Best is trial 0 with value: 0.2805542901415071.
# [I 2026-05-07 02:43:00,611] Trial 2 finished with value: 0.28425411656608734 and parameters: {'n_estimators': 93, 'learning_rate': 0.01597939871741036, 'max_depth': 4, 'subsample': 0.6348734651630105, 'gamma': 1.4607232426760908, 'reg_lambda': 1.7327236865873834, 'scale_pos_weight': 5}. Best is trial 2 with value: 0.28425411656608734.
# [I 2026-05-07 02:43:02,234] Trial 3 finished with value: 0.28602316100934205 and parameters: {'n_estimators': 101, 'learning_rate': 0.025946573538779622, 'max_depth': 3, 'subsample': 0.7518862129753596, 'gamma': 0.8526206184364576, 'reg_lambda': 1.130103185970559, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:04,101] Trial 4 finished with value: 0.2840243298337495 and parameters: {'n_estimators': 80, 'learning_rate': 0.011702263636127802, 'max_depth': 4, 'subsample': 0.7100381234349002, 'gamma': 0.6101911742238941, 'reg_lambda': 1.9903538202225404, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:10,502] Trial 5 finished with value: 0.28263089028085403 and parameters: {'n_estimators': 116, 'learning_rate': 0.016514928287652886, 'max_depth': 4, 'subsample': 0.7366775698358199, 'gamma': 0.9242722776276352, 'reg_lambda': 2.939169255529117, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:12,719] Trial 6 finished with value: 0.27681166558175907 and parameters: {'n_estimators': 110, 'learning_rate': 0.04409226795827594, 'max_depth': 3, 'subsample': 0.6489957156047863, 'gamma': 0.22613644455269033, 'reg_lambda': 1.6506606615265287, 'scale_pos_weight': 8}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:14,410] Trial 7 finished with value: 0.2846328822367153 and parameters: {'n_estimators': 86, 'learning_rate': 0.015716824201651516, 'max_depth': 4, 'subsample': 0.6352310562436907, 'gamma': 4.010984903770199, 'reg_lambda': 1.1491012873595416, 'scale_pos_weight': 1}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:15,566] Trial 8 finished with value: 0.2758788629300192 and parameters: {'n_estimators': 50, 'learning_rate': 0.03715207529088701, 'max_depth': 4, 'subsample': 0.7822517920102467, 'gamma': 3.8563517334297286, 'reg_lambda': 1.1480893034681807, 'scale_pos_weight': 8}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:17,387] Trial 9 finished with value: 0.28592624454410553 and parameters: {'n_estimators': 112, 'learning_rate': 0.017032868513634135, 'max_depth': 3, 'subsample': 0.6777455804289155, 'gamma': 1.6259166101337352, 'reg_lambda': 2.459212356676128, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:19,409] Trial 10 finished with value: 0.2848502808595409 and parameters: {'n_estimators': 145, 'learning_rate': 0.028463916808402774, 'max_depth': 3, 'subsample': 0.8330725854779467, 'gamma': 2.595720016297407, 'reg_lambda': 2.3804941471382906, 'scale_pos_weight': 1}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:24,559] Trial 11 finished with value: 0.2855417227825524 and parameters: {'n_estimators': 135, 'learning_rate': 0.024113836516591467, 'max_depth': 3, 'subsample': 0.6815150175898782, 'gamma': 2.199746022641412, 'reg_lambda': 2.5965434120792867, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:27,496] Trial 12 finished with value: 0.2859157324571697 and parameters: {'n_estimators': 64, 'learning_rate': 0.021582187933354292, 'max_depth': 3, 'subsample': 0.6893476635282882, 'gamma': 2.0336289354778776, 'reg_lambda': 2.2917128814064824, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:29,125] Trial 13 finished with value: 0.2847604867124106 and parameters: {'n_estimators': 103, 'learning_rate': 0.02931831391466514, 'max_depth': 3, 'subsample': 0.7657255638237337, 'gamma': 2.6356325170657584, 'reg_lambda': 2.8651584117869007, 'scale_pos_weight': 5}. Best is trial 3 with value: 0.28602316100934205.
# [I 2026-05-07 02:43:31,108] Trial 14 finished with value: 0.2863618665150863 and parameters: {'n_estimators': 127, 'learning_rate': 0.020336416590674453, 'max_depth': 3, 'subsample': 0.6022366375225473, 'gamma': 1.6359377514960272, 'reg_lambda': 2.1109838103285603, 'scale_pos_weight': 5}. Best is trial 14 with value: 0.2863618665150863.
# [I 2026-05-07 02:43:33,092] Trial 15 finished with value: 0.287308170785324 and parameters: {'n_estimators': 129, 'learning_rate': 0.02113853169504217, 'max_depth': 3, 'subsample': 0.6064508519741295, 'gamma': 4.980084946806068, 'reg_lambda': 2.0240199592506998, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:35,078] Trial 16 finished with value: 0.2870443563644315 and parameters: {'n_estimators': 130, 'learning_rate': 0.021072605927449143, 'max_depth': 3, 'subsample': 0.6062687835906765, 'gamma': 4.729404374721523, 'reg_lambda': 2.062799098183946, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:38,525] Trial 17 finished with value: 0.2864238475089811 and parameters: {'n_estimators': 145, 'learning_rate': 0.03366551038931191, 'max_depth': 3, 'subsample': 0.6013230408124183, 'gamma': 4.88633232797539, 'reg_lambda': 1.8835658502423192, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:43,712] Trial 18 finished with value: 0.2866749350370773 and parameters: {'n_estimators': 134, 'learning_rate': 0.01282766542606983, 'max_depth': 3, 'subsample': 0.6532886731697447, 'gamma': 4.957287725272482, 'reg_lambda': 1.5898641455878735, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:45,733] Trial 19 finished with value: 0.2869536323356618 and parameters: {'n_estimators': 130, 'learning_rate': 0.020178785752925803, 'max_depth': 3, 'subsample': 0.6153036090556183, 'gamma': 4.149720545809459, 'reg_lambda': 2.124918315962111, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:47,907] Trial 20 finished with value: 0.2870147140958459 and parameters: {'n_estimators': 150, 'learning_rate': 0.01877810709267065, 'max_depth': 3, 'subsample': 0.6660175916155925, 'gamma': 3.410013363267332, 'reg_lambda': 2.6869607922606686, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:50,202] Trial 21 finished with value: 0.2863221999151982 and parameters: {'n_estimators': 149, 'learning_rate': 0.01860577578747336, 'max_depth': 3, 'subsample': 0.6292784142863926, 'gamma': 3.2405167387505056, 'reg_lambda': 2.649264451043962, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:52,339] Trial 22 finished with value: 0.2865071673442984 and parameters: {'n_estimators': 139, 'learning_rate': 0.013958963911970754, 'max_depth': 3, 'subsample': 0.6510457465900988, 'gamma': 4.383006162373654, 'reg_lambda': 2.7364540084927422, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:43:58,878] Trial 23 finished with value: 0.28687543129797605 and parameters: {'n_estimators': 122, 'learning_rate': 0.023048538033400894, 'max_depth': 3, 'subsample': 0.6674049809665998, 'gamma': 3.3986126851272025, 'reg_lambda': 2.204893836098267, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:44:01,054] Trial 24 finished with value: 0.28617628577395626 and parameters: {'n_estimators': 150, 'learning_rate': 0.01885594715559869, 'max_depth': 3, 'subsample': 0.7026733381960222, 'gamma': 4.550055883458381, 'reg_lambda': 1.8599491178327108, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:44:02,996] Trial 25 finished with value: 0.2869176550245778 and parameters: {'n_estimators': 125, 'learning_rate': 0.026462610527224407, 'max_depth': 3, 'subsample': 0.61861212455281, 'gamma': 3.487325811994112, 'reg_lambda': 2.0001597505783435, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:44:04,998] Trial 26 finished with value: 0.2855994125646719 and parameters: {'n_estimators': 138, 'learning_rate': 0.032374014917309415, 'max_depth': 3, 'subsample': 0.6574351162678785, 'gamma': 2.9307571130783816, 'reg_lambda': 2.455475107342421, 'scale_pos_weight': 1}. Best is trial 15 with value: 0.287308170785324.
# [I 2026-05-07 02:44:07,132] Trial 27 finished with value: 0.28742453877548646 and parameters: {'n_estimators': 141, 'learning_rate': 0.014214098936582431, 'max_depth': 3, 'subsample': 0.6200638003140176, 'gamma': 4.5826670249299095, 'reg_lambda': 1.4709363669585676, 'scale_pos_weight': 1}. Best is trial 27 with value: 0.28742453877548646.
# [I 2026-05-07 02:44:09,325] Trial 28 finished with value: 0.2875826582331339 and parameters: {'n_estimators': 119, 'learning_rate': 0.013596226505057735, 'max_depth': 3, 'subsample': 0.6157499064877974, 'gamma': 4.617496923264991, 'reg_lambda': 1.4268787777083447, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:14,639] Trial 29 finished with value: 0.27762542678633567 and parameters: {'n_estimators': 109, 'learning_rate': 0.014030250079477431, 'max_depth': 3, 'subsample': 0.6272801442580518, 'gamma': 4.375401761078428, 'reg_lambda': 1.4125667407574634, 'scale_pos_weight': 8}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:17,197] Trial 30 finished with value: 0.28585043780782826 and parameters: {'n_estimators': 117, 'learning_rate': 0.010226192796274803, 'max_depth': 3, 'subsample': 0.7209363530715921, 'gamma': 3.9752172287308065, 'reg_lambda': 1.0005242246094257, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:19,947] Trial 31 finished with value: 0.28711989666712506 and parameters: {'n_estimators': 134, 'learning_rate': 0.011795055377267258, 'max_depth': 3, 'subsample': 0.6005500065683218, 'gamma': 4.678688890425058, 'reg_lambda': 1.5156040774637685, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:22,104] Trial 32 finished with value: 0.28685487144071387 and parameters: {'n_estimators': 140, 'learning_rate': 0.011901334036824914, 'max_depth': 3, 'subsample': 0.6200668649158109, 'gamma': 4.616951811808417, 'reg_lambda': 1.490008558227866, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:23,984] Trial 33 finished with value: 0.28623180815068283 and parameters: {'n_estimators': 120, 'learning_rate': 0.011120390970385518, 'max_depth': 3, 'subsample': 0.6336162407705184, 'gamma': 3.7927750068970782, 'reg_lambda': 1.2954880459099067, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:27,394] Trial 34 finished with value: 0.2864513736878266 and parameters: {'n_estimators': 131, 'learning_rate': 0.014216402124622262, 'max_depth': 3, 'subsample': 0.6437054750066221, 'gamma': 4.321421927561992, 'reg_lambda': 1.7538873713994487, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:33,259] Trial 35 finished with value: 0.2759447484848698 and parameters: {'n_estimators': 142, 'learning_rate': 0.01270912969623837, 'max_depth': 4, 'subsample': 0.6120456421795999, 'gamma': 4.993746856427347, 'reg_lambda': 1.2775861838519116, 'scale_pos_weight': 8}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:35,211] Trial 36 finished with value: 0.2874366499124751 and parameters: {'n_estimators': 125, 'learning_rate': 0.014865865521571799, 'max_depth': 3, 'subsample': 0.6027415632716495, 'gamma': 4.610268869677245, 'reg_lambda': 1.5291206706407277, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:36,802] Trial 37 finished with value: 0.28676754388480186 and parameters: {'n_estimators': 93, 'learning_rate': 0.015676281512405712, 'max_depth': 3, 'subsample': 0.6388655888763154, 'gamma': 3.686275771399461, 'reg_lambda': 1.7494485141930076, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:38,731] Trial 38 finished with value: 0.2847574933028343 and parameters: {'n_estimators': 105, 'learning_rate': 0.017258193607074018, 'max_depth': 4, 'subsample': 0.6224306275649244, 'gamma': 4.241002439771634, 'reg_lambda': 1.3843640549906693, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:41,114] Trial 39 finished with value: 0.27825319346914107 and parameters: {'n_estimators': 124, 'learning_rate': 0.014683671225751645, 'max_depth': 3, 'subsample': 0.8038502713470804, 'gamma': 4.5143440244080955, 'reg_lambda': 1.5998405888019416, 'scale_pos_weight': 8}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:48,123] Trial 40 finished with value: 0.28427498420389463 and parameters: {'n_estimators': 116, 'learning_rate': 0.012724252653538343, 'max_depth': 4, 'subsample': 0.6652989143820467, 'gamma': 4.09211820506419, 'reg_lambda': 1.8790386097243772, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:50,154] Trial 41 finished with value: 0.2869790425130043 and parameters: {'n_estimators': 133, 'learning_rate': 0.011525886839415212, 'max_depth': 3, 'subsample': 0.6038720843242315, 'gamma': 4.781131944044059, 'reg_lambda': 1.488984112309469, 'scale_pos_weight': 1}. Best is trial 28 with value: 0.2875826582331339.
# [I 2026-05-07 02:44:52,114] Trial 42 finished with value: 0.2878832271204838 and parameters: {'n_estimators': 126, 'learning_rate': 0.015400435116568936, 'max_depth': 3, 'subsample': 0.6144357458572153, 'gamma': 4.6808075436236285, 'reg_lambda': 1.5009315456772554, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:44:53,927] Trial 43 finished with value: 0.28670320431324475 and parameters: {'n_estimators': 113, 'learning_rate': 0.01551162345763885, 'max_depth': 3, 'subsample': 0.6387372952368443, 'gamma': 4.481240139637967, 'reg_lambda': 1.234036145355752, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:44:55,577] Trial 44 finished with value: 0.28713206074409786 and parameters: {'n_estimators': 95, 'learning_rate': 0.017341155825772635, 'max_depth': 3, 'subsample': 0.6174081017262006, 'gamma': 4.997960773300674, 'reg_lambda': 1.7227333359139756, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:44:57,363] Trial 45 finished with value: 0.2842798748995311 and parameters: {'n_estimators': 119, 'learning_rate': 0.048459799294126624, 'max_depth': 3, 'subsample': 0.6281099526348185, 'gamma': 0.0203461620945653, 'reg_lambda': 1.6412212689952281, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:00,386] Trial 46 finished with value: 0.2729642416214628 and parameters: {'n_estimators': 77, 'learning_rate': 0.013038895636114805, 'max_depth': 3, 'subsample': 0.615084802658555, 'gamma': 4.716020365787239, 'reg_lambda': 1.3832998815528934, 'scale_pos_weight': 8}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:05,392] Trial 47 finished with value: 0.28635316199332456 and parameters: {'n_estimators': 129, 'learning_rate': 0.010991488703966462, 'max_depth': 3, 'subsample': 0.6401283710371145, 'gamma': 3.701295072295773, 'reg_lambda': 1.1913801244427982, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:07,133] Trial 48 finished with value: 0.28640747727546806 and parameters: {'n_estimators': 108, 'learning_rate': 0.014935538949290011, 'max_depth': 3, 'subsample': 0.7389367989866963, 'gamma': 0.5971999619557242, 'reg_lambda': 1.0748977496845078, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:09,090] Trial 49 finished with value: 0.286374824688461 and parameters: {'n_estimators': 126, 'learning_rate': 0.016769494279770633, 'max_depth': 3, 'subsample': 0.6082155255178832, 'gamma': 4.189291238708796, 'reg_lambda': 1.534960264490514, 'scale_pos_weight': 5}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:10,751] Trial 50 finished with value: 0.2865156296471203 and parameters: {'n_estimators': 99, 'learning_rate': 0.013455057410836036, 'max_depth': 3, 'subsample': 0.629078488226982, 'gamma': 3.951975026732039, 'reg_lambda': 1.8033803899277294, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:12,384] Trial 51 finished with value: 0.28661017695683744 and parameters: {'n_estimators': 96, 'learning_rate': 0.018061620087901215, 'max_depth': 3, 'subsample': 0.6150153166725143, 'gamma': 4.974949745798823, 'reg_lambda': 1.7073370678006936, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:13,823] Trial 52 finished with value: 0.2864785646540986 and parameters: {'n_estimators': 82, 'learning_rate': 0.016410934141579774, 'max_depth': 3, 'subsample': 0.600275569516176, 'gamma': 4.534964131495247, 'reg_lambda': 1.4389380622656383, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:17,856] Trial 53 finished with value: 0.2868811417082403 and parameters: {'n_estimators': 89, 'learning_rate': 0.020087238997210745, 'max_depth': 3, 'subsample': 0.6222985615803055, 'gamma': 4.8326806915989025, 'reg_lambda': 1.3221765827701408, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:21,239] Trial 54 finished with value: 0.2866327010431488 and parameters: {'n_estimators': 74, 'learning_rate': 0.017390009816313147, 'max_depth': 3, 'subsample': 0.6479135688453125, 'gamma': 4.823138209884655, 'reg_lambda': 1.681540635267163, 'scale_pos_weight': 1}. Best is trial 42 with value: 0.2878832271204838.
# [I 2026-05-07 02:45:23,302] Trial 55 finished with value: 0.28788825782374317 and parameters: {'n_estimators': 137, 'learning_rate': 0.015221938541885404, 'max_depth': 3, 'subsample': 0.6130218289443606, 'gamma': 4.313387713193672, 'reg_lambda': 1.567614807194918, 'scale_pos_weight': 1}. Best is trial 55 with value: 0.28788825782374317.
# [I 2026-05-07 02:45:25,386] Trial 56 finished with value: 0.28608145601134993 and parameters: {'n_estimators': 144, 'learning_rate': 0.01521673491619822, 'max_depth': 3, 'subsample': 0.6881258988479882, 'gamma': 4.151037900058472, 'reg_lambda': 1.96305331861889, 'scale_pos_weight': 5}. Best is trial 55 with value: 0.28788825782374317.
# [I 2026-05-07 02:45:27,317] Trial 57 finished with value: 0.28541596460299956 and parameters: {'n_estimators': 136, 'learning_rate': 0.023808229312142996, 'max_depth': 3, 'subsample': 0.7679076276028531, 'gamma': 1.3055725682678783, 'reg_lambda': 1.554408233522327, 'scale_pos_weight': 1}. Best is trial 55 with value: 0.28788825782374317.
# [I 2026-05-07 02:45:29,552] Trial 58 finished with value: 0.2873588222040485 and parameters: {'n_estimators': 146, 'learning_rate': 0.013700500312796123, 'max_depth': 3, 'subsample': 0.6111391597664722, 'gamma': 4.400476536042668, 'reg_lambda': 2.2159240790034436, 'scale_pos_weight': 1}. Best is trial 55 with value: 0.28788825782374317.
# [I 2026-05-07 02:45:33,640] Trial 59 finished with value: 0.28659894634102595 and parameters: {'n_estimators': 138, 'learning_rate': 0.0121624720161122, 'max_depth': 3, 'subsample': 0.6578160585352735, 'gamma': 4.352717250847878, 'reg_lambda': 1.4507597518833608, 'scale_pos_weight': 1}. Best is trial 55 with value: 0.28788825782374317.

# %%
# ── best 10 => XGB_MODEL_CONFIGS ──────────────────────────────
trials_df = study_xgb.trials_dataframe().sort_values('value', ascending=False).head(10)

XGB_MODEL_CONFIGS = {}
for i, row in enumerate(study_xgb.trials):
    if i >= 10:
        break
top_trials = sorted(study_xgb.trials, key=lambda t: t.value if t.value else -999, reverse=True)[:10]

for i, t in enumerate(top_trials):
    name = f'XGB_optuna_{i+1}'
    XGB_MODEL_CONFIGS[name] = (
        XGBClassifier(**t.params, eval_metric='logloss', random_state=42), 'raw'
    )

# ── evaluation ────────────────────────────────────────────────
xgb_results = evaluate_model_configs(XGB_MODEL_CONFIGS)

# (val set)
print_selection_table(xgb_results, sort_key='val_auc', reverse=True, title='XGB - Val Set', mode='val')
print_selection_table(xgb_results, sort_key='val_auc_drop', reverse=False, title='XGB - Val Robustness', mode='val')
print_selection_table(xgb_results, sort_key='val_recall', reverse=True, title='XGB - Val Recall', mode='val')

# (test set)
print_selection_table(xgb_results, sort_key='test_auc', reverse=True, title='XGB - Test Set (Final)', mode='test')
print_selection_table(xgb_results, sort_key='test_auc_drop', reverse=False, title='XGB - Test Robustness (Final)', mode='test')
print_selection_table(xgb_results, sort_key='recall', reverse=True, title='XGB - Test Recall (Final)', mode='test')

# (best summary)
print_best_summary(xgb_results, prefix='XGB_', title='XGBoost Selection Summary')

# ── Hyperparameter print ──────────────────────────────────────
print_optuna_results(study_xgb, top_trials, title='XGB Optuna Hyperparameter Results')
# Out:
# === XGB - Val Set ===
# XGB_optuna_10         temp_val_AUC=0.6827  rand_val_AUC=0.6991  val_AUC_drop=0.0164  val_Recall=0.6268  val_Precision=0.2734  val_F1=0.3807  threshold=0.15
# XGB_optuna_7          temp_val_AUC=0.6826  rand_val_AUC=0.6990  val_AUC_drop=0.0163  val_Recall=0.6277  val_Precision=0.2738  val_F1=0.3812  threshold=0.15
# XGB_optuna_1          temp_val_AUC=0.6824  rand_val_AUC=0.6976  val_AUC_drop=0.0153  val_Recall=0.6270  val_Precision=0.2744  val_F1=0.3817  threshold=0.15
# XGB_optuna_5          temp_val_AUC=0.6823  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6272  val_Precision=0.2739  val_F1=0.3813  threshold=0.15
# XGB_optuna_2          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6253  val_Precision=0.2748  val_F1=0.3818  threshold=0.15
# XGB_optuna_4          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6240  val_Precision=0.2741  val_F1=0.3809  threshold=0.15
# XGB_optuna_6          temp_val_AUC=0.6822  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6229  val_Precision=0.2746  val_F1=0.3812  threshold=0.15
# XGB_optuna_3          temp_val_AUC=0.6821  rand_val_AUC=0.6969  val_AUC_drop=0.0149  val_Recall=0.6206  val_Precision=0.2748  val_F1=0.3809  threshold=0.15
# XGB_optuna_9          temp_val_AUC=0.6819  rand_val_AUC=0.6971  val_AUC_drop=0.0152  val_Recall=0.6231  val_Precision=0.2737  val_F1=0.3803  threshold=0.15
# XGB_optuna_8          temp_val_AUC=0.6816  rand_val_AUC=0.6967  val_AUC_drop=0.0150  val_Recall=0.6220  val_Precision=0.2739  val_F1=0.3803  threshold=0.15
#
# === XGB - Val Robustness ===
# XGB_optuna_3          temp_val_AUC=0.6821  rand_val_AUC=0.6969  val_AUC_drop=0.0149  val_Recall=0.6206  val_Precision=0.2748  val_F1=0.3809  threshold=0.15
# XGB_optuna_8          temp_val_AUC=0.6816  rand_val_AUC=0.6967  val_AUC_drop=0.0150  val_Recall=0.6220  val_Precision=0.2739  val_F1=0.3803  threshold=0.15
# XGB_optuna_9          temp_val_AUC=0.6819  rand_val_AUC=0.6971  val_AUC_drop=0.0152  val_Recall=0.6231  val_Precision=0.2737  val_F1=0.3803  threshold=0.15
# XGB_optuna_1          temp_val_AUC=0.6824  rand_val_AUC=0.6976  val_AUC_drop=0.0153  val_Recall=0.6270  val_Precision=0.2744  val_F1=0.3817  threshold=0.15
# XGB_optuna_2          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6253  val_Precision=0.2748  val_F1=0.3818  threshold=0.15
# XGB_optuna_4          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6240  val_Precision=0.2741  val_F1=0.3809  threshold=0.15
# XGB_optuna_5          temp_val_AUC=0.6823  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6272  val_Precision=0.2739  val_F1=0.3813  threshold=0.15
# XGB_optuna_6          temp_val_AUC=0.6822  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6229  val_Precision=0.2746  val_F1=0.3812  threshold=0.15
# XGB_optuna_7          temp_val_AUC=0.6826  rand_val_AUC=0.6990  val_AUC_drop=0.0163  val_Recall=0.6277  val_Precision=0.2738  val_F1=0.3812  threshold=0.15
# XGB_optuna_10         temp_val_AUC=0.6827  rand_val_AUC=0.6991  val_AUC_drop=0.0164  val_Recall=0.6268  val_Precision=0.2734  val_F1=0.3807  threshold=0.15
#
# === XGB - Val Recall ===
# XGB_optuna_7          temp_val_AUC=0.6826  rand_val_AUC=0.6990  val_AUC_drop=0.0163  val_Recall=0.6277  val_Precision=0.2738  val_F1=0.3812  threshold=0.15
# XGB_optuna_5          temp_val_AUC=0.6823  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6272  val_Precision=0.2739  val_F1=0.3813  threshold=0.15
# XGB_optuna_1          temp_val_AUC=0.6824  rand_val_AUC=0.6976  val_AUC_drop=0.0153  val_Recall=0.6270  val_Precision=0.2744  val_F1=0.3817  threshold=0.15
# XGB_optuna_10         temp_val_AUC=0.6827  rand_val_AUC=0.6991  val_AUC_drop=0.0164  val_Recall=0.6268  val_Precision=0.2734  val_F1=0.3807  threshold=0.15
# XGB_optuna_2          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6253  val_Precision=0.2748  val_F1=0.3818  threshold=0.15
# XGB_optuna_4          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6240  val_Precision=0.2741  val_F1=0.3809  threshold=0.15
# XGB_optuna_9          temp_val_AUC=0.6819  rand_val_AUC=0.6971  val_AUC_drop=0.0152  val_Recall=0.6231  val_Precision=0.2737  val_F1=0.3803  threshold=0.15
# XGB_optuna_6          temp_val_AUC=0.6822  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6229  val_Precision=0.2746  val_F1=0.3812  threshold=0.15
# XGB_optuna_8          temp_val_AUC=0.6816  rand_val_AUC=0.6967  val_AUC_drop=0.0150  val_Recall=0.6220  val_Precision=0.2739  val_F1=0.3803  threshold=0.15
# XGB_optuna_3          temp_val_AUC=0.6821  rand_val_AUC=0.6969  val_AUC_drop=0.0149  val_Recall=0.6206  val_Precision=0.2748  val_F1=0.3809  threshold=0.15
#
# === XGB - Test Set (Final) ===
# XGB_optuna_10         temp_test_AUC=0.6813  random_test_AUC=0.7036  test_AUC_drop=0.0223  Recall=0.6090  Precision=0.1364  F1=0.2229  threshold=0.15
# XGB_optuna_7          temp_test_AUC=0.6812  random_test_AUC=0.7034  test_AUC_drop=0.0221  Recall=0.6087  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_5          temp_test_AUC=0.6810  random_test_AUC=0.7015  test_AUC_drop=0.0205  Recall=0.6090  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_1          temp_test_AUC=0.6810  random_test_AUC=0.7017  test_AUC_drop=0.0207  Recall=0.6093  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_3          temp_test_AUC=0.6810  random_test_AUC=0.7000  test_AUC_drop=0.0190  Recall=0.6017  Precision=0.1370  F1=0.2231  threshold=0.15
# XGB_optuna_2          temp_test_AUC=0.6810  random_test_AUC=0.7012  test_AUC_drop=0.0203  Recall=0.6057  Precision=0.1367  F1=0.2230  threshold=0.15
# XGB_optuna_6          temp_test_AUC=0.6809  random_test_AUC=0.7014  test_AUC_drop=0.0206  Recall=0.6074  Precision=0.1371  F1=0.2237  threshold=0.15
# XGB_optuna_4          temp_test_AUC=0.6808  random_test_AUC=0.7006  test_AUC_drop=0.0197  Recall=0.6063  Precision=0.1366  F1=0.2229  threshold=0.15
# XGB_optuna_9          temp_test_AUC=0.6808  random_test_AUC=0.6998  test_AUC_drop=0.0189  Recall=0.6068  Precision=0.1364  F1=0.2228  threshold=0.15
# XGB_optuna_8          temp_test_AUC=0.6806  random_test_AUC=0.6996  test_AUC_drop=0.0190  Recall=0.6059  Precision=0.1367  F1=0.2231  threshold=0.15
#
# === XGB - Test Robustness (Final) ===
# XGB_optuna_9          temp_test_AUC=0.6808  random_test_AUC=0.6998  test_AUC_drop=0.0189  Recall=0.6068  Precision=0.1364  F1=0.2228  threshold=0.15
# XGB_optuna_8          temp_test_AUC=0.6806  random_test_AUC=0.6996  test_AUC_drop=0.0190  Recall=0.6059  Precision=0.1367  F1=0.2231  threshold=0.15
# XGB_optuna_3          temp_test_AUC=0.6810  random_test_AUC=0.7000  test_AUC_drop=0.0190  Recall=0.6017  Precision=0.1370  F1=0.2231  threshold=0.15
# XGB_optuna_4          temp_test_AUC=0.6808  random_test_AUC=0.7006  test_AUC_drop=0.0197  Recall=0.6063  Precision=0.1366  F1=0.2229  threshold=0.15
# XGB_optuna_2          temp_test_AUC=0.6810  random_test_AUC=0.7012  test_AUC_drop=0.0203  Recall=0.6057  Precision=0.1367  F1=0.2230  threshold=0.15
# XGB_optuna_5          temp_test_AUC=0.6810  random_test_AUC=0.7015  test_AUC_drop=0.0205  Recall=0.6090  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_6          temp_test_AUC=0.6809  random_test_AUC=0.7014  test_AUC_drop=0.0206  Recall=0.6074  Precision=0.1371  F1=0.2237  threshold=0.15
# XGB_optuna_1          temp_test_AUC=0.6810  random_test_AUC=0.7017  test_AUC_drop=0.0207  Recall=0.6093  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_7          temp_test_AUC=0.6812  random_test_AUC=0.7034  test_AUC_drop=0.0221  Recall=0.6087  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_10         temp_test_AUC=0.6813  random_test_AUC=0.7036  test_AUC_drop=0.0223  Recall=0.6090  Precision=0.1364  F1=0.2229  threshold=0.15
#
# === XGB - Test Recall (Final) ===
# XGB_optuna_1          temp_test_AUC=0.6810  random_test_AUC=0.7017  test_AUC_drop=0.0207  Recall=0.6093  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_5          temp_test_AUC=0.6810  random_test_AUC=0.7015  test_AUC_drop=0.0205  Recall=0.6090  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_10         temp_test_AUC=0.6813  random_test_AUC=0.7036  test_AUC_drop=0.0223  Recall=0.6090  Precision=0.1364  F1=0.2229  threshold=0.15
# XGB_optuna_7          temp_test_AUC=0.6812  random_test_AUC=0.7034  test_AUC_drop=0.0221  Recall=0.6087  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_6          temp_test_AUC=0.6809  random_test_AUC=0.7014  test_AUC_drop=0.0206  Recall=0.6074  Precision=0.1371  F1=0.2237  threshold=0.15
# XGB_optuna_9          temp_test_AUC=0.6808  random_test_AUC=0.6998  test_AUC_drop=0.0189  Recall=0.6068  Precision=0.1364  F1=0.2228  threshold=0.15
# XGB_optuna_4          temp_test_AUC=0.6808  random_test_AUC=0.7006  test_AUC_drop=0.0197  Recall=0.6063  Precision=0.1366  F1=0.2229  threshold=0.15
# XGB_optuna_8          temp_test_AUC=0.6806  random_test_AUC=0.6996  test_AUC_drop=0.0190  Recall=0.6059  Precision=0.1367  F1=0.2231  threshold=0.15
# XGB_optuna_2          temp_test_AUC=0.6810  random_test_AUC=0.7012  test_AUC_drop=0.0203  Recall=0.6057  Precision=0.1367  F1=0.2230  threshold=0.15
# XGB_optuna_3          temp_test_AUC=0.6810  random_test_AUC=0.7000  test_AUC_drop=0.0190  Recall=0.6017  Precision=0.1370  F1=0.2231  threshold=0.15
# === XGBoost Selection Summary ===
# Best by temporal val AUC: XGB_optuna_10
#   val_AUC=0.6827  test_AUC=0.6813  AUC_drop=0.0223
#
# Best by robustness (smallest AUC drop): XGB_optuna_9
#   val_AUC=0.6819  test_AUC=0.6808  AUC_drop=0.0189
#
# Best balanced (val_AUC - AUC_drop): XGB_optuna_3
#   val_AUC=0.6821  test_AUC=0.6810  AUC_drop=0.0190
#
# === XGB Optuna Hyperparameter Results ===
# Best score: 0.2879
#
# Best params:
#   n_estimators        : 137
#   learning_rate       : 0.015221938541885404
#   max_depth           : 3
#   subsample           : 0.6130218289443606
#   gamma               : 4.313387713193672
#   reg_lambda          : 1.567614807194918
#   scale_pos_weight    : 1
#
# === Top 10 Trials ===
#
# [1] score=0.2879
#   n_estimators        : 137
#   learning_rate       : 0.015221938541885404
#   max_depth           : 3
#   subsample           : 0.6130218289443606
#   gamma               : 4.313387713193672
#   reg_lambda          : 1.567614807194918
#   scale_pos_weight    : 1
#
# [2] score=0.2879
#   n_estimators        : 126
#   learning_rate       : 0.015400435116568936
#   max_depth           : 3
#   subsample           : 0.6144357458572153
#   gamma               : 4.6808075436236285
#   reg_lambda          : 1.5009315456772554
#   scale_pos_weight    : 1
#
# [3] score=0.2876
#   n_estimators        : 119
#   learning_rate       : 0.013596226505057735
#   max_depth           : 3
#   subsample           : 0.6157499064877974
#   gamma               : 4.617496923264991
#   reg_lambda          : 1.4268787777083447
#   scale_pos_weight    : 1
#
# [4] score=0.2874
#   n_estimators        : 125
#   learning_rate       : 0.014865865521571799
#   max_depth           : 3
#   subsample           : 0.6027415632716495
#   gamma               : 4.610268869677245
#   reg_lambda          : 1.5291206706407277
#   scale_pos_weight    : 1
#
# [5] score=0.2874
#   n_estimators        : 141
#   learning_rate       : 0.014214098936582431
#   max_depth           : 3
#   subsample           : 0.6200638003140176
#   gamma               : 4.5826670249299095
#   reg_lambda          : 1.4709363669585676
#   scale_pos_weight    : 1
#
# [6] score=0.2874
#   n_estimators        : 146
#   learning_rate       : 0.013700500312796123
#   max_depth           : 3
#   subsample           : 0.6111391597664722
#   gamma               : 4.400476536042668
#   reg_lambda          : 2.2159240790034436
#   scale_pos_weight    : 1
#
# [7] score=0.2873
#   n_estimators        : 129
#   learning_rate       : 0.02113853169504217
#   max_depth           : 3
#   subsample           : 0.6064508519741295
#   gamma               : 4.980084946806068
#   reg_lambda          : 2.0240199592506998
#   scale_pos_weight    : 1
#
# [8] score=0.2871
#   n_estimators        : 95
#   learning_rate       : 0.017341155825772635
#   max_depth           : 3
#   subsample           : 0.6174081017262006
#   gamma               : 4.997960773300674
#   reg_lambda          : 1.7227333359139756
#   scale_pos_weight    : 1
#
# [9] score=0.2871
#   n_estimators        : 134
#   learning_rate       : 0.011795055377267258
#   max_depth           : 3
#   subsample           : 0.6005500065683218
#   gamma               : 4.678688890425058
#   reg_lambda          : 1.5156040774637685
#   scale_pos_weight    : 1
#
# [10] score=0.2870
#   n_estimators        : 130
#   learning_rate       : 0.021072605927449143
#   max_depth           : 3
#   subsample           : 0.6062687835906765
#   gamma               : 4.729404374721523
#   reg_lambda          : 2.062799098183946
#   scale_pos_weight    : 1

# %% [markdown]
# ## Logistic Regression Test Code (Find Best)

# %%
LR_MODEL_CONFIGS = {
    # 1) L2 sweep
    'LR_L2_C0.0001': (LogisticRegression(C=0.0001, penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L2_C0.001':  (LogisticRegression(C=0.001,  penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L2_C0.01':   (LogisticRegression(C=0.01,   penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L2_C0.1':    (LogisticRegression(C=0.1,    penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L2_C1':      (LogisticRegression(C=1.0,    penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L2_C10':     (LogisticRegression(C=10.0,   penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L2_C100':    (LogisticRegression(C=100.0,  penalty='l2', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),

    # 2) L1 sweep (sparsity)
    'LR_L1_C0.001':  (LogisticRegression(C=0.0001,  penalty='l1', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L1_C0.01':   (LogisticRegression(C=0.001,   penalty='l1', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L1_C0.1':    (LogisticRegression(C=0.01,    penalty='l1', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L1_C1':      (LogisticRegression(C=1.0,    penalty='l1', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L1_C10':     (LogisticRegression(C=10.0,   penalty='l1', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),
    'LR_L1_C100':    (LogisticRegression(C=100.0,  penalty='l1', solver='liblinear', max_iter=2000, random_state=42), 'scaled'),

    # 3) ElasticNet sweep (L1+L2)
    'LR_EN_C0.0001_l10.3':  (LogisticRegression(C=0.0001,  penalty='elasticnet', solver='saga', l1_ratio=0.3, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.0001_l10.5':  (LogisticRegression(C=0.0001,  penalty='elasticnet', solver='saga', l1_ratio=0.5, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.0001_l10.7':  (LogisticRegression(C=0.0001,  penalty='elasticnet', solver='saga', l1_ratio=0.7, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.001_l10.05':   (LogisticRegression(C=0.001,   penalty='elasticnet', solver='saga', l1_ratio=0.05, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.001_l10.1':   (LogisticRegression(C=0.001,   penalty='elasticnet', solver='saga', l1_ratio=0.1, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.001_l10.2':   (LogisticRegression(C=0.001,   penalty='elasticnet', solver='saga', l1_ratio=0.2, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.001_l10.3':   (LogisticRegression(C=0.001,   penalty='elasticnet', solver='saga', l1_ratio=0.3, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.001_l10.5':   (LogisticRegression(C=0.001,   penalty='elasticnet', solver='saga', l1_ratio=0.5, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.001_l10.7':   (LogisticRegression(C=0.001,   penalty='elasticnet', solver='saga', l1_ratio=0.7, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.01_l10.3':     (LogisticRegression(C=1.01,   penalty='elasticnet', solver='saga', l1_ratio=0.3, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.01_l10.5':     (LogisticRegression(C=1.01,   penalty='elasticnet', solver='saga', l1_ratio=0.5, max_iter=2000, random_state=42), 'scaled'),
    'LR_EN_C0.01_l10.7':     (LogisticRegression(C=1.01,   penalty='elasticnet', solver='saga', l1_ratio=0.7, max_iter=2000, random_state=42), 'scaled'),
}

print(f'Total LR model configs: {len(LR_MODEL_CONFIGS)}')
# Out:
# Total LR model configs: 25

# %%
# lr_results = evaluate_model_configs(LR_MODEL_CONFIGS)

# # (val set)
# print_selection_table(lr_results, sort_key='val_auc', reverse=True, title='LR - Val Set', mode='val')
# print_selection_table(lr_results, sort_key='val_auc_drop', reverse=False, title='LR - Val Robustness', mode='val')

# # (test set)
# print_selection_table(lr_results, sort_key='test_auc', reverse=True, title='LR - Test Set (Final)', mode='test')
# print_selection_table(lr_results, sort_key='test_auc_drop', reverse=False, title='LR - Test Robustness (Final)', mode='test')

# # (best summary)
# print_best_summary(lr_results, prefix='LR_', title='Logistic Regression Selection Summary')
# Out:
# === LR - Val Set ===
# LR_L2_C0.001          temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021
# LR_EN_C0.001_l10.05   temp_val_AUC=0.6851  rand_val_AUC=0.6877  val_AUC_drop=0.0026
# LR_EN_C0.001_l10.1    temp_val_AUC=0.6843  rand_val_AUC=0.6879  val_AUC_drop=0.0036
# LR_EN_C0.001_l10.2    temp_val_AUC=0.6833  rand_val_AUC=0.6881  val_AUC_drop=0.0048
# LR_L2_C0.0001         temp_val_AUC=0.6823  rand_val_AUC=0.6869  val_AUC_drop=0.0046
# LR_L2_C0.01           temp_val_AUC=0.6823  rand_val_AUC=0.6877  val_AUC_drop=0.0054
# LR_L1_C0.1            temp_val_AUC=0.6820  rand_val_AUC=0.6879  val_AUC_drop=0.0059
# LR_EN_C0.001_l10.3    temp_val_AUC=0.6812  rand_val_AUC=0.6882  val_AUC_drop=0.0070
# LR_L2_C0.1            temp_val_AUC=0.6787  rand_val_AUC=0.6876  val_AUC_drop=0.0089
# LR_L1_C1              temp_val_AUC=0.6781  rand_val_AUC=0.6876  val_AUC_drop=0.0095
# LR_EN_C0.01_l10.7     temp_val_AUC=0.6781  rand_val_AUC=0.6876  val_AUC_drop=0.0095
# LR_EN_C0.01_l10.5     temp_val_AUC=0.6780  rand_val_AUC=0.6876  val_AUC_drop=0.0095
# LR_EN_C0.01_l10.3     temp_val_AUC=0.6780  rand_val_AUC=0.6876  val_AUC_drop=0.0096
# LR_L2_C1              temp_val_AUC=0.6779  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L1_C10             temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L2_C10             temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L1_C100            temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L2_C100            temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L1_C0.01           temp_val_AUC=0.6774  rand_val_AUC=0.6861  val_AUC_drop=0.0088
# LR_EN_C0.001_l10.5    temp_val_AUC=0.6774  rand_val_AUC=0.6879  val_AUC_drop=0.0105
# LR_EN_C0.001_l10.7    temp_val_AUC=0.6774  rand_val_AUC=0.6871  val_AUC_drop=0.0097
# LR_L1_C0.001          temp_val_AUC=0.5000  rand_val_AUC=0.5000  val_AUC_drop=0.0000
# LR_EN_C0.0001_l10.3   temp_val_AUC=0.5000  rand_val_AUC=0.6857  val_AUC_drop=0.1857
# LR_EN_C0.0001_l10.5   temp_val_AUC=0.5000  rand_val_AUC=0.6835  val_AUC_drop=0.1835
# LR_EN_C0.0001_l10.7   temp_val_AUC=0.5000  rand_val_AUC=0.6835  val_AUC_drop=0.1835
#
# === LR - Val Robustness ===
# LR_L1_C0.001          temp_val_AUC=0.5000  rand_val_AUC=0.5000  val_AUC_drop=0.0000
# LR_L2_C0.001          temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021
# LR_EN_C0.001_l10.05   temp_val_AUC=0.6851  rand_val_AUC=0.6877  val_AUC_drop=0.0026
# LR_EN_C0.001_l10.1    temp_val_AUC=0.6843  rand_val_AUC=0.6879  val_AUC_drop=0.0036
# LR_L2_C0.0001         temp_val_AUC=0.6823  rand_val_AUC=0.6869  val_AUC_drop=0.0046
# LR_EN_C0.001_l10.2    temp_val_AUC=0.6833  rand_val_AUC=0.6881  val_AUC_drop=0.0048
# LR_L2_C0.01           temp_val_AUC=0.6823  rand_val_AUC=0.6877  val_AUC_drop=0.0054
# LR_L1_C0.1            temp_val_AUC=0.6820  rand_val_AUC=0.6879  val_AUC_drop=0.0059
# LR_EN_C0.001_l10.3    temp_val_AUC=0.6812  rand_val_AUC=0.6882  val_AUC_drop=0.0070
# LR_L1_C0.01           temp_val_AUC=0.6774  rand_val_AUC=0.6861  val_AUC_drop=0.0088
# LR_L2_C0.1            temp_val_AUC=0.6787  rand_val_AUC=0.6876  val_AUC_drop=0.0089
# LR_L1_C1              temp_val_AUC=0.6781  rand_val_AUC=0.6876  val_AUC_drop=0.0095
# LR_EN_C0.01_l10.7     temp_val_AUC=0.6781  rand_val_AUC=0.6876  val_AUC_drop=0.0095
# LR_EN_C0.01_l10.5     temp_val_AUC=0.6780  rand_val_AUC=0.6876  val_AUC_drop=0.0095
# LR_EN_C0.01_l10.3     temp_val_AUC=0.6780  rand_val_AUC=0.6876  val_AUC_drop=0.0096
# LR_L2_C1              temp_val_AUC=0.6779  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_EN_C0.001_l10.7    temp_val_AUC=0.6774  rand_val_AUC=0.6871  val_AUC_drop=0.0097
# LR_L1_C10             temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L2_C10             temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L1_C100            temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_L2_C100            temp_val_AUC=0.6778  rand_val_AUC=0.6876  val_AUC_drop=0.0097
# LR_EN_C0.001_l10.5    temp_val_AUC=0.6774  rand_val_AUC=0.6879  val_AUC_drop=0.0105
# LR_EN_C0.0001_l10.5   temp_val_AUC=0.5000  rand_val_AUC=0.6835  val_AUC_drop=0.1835
# LR_EN_C0.0001_l10.7   temp_val_AUC=0.5000  rand_val_AUC=0.6835  val_AUC_drop=0.1835
# LR_EN_C0.0001_l10.3   temp_val_AUC=0.5000  rand_val_AUC=0.6857  val_AUC_drop=0.1857
#
# === LR - Test Set (Final) ===
# LR_EN_C0.001_l10.2    temp_test_AUC=0.6867  random_test_AUC=0.6893  test_AUC_drop=0.0025
# LR_EN_C0.001_l10.1    temp_test_AUC=0.6863  random_test_AUC=0.6892  test_AUC_drop=0.0029
# LR_EN_C0.001_l10.3    temp_test_AUC=0.6859  random_test_AUC=0.6893  test_AUC_drop=0.0034
# LR_EN_C0.001_l10.05   temp_test_AUC=0.6855  random_test_AUC=0.6890  test_AUC_drop=0.0035
# LR_L1_C0.01           temp_test_AUC=0.6834  random_test_AUC=0.6858  test_AUC_drop=0.0023
# LR_EN_C0.001_l10.5    temp_test_AUC=0.6834  random_test_AUC=0.6888  test_AUC_drop=0.0053
# LR_EN_C0.001_l10.7    temp_test_AUC=0.6834  random_test_AUC=0.6878  test_AUC_drop=0.0043
# LR_L1_C0.1            temp_test_AUC=0.6830  random_test_AUC=0.6892  test_AUC_drop=0.0062
# LR_L2_C0.001          temp_test_AUC=0.6827  random_test_AUC=0.6891  test_AUC_drop=0.0064
# LR_L2_C0.0001         temp_test_AUC=0.6824  random_test_AUC=0.6882  test_AUC_drop=0.0058
# LR_L2_C0.01           temp_test_AUC=0.6758  random_test_AUC=0.6889  test_AUC_drop=0.0130
# LR_L2_C0.1            temp_test_AUC=0.6694  random_test_AUC=0.6888  test_AUC_drop=0.0193
# LR_L1_C1              temp_test_AUC=0.6684  random_test_AUC=0.6888  test_AUC_drop=0.0203
# LR_EN_C0.01_l10.7     temp_test_AUC=0.6684  random_test_AUC=0.6888  test_AUC_drop=0.0203
# LR_EN_C0.01_l10.5     temp_test_AUC=0.6684  random_test_AUC=0.6888  test_AUC_drop=0.0204
# LR_EN_C0.01_l10.3     temp_test_AUC=0.6683  random_test_AUC=0.6887  test_AUC_drop=0.0204
# LR_L2_C1              temp_test_AUC=0.6681  random_test_AUC=0.6887  test_AUC_drop=0.0206
# LR_L1_C10             temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0207
# LR_L2_C10             temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0207
# LR_L1_C100            temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0208
# LR_L2_C100            temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0208
# LR_L1_C0.001          temp_test_AUC=0.5000  random_test_AUC=0.5000  test_AUC_drop=0.0000
# LR_EN_C0.0001_l10.3   temp_test_AUC=0.5000  random_test_AUC=0.6841  test_AUC_drop=0.1841
# LR_EN_C0.0001_l10.5   temp_test_AUC=0.5000  random_test_AUC=0.6804  test_AUC_drop=0.1804
# LR_EN_C0.0001_l10.7   temp_test_AUC=0.5000  random_test_AUC=0.6804  test_AUC_drop=0.1804
#
# === LR - Test Robustness (Final) ===
# LR_L1_C0.001          temp_test_AUC=0.5000  random_test_AUC=0.5000  test_AUC_drop=0.0000
# LR_L1_C0.01           temp_test_AUC=0.6834  random_test_AUC=0.6858  test_AUC_drop=0.0023
# LR_EN_C0.001_l10.2    temp_test_AUC=0.6867  random_test_AUC=0.6893  test_AUC_drop=0.0025
# LR_EN_C0.001_l10.1    temp_test_AUC=0.6863  random_test_AUC=0.6892  test_AUC_drop=0.0029
# LR_EN_C0.001_l10.3    temp_test_AUC=0.6859  random_test_AUC=0.6893  test_AUC_drop=0.0034
# LR_EN_C0.001_l10.05   temp_test_AUC=0.6855  random_test_AUC=0.6890  test_AUC_drop=0.0035
# LR_EN_C0.001_l10.7    temp_test_AUC=0.6834  random_test_AUC=0.6878  test_AUC_drop=0.0043
# LR_EN_C0.001_l10.5    temp_test_AUC=0.6834  random_test_AUC=0.6888  test_AUC_drop=0.0053
# LR_L2_C0.0001         temp_test_AUC=0.6824  random_test_AUC=0.6882  test_AUC_drop=0.0058
# LR_L1_C0.1            temp_test_AUC=0.6830  random_test_AUC=0.6892  test_AUC_drop=0.0062
# LR_L2_C0.001          temp_test_AUC=0.6827  random_test_AUC=0.6891  test_AUC_drop=0.0064
# LR_L2_C0.01           temp_test_AUC=0.6758  random_test_AUC=0.6889  test_AUC_drop=0.0130
# LR_L2_C0.1            temp_test_AUC=0.6694  random_test_AUC=0.6888  test_AUC_drop=0.0193
# LR_L1_C1              temp_test_AUC=0.6684  random_test_AUC=0.6888  test_AUC_drop=0.0203
# LR_EN_C0.01_l10.7     temp_test_AUC=0.6684  random_test_AUC=0.6888  test_AUC_drop=0.0203
# LR_EN_C0.01_l10.5     temp_test_AUC=0.6684  random_test_AUC=0.6888  test_AUC_drop=0.0204
# LR_EN_C0.01_l10.3     temp_test_AUC=0.6683  random_test_AUC=0.6887  test_AUC_drop=0.0204
# LR_L2_C1              temp_test_AUC=0.6681  random_test_AUC=0.6887  test_AUC_drop=0.0206
# LR_L1_C10             temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0207
# LR_L2_C10             temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0207
# LR_L1_C100            temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0208
# LR_L2_C100            temp_test_AUC=0.6680  random_test_AUC=0.6887  test_AUC_drop=0.0208
# LR_EN_C0.0001_l10.5   temp_test_AUC=0.5000  random_test_AUC=0.6804  test_AUC_drop=0.1804
# LR_EN_C0.0001_l10.7   temp_test_AUC=0.5000  random_test_AUC=0.6804  test_AUC_drop=0.1804
# LR_EN_C0.0001_l10.3   temp_test_AUC=0.5000  random_test_AUC=0.6841  test_AUC_drop=0.1841
# === Logistic Regression Selection Summary ===
# Best by temporal val AUC: LR_L2_C0.001
#   val_AUC=0.6858  test_AUC=0.6827  AUC_drop=0.0064
#
# Best by robustness (smallest AUC drop): LR_L1_C0.001
#   val_AUC=0.5000  test_AUC=0.5000  AUC_drop=0.0000
#
# Best balanced (val_AUC - AUC_drop): LR_EN_C0.001_l10.05
#   val_AUC=0.6851  test_AUC=0.6855  AUC_drop=0.0035

# %%
def objective_lr(trial):
    penalty = trial.suggest_categorical('penalty', ['l2', 'l1', 'elasticnet'])
    C = trial.suggest_float('C', 1e-4, 1e-2, log=True)

    if penalty == 'elasticnet':
        l1_ratio = trial.suggest_float('l1_ratio', 0.05, 0.3)
        solver = 'saga'
    elif penalty == 'l1':
        l1_ratio = None
        solver = 'liblinear'
    else:
        l1_ratio = None
        solver = 'liblinear'

    kwargs = dict(C=C, penalty=penalty, solver=solver, class_weight='balanced', max_iter=2000, random_state=42)
    if l1_ratio is not None:
        kwargs['l1_ratio'] = l1_ratio

    model = LogisticRegression(**kwargs)
    model.fit(X_train_t_sc, y_train_t)
    model_r = LogisticRegression(**kwargs)
    model_r.fit(X_rand_tr_sc, y_rand_tr)

    val_auc = roc_auc_score(y_val_t, model.predict_proba(X_val_t_sc)[:, 1])
    rand_auc = roc_auc_score(y_rand_val, model_r.predict_proba(X_rand_val_sc)[:, 1])
    auc_drop = rand_auc - val_auc

    y_prob_val = model.predict_proba(X_val_t_sc)[:, 1]
    thresholds = np.arange(0.05, 0.50, 0.01)
    best_thr = max(thresholds, key=lambda t: f1_score(y_val_t, (y_prob_val >= t).astype(int), zero_division=0))
    val_f1 = f1_score(y_val_t, (y_prob_val >= best_thr).astype(int), zero_division=0)

    return w_performance * val_auc - w_robustness * auc_drop + w_f1 * val_f1

study_lr = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_lr.optimize(objective_lr, n_trials=40, show_progress_bar=True)
# Out:
# [I 2026-05-07 02:46:11,058] A new study created in memory with name: no-name-87661157-81a6-47b2-afca-bffddc142baf
#   0%|          | 0/40 [00:00<?, ?it/s]
# [I 2026-05-07 02:46:11,698] Trial 0 finished with value: 0.2867444970265696 and parameters: {'penalty': 'l1', 'C': 0.0015751320499779737}. Best is trial 0 with value: 0.2867444970265696.
# [I 2026-05-07 02:46:12,394] Trial 1 finished with value: 0.29078489989253287 and parameters: {'penalty': 'l2', 'C': 0.005399484409787433}. Best is trial 1 with value: 0.29078489989253287.
# [I 2026-05-07 02:46:13,033] Trial 2 finished with value: 0.2917642307315148 and parameters: {'penalty': 'l1', 'C': 0.008706020878304856}. Best is trial 2 with value: 0.2917642307315148.
# [I 2026-05-07 02:46:13,668] Trial 3 finished with value: 0.28940529491410644 and parameters: {'penalty': 'l2', 'C': 0.00023270677083837802}. Best is trial 2 with value: 0.2917642307315148.
# [I 2026-05-07 02:46:14,120] Trial 4 finished with value: 0.2690753305862833 and parameters: {'penalty': 'l1', 'C': 0.0003823475224675188}. Best is trial 2 with value: 0.2917642307315148.
# [I 2026-05-07 02:46:14,765] Trial 5 finished with value: 0.2920508386652362 and parameters: {'penalty': 'l2', 'C': 0.0005404103854647331}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:15,306] Trial 6 finished with value: 0.2851763993181672 and parameters: {'penalty': 'l1', 'C': 0.0010677482709481358}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:16,339] Trial 7 finished with value: 0.29000308818011145 and parameters: {'penalty': 'elasticnet', 'C': 0.00021930485556643703, 'l1_ratio': 0.06626289824631988}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:16,814] Trial 8 finished with value: 0.27979095429405826 and parameters: {'penalty': 'l1', 'C': 0.0004066563313514797}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:17,259] Trial 9 finished with value: 0.1627279756756651 and parameters: {'penalty': 'l1', 'C': 0.00017541893487450815}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:17,933] Trial 10 finished with value: 0.2917419201483508 and parameters: {'penalty': 'l2', 'C': 0.002510441004250465}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:20,251] Trial 11 finished with value: 0.2907139002914625 and parameters: {'penalty': 'elasticnet', 'C': 0.008131735182005936, 'l1_ratio': 0.2927135207594267}. Best is trial 5 with value: 0.2920508386652362.
# [I 2026-05-07 02:46:21,230] Trial 12 finished with value: 0.29246133548918885 and parameters: {'penalty': 'l2', 'C': 0.0006683343962512113}. Best is trial 12 with value: 0.29246133548918885.
# [I 2026-05-07 02:46:22,167] Trial 13 finished with value: 0.2924655723085939 and parameters: {'penalty': 'l2', 'C': 0.0006040744069768636}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:23,093] Trial 14 finished with value: 0.29238089430387343 and parameters: {'penalty': 'l2', 'C': 0.0008426108147407058}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:24,130] Trial 15 finished with value: 0.2917345954618217 and parameters: {'penalty': 'l2', 'C': 0.0024664179064494297}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:26,104] Trial 16 finished with value: 0.2923144486020469 and parameters: {'penalty': 'l2', 'C': 0.0007739752543419447}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:26,726] Trial 17 finished with value: 0.2875114855540893 and parameters: {'penalty': 'l2', 'C': 0.00011854179084963979}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:27,877] Trial 18 finished with value: 0.2919061480715132 and parameters: {'penalty': 'elasticnet', 'C': 0.0013496874867614452, 'l1_ratio': 0.1984096673562442}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:28,557] Trial 19 finished with value: 0.2917837598040428 and parameters: {'penalty': 'l2', 'C': 0.0004913460742665327}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:29,231] Trial 20 finished with value: 0.2919483311288966 and parameters: {'penalty': 'l2', 'C': 0.002257543441890585}. Best is trial 13 with value: 0.2924655723085939.
# [I 2026-05-07 02:46:29,917] Trial 21 finished with value: 0.29263216553608906 and parameters: {'penalty': 'l2', 'C': 0.0007010478624133058}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:30,580] Trial 22 finished with value: 0.2924926116946635 and parameters: {'penalty': 'l2', 'C': 0.0006555862212388114}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:31,217] Trial 23 finished with value: 0.29082587640609076 and parameters: {'penalty': 'l2', 'C': 0.0003199023106097867}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:31,900] Trial 24 finished with value: 0.29212254852226827 and parameters: {'penalty': 'l2', 'C': 0.0011241509540645975}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:33,055] Trial 25 finished with value: 0.2919593274404258 and parameters: {'penalty': 'elasticnet', 'C': 0.0005990446019230447, 'l1_ratio': 0.07155905007004061}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:33,759] Trial 26 finished with value: 0.29228429621158203 and parameters: {'penalty': 'l2', 'C': 0.0015528384224945627}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:34,403] Trial 27 finished with value: 0.290194644189528 and parameters: {'penalty': 'l2', 'C': 0.0002838976958903096}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:35,106] Trial 28 finished with value: 0.2913547702784786 and parameters: {'penalty': 'l2', 'C': 0.00359271863830679}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:36,356] Trial 29 finished with value: 0.2912905017265164 and parameters: {'penalty': 'elasticnet', 'C': 0.0009345884130938793, 'l1_ratio': 0.2955389915274785}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:37,304] Trial 30 finished with value: 0.29211401098777157 and parameters: {'penalty': 'l2', 'C': 0.0018891881510946992}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:38,205] Trial 31 finished with value: 0.2924820707860423 and parameters: {'penalty': 'l2', 'C': 0.0006761526326214437}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:39,133] Trial 32 finished with value: 0.29153553437496676 and parameters: {'penalty': 'l2', 'C': 0.00046280460051526483}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:40,121] Trial 33 finished with value: 0.2925002122767365 and parameters: {'penalty': 'l2', 'C': 0.000720009401735713}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:41,203] Trial 34 finished with value: 0.2923127060315733 and parameters: {'penalty': 'l2', 'C': 0.0012688672264831579}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:42,271] Trial 35 finished with value: 0.2924522856827056 and parameters: {'penalty': 'l2', 'C': 0.0008130486010330941}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:43,196] Trial 36 finished with value: 0.2910145125641469 and parameters: {'penalty': 'l2', 'C': 0.0003575465936745701}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:43,682] Trial 37 finished with value: 0.28498015818491457 and parameters: {'penalty': 'l1', 'C': 0.0007013363115829801}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:44,363] Trial 38 finished with value: 0.29208910811955574 and parameters: {'penalty': 'l2', 'C': 0.0010465494593514372}. Best is trial 21 with value: 0.29263216553608906.
# [I 2026-05-07 02:46:44,818] Trial 39 finished with value: 0.16268170164948492 and parameters: {'penalty': 'l1', 'C': 0.00024103866722295379}. Best is trial 21 with value: 0.29263216553608906.

# %%
# ── best 10 => LR_MODEL_CONFIGS ──────────────────────────────
top_trials_lr = sorted(study_lr.trials, key=lambda t: t.value if t.value else -999, reverse=True)[:10]

LR_MODEL_CONFIGS = {}
for i, t in enumerate(top_trials_lr):
    name = f'LR_optuna_{i+1}'
    params = t.params.copy()
    penalty  = params.pop('penalty')
    C        = params.pop('C')
    l1_ratio = params.pop('l1_ratio', None)
    solver   = 'saga' if penalty == 'elasticnet' else 'liblinear'

    kwargs = dict(C=C, penalty=penalty, solver=solver, max_iter=2000, random_state=42)
    if l1_ratio is not None:
        kwargs['l1_ratio'] = l1_ratio

    LR_MODEL_CONFIGS[name] = (LogisticRegression(**kwargs), 'scaled')

# ── evaluation ────────────────────────────────────────────────
lr_results = evaluate_model_configs(LR_MODEL_CONFIGS)

# (val set)
print_selection_table(lr_results, sort_key='val_auc', reverse=True, title='LR - Val Set', mode='val')
print_selection_table(lr_results, sort_key='val_auc_drop', reverse=False, title='LR - Val Robustness', mode='val')
print_selection_table(lr_results, sort_key='val_recall', reverse=True, title='LR - Val Recall', mode='val')

# (test set)
print_selection_table(lr_results, sort_key='test_auc', reverse=True, title='LR - Test Set (Final)', mode='test')
print_selection_table(lr_results, sort_key='test_auc_drop', reverse=False, title='LR - Test Robustness (Final)', mode='test')
print_selection_table(lr_results, sort_key='recall', reverse=True, title='LR - Test Recall (Final)', mode='test')

# (best summary)
print_best_summary(lr_results, prefix='LR_', title='Logistic Regression Selection Summary')

# ── Hyperparameter print ──────────────────────────────────────
print_optuna_results(study_lr, top_trials_lr, title='LR Optuna Hyperparameter Results')
# Out:
# === LR - Val Set ===
# LR_optuna_1           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5876  val_Precision=0.2848  val_F1=0.3837  threshold=0.25
# LR_optuna_4           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6020  val_Precision=0.2804  val_F1=0.3826  threshold=0.25
# LR_optuna_6           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6075  val_Precision=0.2794  val_F1=0.3827  threshold=0.25
# LR_optuna_2           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5764  val_Precision=0.2871  val_F1=0.3833  threshold=0.25
# LR_optuna_3           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6162  val_Precision=0.2774  val_F1=0.3825  threshold=0.25
# LR_optuna_9           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.6148  val_Precision=0.2775  val_F1=0.3824  threshold=0.24
# LR_optuna_7           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5954  val_Precision=0.2820  val_F1=0.3827  threshold=0.24
# LR_optuna_5           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5838  val_Precision=0.2862  val_F1=0.3841  threshold=0.26
# LR_optuna_8           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5829  val_Precision=0.2856  val_F1=0.3834  threshold=0.24
# LR_optuna_10          temp_val_AUC=0.6856  rand_val_AUC=0.6879  val_AUC_drop=0.0023  val_Recall=0.5785  val_Precision=0.2856  val_F1=0.3824  threshold=0.22
#
# === LR - Val Robustness ===
# LR_optuna_3           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6162  val_Precision=0.2774  val_F1=0.3825  threshold=0.25
# LR_optuna_6           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6075  val_Precision=0.2794  val_F1=0.3827  threshold=0.25
# LR_optuna_4           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6020  val_Precision=0.2804  val_F1=0.3826  threshold=0.25
# LR_optuna_1           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5876  val_Precision=0.2848  val_F1=0.3837  threshold=0.25
# LR_optuna_2           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5764  val_Precision=0.2871  val_F1=0.3833  threshold=0.25
# LR_optuna_5           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5838  val_Precision=0.2862  val_F1=0.3841  threshold=0.26
# LR_optuna_9           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.6148  val_Precision=0.2775  val_F1=0.3824  threshold=0.24
# LR_optuna_7           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5954  val_Precision=0.2820  val_F1=0.3827  threshold=0.24
# LR_optuna_8           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5829  val_Precision=0.2856  val_F1=0.3834  threshold=0.24
# LR_optuna_10          temp_val_AUC=0.6856  rand_val_AUC=0.6879  val_AUC_drop=0.0023  val_Recall=0.5785  val_Precision=0.2856  val_F1=0.3824  threshold=0.22
#
# === LR - Val Recall ===
# LR_optuna_3           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6162  val_Precision=0.2774  val_F1=0.3825  threshold=0.25
# LR_optuna_9           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.6148  val_Precision=0.2775  val_F1=0.3824  threshold=0.24
# LR_optuna_6           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6075  val_Precision=0.2794  val_F1=0.3827  threshold=0.25
# LR_optuna_4           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6020  val_Precision=0.2804  val_F1=0.3826  threshold=0.25
# LR_optuna_7           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5954  val_Precision=0.2820  val_F1=0.3827  threshold=0.24
# LR_optuna_1           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5876  val_Precision=0.2848  val_F1=0.3837  threshold=0.25
# LR_optuna_5           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5838  val_Precision=0.2862  val_F1=0.3841  threshold=0.26
# LR_optuna_8           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5829  val_Precision=0.2856  val_F1=0.3834  threshold=0.24
# LR_optuna_10          temp_val_AUC=0.6856  rand_val_AUC=0.6879  val_AUC_drop=0.0023  val_Recall=0.5785  val_Precision=0.2856  val_F1=0.3824  threshold=0.22
# LR_optuna_2           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5764  val_Precision=0.2871  val_F1=0.3833  threshold=0.25
#
# === LR - Test Set (Final) ===
# LR_optuna_5           temp_test_AUC=0.6834  random_test_AUC=0.6891  test_AUC_drop=0.0057  Recall=0.5713  Precision=0.1409  F1=0.2261  threshold=0.26
# LR_optuna_3           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.6048  Precision=0.1381  F1=0.2249  threshold=0.25
# LR_optuna_6           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5959  Precision=0.1387  F1=0.2250  threshold=0.25
# LR_optuna_4           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5905  Precision=0.1390  F1=0.2251  threshold=0.25
# LR_optuna_1           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5757  Precision=0.1404  F1=0.2257  threshold=0.25
# LR_optuna_2           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5659  Precision=0.1415  F1=0.2264  threshold=0.25
# LR_optuna_9           temp_test_AUC=0.6831  random_test_AUC=0.6891  test_AUC_drop=0.0060  Recall=0.6040  Precision=0.1380  F1=0.2247  threshold=0.24
# LR_optuna_7           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5846  Precision=0.1395  F1=0.2253  threshold=0.24
# LR_optuna_8           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5712  Precision=0.1406  F1=0.2256  threshold=0.24
# LR_optuna_10          temp_test_AUC=0.6823  random_test_AUC=0.6891  test_AUC_drop=0.0068  Recall=0.5694  Precision=0.1407  F1=0.2256  threshold=0.22
#
# === LR - Test Robustness (Final) ===
# LR_optuna_5           temp_test_AUC=0.6834  random_test_AUC=0.6891  test_AUC_drop=0.0057  Recall=0.5713  Precision=0.1409  F1=0.2261  threshold=0.26
# LR_optuna_3           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.6048  Precision=0.1381  F1=0.2249  threshold=0.25
# LR_optuna_6           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5959  Precision=0.1387  F1=0.2250  threshold=0.25
# LR_optuna_4           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5905  Precision=0.1390  F1=0.2251  threshold=0.25
# LR_optuna_1           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5757  Precision=0.1404  F1=0.2257  threshold=0.25
# LR_optuna_2           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5659  Precision=0.1415  F1=0.2264  threshold=0.25
# LR_optuna_9           temp_test_AUC=0.6831  random_test_AUC=0.6891  test_AUC_drop=0.0060  Recall=0.6040  Precision=0.1380  F1=0.2247  threshold=0.24
# LR_optuna_7           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5846  Precision=0.1395  F1=0.2253  threshold=0.24
# LR_optuna_8           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5712  Precision=0.1406  F1=0.2256  threshold=0.24
# LR_optuna_10          temp_test_AUC=0.6823  random_test_AUC=0.6891  test_AUC_drop=0.0068  Recall=0.5694  Precision=0.1407  F1=0.2256  threshold=0.22
#
# === LR - Test Recall (Final) ===
# LR_optuna_3           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.6048  Precision=0.1381  F1=0.2249  threshold=0.25
# LR_optuna_9           temp_test_AUC=0.6831  random_test_AUC=0.6891  test_AUC_drop=0.0060  Recall=0.6040  Precision=0.1380  F1=0.2247  threshold=0.24
# LR_optuna_6           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5959  Precision=0.1387  F1=0.2250  threshold=0.25
# LR_optuna_4           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5905  Precision=0.1390  F1=0.2251  threshold=0.25
# LR_optuna_7           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5846  Precision=0.1395  F1=0.2253  threshold=0.24
# LR_optuna_1           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5757  Precision=0.1404  F1=0.2257  threshold=0.25
# LR_optuna_5           temp_test_AUC=0.6834  random_test_AUC=0.6891  test_AUC_drop=0.0057  Recall=0.5713  Precision=0.1409  F1=0.2261  threshold=0.26
# LR_optuna_8           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5712  Precision=0.1406  F1=0.2256  threshold=0.24
# LR_optuna_10          temp_test_AUC=0.6823  random_test_AUC=0.6891  test_AUC_drop=0.0068  Recall=0.5694  Precision=0.1407  F1=0.2256  threshold=0.22
# LR_optuna_2           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5659  Precision=0.1415  F1=0.2264  threshold=0.25
# === Logistic Regression Selection Summary ===
# Best by temporal val AUC: LR_optuna_1
#   val_AUC=0.6859  test_AUC=0.6832  AUC_drop=0.0059
#
# Best by robustness (smallest AUC drop): LR_optuna_5
#   val_AUC=0.6858  test_AUC=0.6834  AUC_drop=0.0057
#
# Best balanced (val_AUC - AUC_drop): LR_optuna_5
#   val_AUC=0.6858  test_AUC=0.6834  AUC_drop=0.0057
#
# === LR Optuna Hyperparameter Results ===
# Best score: 0.2926
#
# Best params:
#   penalty             : l2
#   C                   : 0.0007010478624133058
#
# === Top 10 Trials ===
#
# [1] score=0.2926
#   penalty             : l2
#   C                   : 0.0007010478624133058
#
# [2] score=0.2925
#   penalty             : l2
#   C                   : 0.000720009401735713
#
# [3] score=0.2925
#   penalty             : l2
#   C                   : 0.0006555862212388114
#
# [4] score=0.2925
#   penalty             : l2
#   C                   : 0.0006761526326214437
#
# [5] score=0.2925
#   penalty             : l2
#   C                   : 0.0006040744069768636
#
# [6] score=0.2925
#   penalty             : l2
#   C                   : 0.0006683343962512113
#
# [7] score=0.2925
#   penalty             : l2
#   C                   : 0.0008130486010330941
#
# [8] score=0.2924
#   penalty             : l2
#   C                   : 0.0008426108147407058
#
# [9] score=0.2923
#   penalty             : l2
#   C                   : 0.0007739752543419447
#
# [10] score=0.2923
#   penalty             : l2
#   C                   : 0.0012688672264831579

# %% [markdown]
# ## Decision Tree Test Code (Find Best)

# %%
DT_MODEL_CONFIGS = {
    # 1) max_depth sweep
    # 'DTree_d3':   (DecisionTreeClassifier(max_depth=3,  random_state=42), 'raw'),
    # 'DTree_d4':   (DecisionTreeClassifier(max_depth=4,  random_state=42), 'raw'),
    # 'DTree_d5':   (DecisionTreeClassifier(max_depth=5,  random_state=42), 'raw'),
    # 'DTree_d7':   (DecisionTreeClassifier(max_depth=7,  random_state=42), 'raw'),
    # 'DTree_d10':  (DecisionTreeClassifier(max_depth=10, random_state=42), 'raw'),

    'DTree_d3':           (DecisionTreeClassifier(max_depth=3,  random_state=42), 'raw'),
    'DTree_d3_ent':       (DecisionTreeClassifier(max_depth=3,  criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_bal':       (DecisionTreeClassifier(max_depth=3,  class_weight='balanced', random_state=42), 'raw'),

    'DTree_d4':           (DecisionTreeClassifier(max_depth=4,  random_state=42), 'raw'),
    'DTree_d4_ent':       (DecisionTreeClassifier(max_depth=4,  criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_bal':       (DecisionTreeClassifier(max_depth=4,  class_weight='balanced', random_state=42), 'raw'),

    'DTree_d5':           (DecisionTreeClassifier(max_depth=5,  random_state=42), 'raw'),
    'DTree_d5_ent':       (DecisionTreeClassifier(max_depth=5,  criterion='entropy', random_state=42), 'raw'),
    'DTree_d5_bal':       (DecisionTreeClassifier(max_depth=5,  class_weight='balanced', random_state=42), 'raw'),

    'DTree_d7':           (DecisionTreeClassifier(max_depth=7,  random_state=42), 'raw'),
    'DTree_d7_ent':       (DecisionTreeClassifier(max_depth=7,  criterion='entropy', random_state=42), 'raw'),
    'DTree_d7_bal':       (DecisionTreeClassifier(max_depth=7,  class_weight='balanced', random_state=42), 'raw'),

    'DTree_d10':          (DecisionTreeClassifier(max_depth=10, random_state=42), 'raw'),
    'DTree_d10_ent':      (DecisionTreeClassifier(max_depth=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d10_bal':      (DecisionTreeClassifier(max_depth=10, class_weight='balanced', random_state=42), 'raw'),

    # 2) min_samples_leaf sweep (d3, d5, d7 각각)
    'DTree_d3_leaf5':   (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  random_state=42), 'raw'),
    'DTree_d3_leaf20':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, random_state=42), 'raw'),
    'DTree_d3_leaf50':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, random_state=42), 'raw'),
    'DTree_d5_leaf5':   (DecisionTreeClassifier(max_depth=5, min_samples_leaf=5,  random_state=42), 'raw'),
    'DTree_d5_leaf20':  (DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, random_state=42), 'raw'),
    'DTree_d5_leaf50':  (DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, random_state=42), 'raw'),
    'DTree_d7_leaf5':   (DecisionTreeClassifier(max_depth=7, min_samples_leaf=5,  random_state=42), 'raw'),
    'DTree_d7_leaf20':  (DecisionTreeClassifier(max_depth=7, min_samples_leaf=20, random_state=42), 'raw'),
    'DTree_d7_leaf50':  (DecisionTreeClassifier(max_depth=7, min_samples_leaf=50, random_state=42), 'raw'),

    # # 3) min_samples_split sweep (d3, d5, d7 각각)
    # 'DTree_d3_split10':  (DecisionTreeClassifier(max_depth=3, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d3_split20':  (DecisionTreeClassifier(max_depth=3, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d3_split50':  (DecisionTreeClassifier(max_depth=3, min_samples_split=50, random_state=42), 'raw'),
    # 'DTree_d5_split10':  (DecisionTreeClassifier(max_depth=5, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d5_split20':  (DecisionTreeClassifier(max_depth=5, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d5_split50':  (DecisionTreeClassifier(max_depth=5, min_samples_split=50, random_state=42), 'raw'),
    # 'DTree_d7_split10':  (DecisionTreeClassifier(max_depth=7, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d7_split20':  (DecisionTreeClassifier(max_depth=7, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d7_split50':  (DecisionTreeClassifier(max_depth=7, min_samples_split=50, random_state=42), 'raw'),

    # depth=3, leaf=5
    'DTree_d3_leaf5_split10':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=10, random_state=42), 'raw'),
    'DTree_d3_leaf5_split20':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    'DTree_d3_leaf5_split50':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=50, random_state=42), 'raw'),

    # depth=3, leaf=20
    'DTree_d3_leaf20_split10': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=10, random_state=42), 'raw'),
    'DTree_d3_leaf20_split20': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=20, random_state=42), 'raw'),
    'DTree_d3_leaf20_split50': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),

    # depth=3, leaf=50
    'DTree_d3_leaf50_split10': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=10, random_state=42), 'raw'),
    'DTree_d3_leaf50_split20': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=20, random_state=42), 'raw'),
    'DTree_d3_leaf50_split50': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=50, random_state=42), 'raw'),

    # depth=4, leaf=5
    'DTree_d4_leaf5_split10':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=10, random_state=42), 'raw'),
    'DTree_d4_leaf5_split20':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    'DTree_d4_leaf5_split50':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=50, random_state=42), 'raw'),

    # depth=4, leaf=20
    'DTree_d4_leaf20_split10': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=10, random_state=42), 'raw'),
    'DTree_d4_leaf20_split20': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=20, random_state=42), 'raw'),
    'DTree_d4_leaf20_split50': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),

    # depth=4, leaf=50
    'DTree_d4_leaf50_split10': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=10, random_state=42), 'raw'),
    'DTree_d4_leaf50_split20': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=20, random_state=42), 'raw'),
    'DTree_d4_leaf50_split50': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=50, random_state=42), 'raw'),

    # # depth=5, leaf=5
    # 'DTree_d5_leaf5_split10':  (DecisionTreeClassifier(max_depth=5, min_samples_leaf=5,  min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d5_leaf5_split20':  (DecisionTreeClassifier(max_depth=5, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d5_leaf5_split50':  (DecisionTreeClassifier(max_depth=5, min_samples_leaf=5,  min_samples_split=50, random_state=42), 'raw'),

    # # depth=5, leaf=20
    # 'DTree_d5_leaf20_split10': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d5_leaf20_split20': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d5_leaf20_split50': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),

    # # depth=5, leaf=50
    # 'DTree_d5_leaf50_split10': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d5_leaf50_split20': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d5_leaf50_split50': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, min_samples_split=50, random_state=42), 'raw'),

    # # depth=6, leaf=5
    # 'DTree_d6_leaf5_split10':  (DecisionTreeClassifier(max_depth=6, min_samples_leaf=5,  min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d6_leaf5_split20':  (DecisionTreeClassifier(max_depth=6, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d6_leaf5_split50':  (DecisionTreeClassifier(max_depth=6, min_samples_leaf=5,  min_samples_split=50, random_state=42), 'raw'),

    # # depth=6, leaf=20
    # 'DTree_d6_leaf20_split10': (DecisionTreeClassifier(max_depth=6, min_samples_leaf=20, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d6_leaf20_split20': (DecisionTreeClassifier(max_depth=6, min_samples_leaf=20, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d6_leaf20_split50': (DecisionTreeClassifier(max_depth=6, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),

    # # depth=6, leaf=50
    # 'DTree_d6_leaf50_split10': (DecisionTreeClassifier(max_depth=6, min_samples_leaf=50, min_samples_split=10, random_state=42), 'raw'),
    # 'DTree_d6_leaf50_split20': (DecisionTreeClassifier(max_depth=6, min_samples_leaf=50, min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d6_leaf50_split50': (DecisionTreeClassifier(max_depth=6, min_samples_leaf=50, min_samples_split=50, random_state=42), 'raw'),

    # depth=3, entropy
    'DTree_d3_leaf5_split10_ent':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf5_split20_ent':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=20, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf5_split50_ent':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=50, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf20_split10_ent': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf20_split20_ent': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=20, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf20_split50_ent': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=50, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf50_split10_ent': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf50_split20_ent': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=20, criterion='entropy', random_state=42), 'raw'),
    'DTree_d3_leaf50_split50_ent': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=50, criterion='entropy', random_state=42), 'raw'),

    # depth=3, balanced
    'DTree_d3_leaf5_split10_bal':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=10, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf5_split20_bal':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=20, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf5_split50_bal':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=50, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf20_split10_bal': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=10, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf20_split20_bal': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=20, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf20_split50_bal': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=50, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf50_split10_bal': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=10, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf50_split20_bal': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=20, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d3_leaf50_split50_bal': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=50, min_samples_split=50, class_weight='balanced', random_state=42), 'raw'),

    # depth=4, entropy
    'DTree_d4_leaf5_split10_ent':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf5_split20_ent':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=20, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf5_split50_ent':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=50, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf20_split10_ent': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf20_split20_ent': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=20, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf20_split50_ent': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=50, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf50_split10_ent': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=10, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf50_split20_ent': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=20, criterion='entropy', random_state=42), 'raw'),
    'DTree_d4_leaf50_split50_ent': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=50, criterion='entropy', random_state=42), 'raw'),

    # depth=4, balanced
    'DTree_d4_leaf5_split10_bal':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=10, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf5_split20_bal':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=20, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf5_split50_bal':  (DecisionTreeClassifier(max_depth=4, min_samples_leaf=5,  min_samples_split=50, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf20_split10_bal': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=10, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf20_split20_bal': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=20, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf20_split50_bal': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=20, min_samples_split=50, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf50_split10_bal': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=10, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf50_split20_bal': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=20, class_weight='balanced', random_state=42), 'raw'),
    'DTree_d4_leaf50_split50_bal': (DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, min_samples_split=50, class_weight='balanced', random_state=42), 'raw'),

    # # 6) combo (leaf + split + d3, d5, d7 각각)
    # 'DTree_d3_leaf5_split20':  (DecisionTreeClassifier(max_depth=3, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d3_leaf20_split50': (DecisionTreeClassifier(max_depth=3, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),
    # 'DTree_d5_leaf5_split20':  (DecisionTreeClassifier(max_depth=5, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d5_leaf20_split50': (DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),
    # 'DTree_d7_leaf5_split20':  (DecisionTreeClassifier(max_depth=7, min_samples_leaf=5,  min_samples_split=20, random_state=42), 'raw'),
    # 'DTree_d7_leaf20_split50': (DecisionTreeClassifier(max_depth=7, min_samples_leaf=20, min_samples_split=50, random_state=42), 'raw'),
}

print(f'Total DT model configs: {len(DT_MODEL_CONFIGS)}')
# Out:
# Total DT model configs: 78

# %%
# dt_results = evaluate_model_configs(DT_MODEL_CONFIGS)

# # (val set)
# print_selection_table(dt_results, sort_key='val_auc', reverse=True, title='DT - Val Set', mode='val')
# print_selection_table(dt_results, sort_key='val_auc_drop', reverse=False, title='DT - Val Robustness', mode='val')

# # (test set)
# print_selection_table(dt_results, sort_key='test_auc', reverse=True, title='DT - Test Set (Final)', mode='test')
# print_selection_table(dt_results, sort_key='test_auc_drop', reverse=False, title='DT - Test Robustness (Final)', mode='test')

# # (best summary)
# print_best_summary(dt_results, prefix='DTree_', title='Decision Tree Selection Summary')
# Out:
# === DT - Val Set ===
# DTree_d4              temp_val_AUC=0.6719  rand_val_AUC=0.6874  val_AUC_drop=0.0155
# DTree_d4_leaf5_split10  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf5_split20  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf5_split50  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf20_split10  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf20_split20  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf20_split50  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf50_split10  temp_val_AUC=0.6717  rand_val_AUC=0.6873  val_AUC_drop=0.0156
# DTree_d4_leaf50_split20  temp_val_AUC=0.6717  rand_val_AUC=0.6873  val_AUC_drop=0.0156
# DTree_d4_leaf50_split50  temp_val_AUC=0.6717  rand_val_AUC=0.6873  val_AUC_drop=0.0156
# DTree_d3_bal          temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf5_split10_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf5_split20_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf5_split50_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf20_split10_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf20_split20_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf20_split50_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf50_split10_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf50_split20_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf50_split50_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d4_leaf50_split10_ent  temp_val_AUC=0.6700  rand_val_AUC=0.6849  val_AUC_drop=0.0149
# DTree_d4_leaf50_split20_ent  temp_val_AUC=0.6700  rand_val_AUC=0.6849  val_AUC_drop=0.0149
# DTree_d4_leaf50_split50_ent  temp_val_AUC=0.6700  rand_val_AUC=0.6849  val_AUC_drop=0.0149
# DTree_d4_leaf20_split10_ent  temp_val_AUC=0.6690  rand_val_AUC=0.6849  val_AUC_drop=0.0160
# DTree_d4_leaf20_split20_ent  temp_val_AUC=0.6690  rand_val_AUC=0.6849  val_AUC_drop=0.0160
# DTree_d4_leaf20_split50_ent  temp_val_AUC=0.6690  rand_val_AUC=0.6849  val_AUC_drop=0.0160
# DTree_d3              temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5        temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20       temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50       temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5_split10  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5_split20  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5_split50  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20_split10  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20_split20  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20_split50  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50_split10  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50_split20  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50_split50  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d4_leaf50_split10_bal  temp_val_AUC=0.6679  rand_val_AUC=0.6848  val_AUC_drop=0.0169
# DTree_d4_leaf50_split20_bal  temp_val_AUC=0.6679  rand_val_AUC=0.6848  val_AUC_drop=0.0169
# DTree_d4_leaf50_split50_bal  temp_val_AUC=0.6679  rand_val_AUC=0.6848  val_AUC_drop=0.0169
# DTree_d4_ent          temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf5_split10_ent  temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf5_split20_ent  temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf5_split50_ent  temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf20_split10_bal  temp_val_AUC=0.6670  rand_val_AUC=0.6848  val_AUC_drop=0.0178
# DTree_d4_leaf20_split20_bal  temp_val_AUC=0.6670  rand_val_AUC=0.6848  val_AUC_drop=0.0178
# DTree_d4_leaf20_split50_bal  temp_val_AUC=0.6670  rand_val_AUC=0.6848  val_AUC_drop=0.0178
# DTree_d5_leaf20       temp_val_AUC=0.6670  rand_val_AUC=0.6951  val_AUC_drop=0.0281
# DTree_d5_leaf50       temp_val_AUC=0.6669  rand_val_AUC=0.6952  val_AUC_drop=0.0282
# DTree_d5_leaf5        temp_val_AUC=0.6668  rand_val_AUC=0.6952  val_AUC_drop=0.0284
# DTree_d5_ent          temp_val_AUC=0.6663  rand_val_AUC=0.6875  val_AUC_drop=0.0212
# DTree_d4_bal          temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d4_leaf5_split10_bal  temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d4_leaf5_split20_bal  temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d4_leaf5_split50_bal  temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d3_ent          temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf5_split10_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf5_split20_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf5_split50_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf20_split10_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf20_split20_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf20_split50_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf50_split10_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf50_split20_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf50_split50_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d5              temp_val_AUC=0.6657  rand_val_AUC=0.6952  val_AUC_drop=0.0294
# DTree_d5_bal          temp_val_AUC=0.6616  rand_val_AUC=0.6885  val_AUC_drop=0.0268
# DTree_d7_ent          temp_val_AUC=0.6566  rand_val_AUC=0.6923  val_AUC_drop=0.0357
# DTree_d7_leaf5        temp_val_AUC=0.6530  rand_val_AUC=0.6946  val_AUC_drop=0.0416
# DTree_d7_leaf50       temp_val_AUC=0.6525  rand_val_AUC=0.6944  val_AUC_drop=0.0419
# DTree_d7_leaf20       temp_val_AUC=0.6518  rand_val_AUC=0.6941  val_AUC_drop=0.0423
# DTree_d7              temp_val_AUC=0.6510  rand_val_AUC=0.6949  val_AUC_drop=0.0440
# DTree_d7_bal          temp_val_AUC=0.6480  rand_val_AUC=0.6929  val_AUC_drop=0.0448
# DTree_d10             temp_val_AUC=0.6324  rand_val_AUC=0.6896  val_AUC_drop=0.0573
# DTree_d10_ent         temp_val_AUC=0.6291  rand_val_AUC=0.6870  val_AUC_drop=0.0578
# DTree_d10_bal         temp_val_AUC=0.6133  rand_val_AUC=0.6828  val_AUC_drop=0.0694
#
# === DT - Val Robustness ===
# DTree_d3_bal          temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf5_split10_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf5_split20_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf5_split50_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf20_split10_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf20_split20_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf20_split50_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf50_split10_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf50_split20_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_leaf50_split50_bal  temp_val_AUC=0.6706  rand_val_AUC=0.6795  val_AUC_drop=0.0090
# DTree_d3_ent          temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf5_split10_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf5_split20_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf5_split50_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf20_split10_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf20_split20_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf20_split50_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf50_split10_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf50_split20_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d3_leaf50_split50_ent  temp_val_AUC=0.6660  rand_val_AUC=0.6795  val_AUC_drop=0.0136
# DTree_d4_leaf50_split10_ent  temp_val_AUC=0.6700  rand_val_AUC=0.6849  val_AUC_drop=0.0149
# DTree_d4_leaf50_split20_ent  temp_val_AUC=0.6700  rand_val_AUC=0.6849  val_AUC_drop=0.0149
# DTree_d4_leaf50_split50_ent  temp_val_AUC=0.6700  rand_val_AUC=0.6849  val_AUC_drop=0.0149
# DTree_d4_leaf5_split10  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf5_split20  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf5_split50  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf20_split10  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf20_split20  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4_leaf20_split50  temp_val_AUC=0.6719  rand_val_AUC=0.6873  val_AUC_drop=0.0154
# DTree_d4              temp_val_AUC=0.6719  rand_val_AUC=0.6874  val_AUC_drop=0.0155
# DTree_d4_leaf50_split10  temp_val_AUC=0.6717  rand_val_AUC=0.6873  val_AUC_drop=0.0156
# DTree_d4_leaf50_split20  temp_val_AUC=0.6717  rand_val_AUC=0.6873  val_AUC_drop=0.0156
# DTree_d4_leaf50_split50  temp_val_AUC=0.6717  rand_val_AUC=0.6873  val_AUC_drop=0.0156
# DTree_d3              temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5        temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20       temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50       temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5_split10  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5_split20  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf5_split50  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20_split10  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20_split20  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf20_split50  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50_split10  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50_split20  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d3_leaf50_split50  temp_val_AUC=0.6686  rand_val_AUC=0.6845  val_AUC_drop=0.0159
# DTree_d4_leaf20_split10_ent  temp_val_AUC=0.6690  rand_val_AUC=0.6849  val_AUC_drop=0.0160
# DTree_d4_leaf20_split20_ent  temp_val_AUC=0.6690  rand_val_AUC=0.6849  val_AUC_drop=0.0160
# DTree_d4_leaf20_split50_ent  temp_val_AUC=0.6690  rand_val_AUC=0.6849  val_AUC_drop=0.0160
# DTree_d4_leaf50_split10_bal  temp_val_AUC=0.6679  rand_val_AUC=0.6848  val_AUC_drop=0.0169
# DTree_d4_leaf50_split20_bal  temp_val_AUC=0.6679  rand_val_AUC=0.6848  val_AUC_drop=0.0169
# DTree_d4_leaf50_split50_bal  temp_val_AUC=0.6679  rand_val_AUC=0.6848  val_AUC_drop=0.0169
# DTree_d4_ent          temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf5_split10_ent  temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf5_split20_ent  temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf5_split50_ent  temp_val_AUC=0.6679  rand_val_AUC=0.6849  val_AUC_drop=0.0170
# DTree_d4_leaf20_split10_bal  temp_val_AUC=0.6670  rand_val_AUC=0.6848  val_AUC_drop=0.0178
# DTree_d4_leaf20_split20_bal  temp_val_AUC=0.6670  rand_val_AUC=0.6848  val_AUC_drop=0.0178
# DTree_d4_leaf20_split50_bal  temp_val_AUC=0.6670  rand_val_AUC=0.6848  val_AUC_drop=0.0178
# DTree_d4_bal          temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d4_leaf5_split10_bal  temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d4_leaf5_split20_bal  temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d4_leaf5_split50_bal  temp_val_AUC=0.6660  rand_val_AUC=0.6848  val_AUC_drop=0.0188
# DTree_d5_ent          temp_val_AUC=0.6663  rand_val_AUC=0.6875  val_AUC_drop=0.0212
# DTree_d5_bal          temp_val_AUC=0.6616  rand_val_AUC=0.6885  val_AUC_drop=0.0268
# DTree_d5_leaf20       temp_val_AUC=0.6670  rand_val_AUC=0.6951  val_AUC_drop=0.0281
# DTree_d5_leaf50       temp_val_AUC=0.6669  rand_val_AUC=0.6952  val_AUC_drop=0.0282
# DTree_d5_leaf5        temp_val_AUC=0.6668  rand_val_AUC=0.6952  val_AUC_drop=0.0284
# DTree_d5              temp_val_AUC=0.6657  rand_val_AUC=0.6952  val_AUC_drop=0.0294
# DTree_d7_ent          temp_val_AUC=0.6566  rand_val_AUC=0.6923  val_AUC_drop=0.0357
# DTree_d7_leaf5        temp_val_AUC=0.6530  rand_val_AUC=0.6946  val_AUC_drop=0.0416
# DTree_d7_leaf50       temp_val_AUC=0.6525  rand_val_AUC=0.6944  val_AUC_drop=0.0419
# DTree_d7_leaf20       temp_val_AUC=0.6518  rand_val_AUC=0.6941  val_AUC_drop=0.0423
# DTree_d7              temp_val_AUC=0.6510  rand_val_AUC=0.6949  val_AUC_drop=0.0440
# DTree_d7_bal          temp_val_AUC=0.6480  rand_val_AUC=0.6929  val_AUC_drop=0.0448
# DTree_d10             temp_val_AUC=0.6324  rand_val_AUC=0.6896  val_AUC_drop=0.0573
# DTree_d10_ent         temp_val_AUC=0.6291  rand_val_AUC=0.6870  val_AUC_drop=0.0578
# DTree_d10_bal         temp_val_AUC=0.6133  rand_val_AUC=0.6828  val_AUC_drop=0.0694
#
# === DT - Test Set (Final) ===
# DTree_d3              temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5        temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20       temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50       temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5_split10  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5_split20  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5_split50  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20_split10  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20_split20  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20_split50  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50_split10  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50_split20  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50_split50  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d4              temp_test_AUC=0.6715  random_test_AUC=0.6926  test_AUC_drop=0.0211
# DTree_d4_leaf5_split10  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf5_split20  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf5_split50  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf20_split10  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf20_split20  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf20_split50  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf50_split10  temp_test_AUC=0.6712  random_test_AUC=0.6926  test_AUC_drop=0.0213
# DTree_d4_leaf50_split20  temp_test_AUC=0.6712  random_test_AUC=0.6926  test_AUC_drop=0.0213
# DTree_d4_leaf50_split50  temp_test_AUC=0.6712  random_test_AUC=0.6926  test_AUC_drop=0.0213
# DTree_d4_ent          temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf5_split10_ent  temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf5_split20_ent  temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf5_split50_ent  temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf20_split10_ent  temp_test_AUC=0.6685  random_test_AUC=0.6879  test_AUC_drop=0.0194
# DTree_d4_leaf20_split20_ent  temp_test_AUC=0.6685  random_test_AUC=0.6879  test_AUC_drop=0.0194
# DTree_d4_leaf20_split50_ent  temp_test_AUC=0.6685  random_test_AUC=0.6879  test_AUC_drop=0.0194
# DTree_d3_bal          temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf5_split10_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf5_split20_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf5_split50_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf20_split10_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf20_split20_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf20_split50_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf50_split10_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf50_split20_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf50_split50_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d4_leaf20_split10_bal  temp_test_AUC=0.6666  random_test_AUC=0.6879  test_AUC_drop=0.0213
# DTree_d4_leaf20_split20_bal  temp_test_AUC=0.6666  random_test_AUC=0.6879  test_AUC_drop=0.0213
# DTree_d4_leaf20_split50_bal  temp_test_AUC=0.6666  random_test_AUC=0.6879  test_AUC_drop=0.0213
# DTree_d5_leaf5        temp_test_AUC=0.6665  random_test_AUC=0.7004  test_AUC_drop=0.0338
# DTree_d5_leaf20       temp_test_AUC=0.6663  random_test_AUC=0.7004  test_AUC_drop=0.0341
# DTree_d4_bal          temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf5_split10_bal  temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf5_split20_bal  temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf5_split50_bal  temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf50_split10_ent  temp_test_AUC=0.6659  random_test_AUC=0.6879  test_AUC_drop=0.0220
# DTree_d4_leaf50_split20_ent  temp_test_AUC=0.6659  random_test_AUC=0.6879  test_AUC_drop=0.0220
# DTree_d4_leaf50_split50_ent  temp_test_AUC=0.6659  random_test_AUC=0.6879  test_AUC_drop=0.0220
# DTree_d5_leaf50       temp_test_AUC=0.6657  random_test_AUC=0.7004  test_AUC_drop=0.0347
# DTree_d4_leaf50_split10_bal  temp_test_AUC=0.6655  random_test_AUC=0.6879  test_AUC_drop=0.0224
# DTree_d4_leaf50_split20_bal  temp_test_AUC=0.6655  random_test_AUC=0.6879  test_AUC_drop=0.0224
# DTree_d4_leaf50_split50_bal  temp_test_AUC=0.6655  random_test_AUC=0.6879  test_AUC_drop=0.0224
# DTree_d5_ent          temp_test_AUC=0.6640  random_test_AUC=0.6930  test_AUC_drop=0.0290
# DTree_d3_ent          temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf5_split10_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf5_split20_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf5_split50_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf20_split10_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf20_split20_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf20_split50_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf50_split10_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf50_split20_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf50_split50_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d5              temp_test_AUC=0.6637  random_test_AUC=0.7004  test_AUC_drop=0.0367
# DTree_d5_bal          temp_test_AUC=0.6568  random_test_AUC=0.6933  test_AUC_drop=0.0365
# DTree_d7_ent          temp_test_AUC=0.6497  random_test_AUC=0.6974  test_AUC_drop=0.0477
# DTree_d7_leaf50       temp_test_AUC=0.6494  random_test_AUC=0.7012  test_AUC_drop=0.0518
# DTree_d7_leaf20       temp_test_AUC=0.6447  random_test_AUC=0.7021  test_AUC_drop=0.0574
# DTree_d7_leaf5        temp_test_AUC=0.6445  random_test_AUC=0.7024  test_AUC_drop=0.0579
# DTree_d7              temp_test_AUC=0.6376  random_test_AUC=0.7024  test_AUC_drop=0.0648
# DTree_d7_bal          temp_test_AUC=0.6341  random_test_AUC=0.6951  test_AUC_drop=0.0610
# DTree_d10             temp_test_AUC=0.6158  random_test_AUC=0.6965  test_AUC_drop=0.0807
# DTree_d10_ent         temp_test_AUC=0.6128  random_test_AUC=0.6903  test_AUC_drop=0.0774
# DTree_d10_bal         temp_test_AUC=0.5981  random_test_AUC=0.6850  test_AUC_drop=0.0868
#
# === DT - Test Robustness (Final) ===
# DTree_d3              temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5        temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20       temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50       temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5_split10  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5_split20  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf5_split50  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20_split10  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20_split20  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf20_split50  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50_split10  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50_split20  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_leaf50_split50  temp_test_AUC=0.6723  random_test_AUC=0.6861  test_AUC_drop=0.0138
# DTree_d3_bal          temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf5_split10_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf5_split20_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf5_split50_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf20_split10_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf20_split20_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf20_split50_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf50_split10_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf50_split20_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_leaf50_split50_bal  temp_test_AUC=0.6685  random_test_AUC=0.6828  test_AUC_drop=0.0143
# DTree_d3_ent          temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf5_split10_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf5_split20_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf5_split50_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf20_split10_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf20_split20_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf20_split50_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf50_split10_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf50_split20_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d3_leaf50_split50_ent  temp_test_AUC=0.6640  random_test_AUC=0.6828  test_AUC_drop=0.0188
# DTree_d4_ent          temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf5_split10_ent  temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf5_split20_ent  temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf5_split50_ent  temp_test_AUC=0.6690  random_test_AUC=0.6879  test_AUC_drop=0.0189
# DTree_d4_leaf20_split10_ent  temp_test_AUC=0.6685  random_test_AUC=0.6879  test_AUC_drop=0.0194
# DTree_d4_leaf20_split20_ent  temp_test_AUC=0.6685  random_test_AUC=0.6879  test_AUC_drop=0.0194
# DTree_d4_leaf20_split50_ent  temp_test_AUC=0.6685  random_test_AUC=0.6879  test_AUC_drop=0.0194
# DTree_d4_leaf5_split10  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf5_split20  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf5_split50  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf20_split10  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf20_split20  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4_leaf20_split50  temp_test_AUC=0.6715  random_test_AUC=0.6925  test_AUC_drop=0.0210
# DTree_d4              temp_test_AUC=0.6715  random_test_AUC=0.6926  test_AUC_drop=0.0211
# DTree_d4_leaf20_split10_bal  temp_test_AUC=0.6666  random_test_AUC=0.6879  test_AUC_drop=0.0213
# DTree_d4_leaf20_split20_bal  temp_test_AUC=0.6666  random_test_AUC=0.6879  test_AUC_drop=0.0213
# DTree_d4_leaf20_split50_bal  temp_test_AUC=0.6666  random_test_AUC=0.6879  test_AUC_drop=0.0213
# DTree_d4_leaf50_split10  temp_test_AUC=0.6712  random_test_AUC=0.6926  test_AUC_drop=0.0213
# DTree_d4_leaf50_split20  temp_test_AUC=0.6712  random_test_AUC=0.6926  test_AUC_drop=0.0213
# DTree_d4_leaf50_split50  temp_test_AUC=0.6712  random_test_AUC=0.6926  test_AUC_drop=0.0213
# DTree_d4_bal          temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf5_split10_bal  temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf5_split20_bal  temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf5_split50_bal  temp_test_AUC=0.6660  random_test_AUC=0.6879  test_AUC_drop=0.0218
# DTree_d4_leaf50_split10_ent  temp_test_AUC=0.6659  random_test_AUC=0.6879  test_AUC_drop=0.0220
# DTree_d4_leaf50_split20_ent  temp_test_AUC=0.6659  random_test_AUC=0.6879  test_AUC_drop=0.0220
# DTree_d4_leaf50_split50_ent  temp_test_AUC=0.6659  random_test_AUC=0.6879  test_AUC_drop=0.0220
# DTree_d4_leaf50_split10_bal  temp_test_AUC=0.6655  random_test_AUC=0.6879  test_AUC_drop=0.0224
# DTree_d4_leaf50_split20_bal  temp_test_AUC=0.6655  random_test_AUC=0.6879  test_AUC_drop=0.0224
# DTree_d4_leaf50_split50_bal  temp_test_AUC=0.6655  random_test_AUC=0.6879  test_AUC_drop=0.0224
# DTree_d5_ent          temp_test_AUC=0.6640  random_test_AUC=0.6930  test_AUC_drop=0.0290
# DTree_d5_leaf5        temp_test_AUC=0.6665  random_test_AUC=0.7004  test_AUC_drop=0.0338
# DTree_d5_leaf20       temp_test_AUC=0.6663  random_test_AUC=0.7004  test_AUC_drop=0.0341
# DTree_d5_leaf50       temp_test_AUC=0.6657  random_test_AUC=0.7004  test_AUC_drop=0.0347
# DTree_d5_bal          temp_test_AUC=0.6568  random_test_AUC=0.6933  test_AUC_drop=0.0365
# DTree_d5              temp_test_AUC=0.6637  random_test_AUC=0.7004  test_AUC_drop=0.0367
# DTree_d7_ent          temp_test_AUC=0.6497  random_test_AUC=0.6974  test_AUC_drop=0.0477
# DTree_d7_leaf50       temp_test_AUC=0.6494  random_test_AUC=0.7012  test_AUC_drop=0.0518
# DTree_d7_leaf20       temp_test_AUC=0.6447  random_test_AUC=0.7021  test_AUC_drop=0.0574
# DTree_d7_leaf5        temp_test_AUC=0.6445  random_test_AUC=0.7024  test_AUC_drop=0.0579
# DTree_d7_bal          temp_test_AUC=0.6341  random_test_AUC=0.6951  test_AUC_drop=0.0610
# DTree_d7              temp_test_AUC=0.6376  random_test_AUC=0.7024  test_AUC_drop=0.0648
# DTree_d10_ent         temp_test_AUC=0.6128  random_test_AUC=0.6903  test_AUC_drop=0.0774
# DTree_d10             temp_test_AUC=0.6158  random_test_AUC=0.6965  test_AUC_drop=0.0807
# DTree_d10_bal         temp_test_AUC=0.5981  random_test_AUC=0.6850  test_AUC_drop=0.0868
# === Decision Tree Selection Summary ===
# Best by temporal val AUC: DTree_d4
#   val_AUC=0.6719  test_AUC=0.6715  AUC_drop=0.0211
#
# Best by robustness (smallest AUC drop): DTree_d3
#   val_AUC=0.6686  test_AUC=0.6723  AUC_drop=0.0138
#
# Best balanced (val_AUC - AUC_drop): DTree_d3_bal
#   val_AUC=0.6706  test_AUC=0.6685  AUC_drop=0.0143

# %%
def objective_dt(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 5),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 50),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 50),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced']),
    }

    model = DecisionTreeClassifier(**params, random_state=42)
    model.fit(X_train_t, y_train_t)
    model_r = DecisionTreeClassifier(**params, random_state=42)
    model_r.fit(X_rand_tr, y_rand_tr)

    val_auc = roc_auc_score(y_val_t, model.predict_proba(X_val_t)[:, 1])
    rand_auc = roc_auc_score(y_rand_val, model_r.predict_proba(X_rand_val)[:, 1])
    auc_drop = rand_auc - val_auc

    y_prob_val = model.predict_proba(X_val_t)[:, 1]
    thresholds = np.arange(0.05, 0.50, 0.01)
    best_thr = max(thresholds, key=lambda t: f1_score(y_val_t, (y_prob_val >= t).astype(int), zero_division=0))
    val_f1 = f1_score(y_val_t, (y_prob_val >= best_thr).astype(int), zero_division=0)

    return w_performance * val_auc - w_robustness * auc_drop + w_f1 * val_f1

study_dt = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_dt.optimize(objective_dt, n_trials=60, show_progress_bar=True)
# Out:
# [I 2026-05-07 02:46:55,167] A new study created in memory with name: no-name-99a65c0a-d901-4e6b-9a14-28b31ce19ad6
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-05-07 02:46:56,293] Trial 0 finished with value: 0.2811602873752982 and parameters: {'max_depth': 4, 'min_samples_leaf': 48, 'min_samples_split': 37, 'criterion': 'gini', 'class_weight': None}. Best is trial 0 with value: 0.2811602873752982.
# [I 2026-05-07 02:46:57,644] Trial 1 finished with value: 0.2803284797402719 and parameters: {'max_depth': 5, 'min_samples_leaf': 31, 'min_samples_split': 36, 'criterion': 'entropy', 'class_weight': None}. Best is trial 0 with value: 0.2811602873752982.
# [I 2026-05-07 02:46:58,616] Trial 2 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 16, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.2832375838279958.
# [I 2026-05-07 02:46:59,688] Trial 3 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 15, 'min_samples_split': 19, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:00,499] Trial 4 finished with value: 0.2788122827609529 and parameters: {'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 31, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:01,422] Trial 5 finished with value: 0.2756738379150066 and parameters: {'max_depth': 5, 'min_samples_leaf': 16, 'min_samples_split': 6, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:02,102] Trial 6 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 46, 'min_samples_split': 14, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:02,773] Trial 7 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 49, 'min_samples_split': 39, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:03,466] Trial 8 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:04,308] Trial 9 finished with value: 0.2809264408200723 and parameters: {'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 28, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:05,093] Trial 10 finished with value: 0.28176704685752224 and parameters: {'max_depth': 4, 'min_samples_leaf': 29, 'min_samples_split': 49, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:05,795] Trial 11 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 21, 'min_samples_split': 3, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:06,494] Trial 12 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 17, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:07,190] Trial 13 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 9, 'min_samples_split': 10, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:08,007] Trial 14 finished with value: 0.28176704685752224 and parameters: {'max_depth': 4, 'min_samples_leaf': 22, 'min_samples_split': 21, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:08,724] Trial 15 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 39, 'min_samples_split': 22, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:09,440] Trial 16 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 9, 'min_samples_split': 10, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:10,769] Trial 17 finished with value: 0.2769241474526904 and parameters: {'max_depth': 5, 'min_samples_leaf': 16, 'min_samples_split': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:11,749] Trial 18 finished with value: 0.2821558499761673 and parameters: {'max_depth': 3, 'min_samples_leaf': 25, 'min_samples_split': 10, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:13,012] Trial 19 finished with value: 0.2809264408200723 and parameters: {'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:14,239] Trial 20 finished with value: 0.2809264408200723 and parameters: {'max_depth': 4, 'min_samples_leaf': 13, 'min_samples_split': 26, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:15,306] Trial 21 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 22, 'min_samples_split': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:16,291] Trial 22 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 20, 'min_samples_split': 6, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:16,993] Trial 23 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 6, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:17,687] Trial 24 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 18, 'min_samples_split': 12, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:18,395] Trial 25 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 26, 'min_samples_split': 6, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:19,067] Trial 26 finished with value: 0.2821558499761673 and parameters: {'max_depth': 3, 'min_samples_leaf': 6, 'min_samples_split': 2, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:19,899] Trial 27 finished with value: 0.2809264408200723 and parameters: {'max_depth': 4, 'min_samples_leaf': 13, 'min_samples_split': 17, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:20,600] Trial 28 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 37, 'min_samples_split': 50, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:21,378] Trial 29 finished with value: 0.2812619944456835 and parameters: {'max_depth': 4, 'min_samples_leaf': 12, 'min_samples_split': 44, 'criterion': 'gini', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:22,079] Trial 30 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 25, 'min_samples_split': 25, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:22,801] Trial 31 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 17, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:23,519] Trial 32 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 32, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:24,232] Trial 33 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 3, 'min_samples_split': 15, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:24,925] Trial 34 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 11, 'min_samples_split': 19, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:25,850] Trial 35 finished with value: 0.2756956571622794 and parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 11, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:26,687] Trial 36 finished with value: 0.2821558499761673 and parameters: {'max_depth': 3, 'min_samples_leaf': 8, 'min_samples_split': 24, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:27,667] Trial 37 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 19, 'min_samples_split': 8, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:28,873] Trial 38 finished with value: 0.2809264408200723 and parameters: {'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 13, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:29,898] Trial 39 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 15, 'min_samples_split': 31, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:30,950] Trial 40 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 17, 'min_samples_split': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:32,005] Trial 41 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 11, 'min_samples_split': 8, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:32,972] Trial 42 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 9, 'min_samples_split': 14, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:33,668] Trial 43 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 14, 'min_samples_split': 9, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:34,401] Trial 44 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 8, 'min_samples_split': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:35,221] Trial 45 finished with value: 0.28176704685752224 and parameters: {'max_depth': 4, 'min_samples_leaf': 21, 'min_samples_split': 16, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:35,975] Trial 46 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 19, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:36,663] Trial 47 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 12, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:37,684] Trial 48 finished with value: 0.2769241474526904 and parameters: {'max_depth': 5, 'min_samples_leaf': 17, 'min_samples_split': 23, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:38,384] Trial 49 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 24, 'min_samples_split': 4, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:39,055] Trial 50 finished with value: 0.2821558499761673 and parameters: {'max_depth': 3, 'min_samples_leaf': 28, 'min_samples_split': 9, 'criterion': 'entropy', 'class_weight': None}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:39,748] Trial 51 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 45, 'min_samples_split': 22, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:40,450] Trial 52 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 40, 'min_samples_split': 21, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:41,171] Trial 53 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 31, 'min_samples_split': 18, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:41,867] Trial 54 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 50, 'min_samples_split': 29, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:42,587] Trial 55 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 37, 'min_samples_split': 28, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:43,682] Trial 56 finished with value: 0.280851081954355 and parameters: {'max_depth': 4, 'min_samples_leaf': 46, 'min_samples_split': 7, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:44,690] Trial 57 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 22, 'min_samples_split': 5, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:45,728] Trial 58 finished with value: 0.28463632920973825 and parameters: {'max_depth': 3, 'min_samples_leaf': 15, 'min_samples_split': 2, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.
# [I 2026-05-07 02:47:46,743] Trial 59 finished with value: 0.2832375838279958 and parameters: {'max_depth': 3, 'min_samples_leaf': 19, 'min_samples_split': 14, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.28463632920973825.

# %%
# ── best 10 => DT_MODEL_CONFIGS ──────────────────────────────
top_trials_dt = sorted(study_dt.trials, key=lambda t: t.value if t.value else -999, reverse=True)[:10]

DT_MODEL_CONFIGS = {}
for i, t in enumerate(top_trials_dt):
    name = f'DTree_optuna_{i+1}'
    DT_MODEL_CONFIGS[name] = (
        DecisionTreeClassifier(**t.params, random_state=42), 'raw'
    )

# ── evaluation ────────────────────────────────────────────────
dt_results = evaluate_model_configs(DT_MODEL_CONFIGS)

# (val set)
print_selection_table(dt_results, sort_key='val_auc', reverse=True, title='DT - Val Set', mode='val')
print_selection_table(dt_results, sort_key='val_auc_drop', reverse=False, title='DT - Val Robustness', mode='val')
print_selection_table(dt_results, sort_key='val_recall', reverse=True, title='DT - Val Recall', mode='val')

# (test set)
print_selection_table(dt_results, sort_key='test_auc', reverse=True, title='DT - Test Set (Final)', mode='test')
print_selection_table(dt_results, sort_key='test_auc_drop', reverse=False, title='DT - Test Robustness (Final)', mode='test')
print_selection_table(dt_results, sort_key='recall', reverse=True, title='DT - Test Recall (Final)', mode='test')

# (best summary)
print_best_summary(dt_results, prefix='DTree_', title='Decision Tree Selection Summary')

# ── Hyperparameter print ──────────────────────────────────────
print_optuna_results(study_dt, top_trials_dt, title='DT Optuna Hyperparameter Results')
# Out:
# === DT - Val Set ===
# DTree_optuna_1        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_2        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_3        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_4        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_5        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_6        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_7        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_8        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_9        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_10       temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
#
# === DT - Val Robustness ===
# DTree_optuna_1        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_2        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_3        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_4        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_5        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_6        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_7        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_8        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_9        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_10       temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
#
# === DT - Val Recall ===
# DTree_optuna_1        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_2        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_3        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_4        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_5        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_6        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_7        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_8        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_9        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_10       temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
#
# === DT - Test Set (Final) ===
# DTree_optuna_1        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_2        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_3        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_4        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_5        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_6        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_7        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_8        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_9        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_10       temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
#
# === DT - Test Robustness (Final) ===
# DTree_optuna_1        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_2        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_3        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_4        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_5        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_6        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_7        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_8        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_9        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_10       temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
#
# === DT - Test Recall (Final) ===
# DTree_optuna_1        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_2        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_3        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_4        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_5        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_6        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_7        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_8        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_9        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_10       temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# === Decision Tree Selection Summary ===
# Best by temporal val AUC: DTree_optuna_1
#   val_AUC=0.6702  test_AUC=0.6675  AUC_drop=0.0153
#
# Best by robustness (smallest AUC drop): DTree_optuna_1
#   val_AUC=0.6702  test_AUC=0.6675  AUC_drop=0.0153
#
# Best balanced (val_AUC - AUC_drop): DTree_optuna_1
#   val_AUC=0.6702  test_AUC=0.6675  AUC_drop=0.0153
#
# === DT Optuna Hyperparameter Results ===
# Best score: 0.2846
#
# Best params:
#   max_depth           : 3
#   min_samples_leaf    : 15
#   min_samples_split   : 19
#   criterion           : entropy
#   class_weight        : balanced
#
# === Top 10 Trials ===
#
# [1] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 15
#   min_samples_split   : 19
#   criterion           : entropy
#   class_weight        : balanced
#
# [2] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 10
#   min_samples_split   : 4
#   criterion           : entropy
#   class_weight        : balanced
#
# [3] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 21
#   min_samples_split   : 3
#   criterion           : entropy
#   class_weight        : balanced
#
# [4] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 1
#   min_samples_split   : 17
#   criterion           : entropy
#   class_weight        : balanced
#
# [5] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 9
#   min_samples_split   : 10
#   criterion           : entropy
#   class_weight        : balanced
#
# [6] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 39
#   min_samples_split   : 22
#   criterion           : entropy
#   class_weight        : balanced
#
# [7] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 9
#   min_samples_split   : 10
#   criterion           : entropy
#   class_weight        : balanced
#
# [8] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 22
#   min_samples_split   : 2
#   criterion           : entropy
#   class_weight        : balanced
#
# [9] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 20
#   min_samples_split   : 6
#   criterion           : entropy
#   class_weight        : balanced
#
# [10] score=0.2846
#   max_depth           : 3
#   min_samples_leaf    : 32
#   min_samples_split   : 6
#   criterion           : entropy
#   class_weight        : balanced

# %% [markdown]
# ## Random Forest Test Code (Find Best)

# %%
RF_MODEL_CONFIGS = {
    # 1) n_estimators sweep (d3, d5 각각)
    'RF_n50_d3':    (RandomForestClassifier(n_estimators=50,  max_depth=3, random_state=42, n_jobs=-1), 'raw'),
    'RF_n100_d3':   (RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3':   (RandomForestClassifier(n_estimators=200, max_depth=3, random_state=42, n_jobs=-1), 'raw'),
    'RF_n300_d3':   (RandomForestClassifier(n_estimators=300, max_depth=3, random_state=42, n_jobs=-1), 'raw'),
    'RF_n50_d5':    (RandomForestClassifier(n_estimators=50,  max_depth=5, random_state=42, n_jobs=-1), 'raw'),
    'RF_n100_d5':   (RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5':   (RandomForestClassifier(n_estimators=200, max_depth=5, random_state=42, n_jobs=-1), 'raw'),
    'RF_n300_d5':   (RandomForestClassifier(n_estimators=300, max_depth=5, random_state=42, n_jobs=-1), 'raw'),

    # 2) max_depth sweep (n100 기준)
    'RF_n200_d4':   (RandomForestClassifier(n_estimators=200, max_depth=4,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d6':   (RandomForestClassifier(n_estimators=200, max_depth=6,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d8':   (RandomForestClassifier(n_estimators=200, max_depth=8,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d12':  (RandomForestClassifier(n_estimators=200, max_depth=12, random_state=42, n_jobs=-1), 'raw'),

    # 3) min_samples_leaf sweep (d3, d5 각각)
    'RF_n200_d3_leaf5':   (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_leaf=5,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_leaf10':  (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_leaf=10, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_leaf20':  (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_leaf=20, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_leaf5':   (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_leaf=5,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_leaf10':  (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_leaf=10, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_leaf20':  (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_leaf=20, random_state=42, n_jobs=-1), 'raw'),

    # 4) max_features sweep (d3, d5 각각)
    'RF_n200_d3_sqrt':  (RandomForestClassifier(n_estimators=200, max_depth=3, max_features='sqrt', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_log2':  (RandomForestClassifier(n_estimators=200, max_depth=3, max_features='log2', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_half':  (RandomForestClassifier(n_estimators=200, max_depth=3, max_features=0.5,    random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_sqrt':  (RandomForestClassifier(n_estimators=200, max_depth=5, max_features='sqrt', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_log2':  (RandomForestClassifier(n_estimators=200, max_depth=5, max_features='log2', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_half':  (RandomForestClassifier(n_estimators=200, max_depth=5, max_features=0.5,    random_state=42, n_jobs=-1), 'raw'),

    # 5) min_samples_split sweep (d3, d5 각각)
    'RF_n200_d3_split5':   (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_split=5,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_split10':  (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_split=10, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_split20':  (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_split=20, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_split5':   (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_split=5,  random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_split10':  (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_split=10, random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_split20':  (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_split=20, random_state=42, n_jobs=-1), 'raw'),

    # # 6) class_weight sweep (d3, d5 각각)
    'RF_n100_d3_balanced': (RandomForestClassifier(n_estimators=200, max_depth=3, class_weight='balanced', random_state=42, n_jobs=-1), 'raw'),
    'RF_n100_d5_balanced': (RandomForestClassifier(n_estimators=200, max_depth=3, class_weight='balanced_subsample', random_state=42, n_jobs=-1), 'raw'),

    # 7) combo (n_estimators + leaf + features, d3, d5 각각)
    'RF_n200_d3_leaf5_sqrt':  (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_leaf=5,  max_features='sqrt', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d3_leaf10_sqrt': (RandomForestClassifier(n_estimators=200, max_depth=3, min_samples_leaf=10, max_features='sqrt', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_leaf5_sqrt':  (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_leaf=5,  max_features='sqrt', random_state=42, n_jobs=-1), 'raw'),
    'RF_n200_d5_leaf10_sqrt': (RandomForestClassifier(n_estimators=200, max_depth=5, min_samples_leaf=10, max_features='sqrt', random_state=42, n_jobs=-1), 'raw'),
}

print(f'Total RF model configs: {len(RF_MODEL_CONFIGS)}')
# Out:
# Total RF model configs: 36

# %%
# rf_results = evaluate_model_configs(RF_MODEL_CONFIGS)

# # (val set)
# print_selection_table(rf_results, sort_key='val_auc', reverse=True, title='RF - Val Set', mode='val')
# print_selection_table(rf_results, sort_key='val_auc_drop', reverse=False, title='RF - Val Robustness', mode='val')

# # (test set)
# print_selection_table(rf_results, sort_key='test_auc', reverse=True, title='RF - Test Set (Final)', mode='test')
# print_selection_table(rf_results, sort_key='test_auc_drop', reverse=False, title='RF - Test Robustness (Final)', mode='test')

# # (best summary)
# print_best_summary(rf_results, prefix='RF_', title='Random Forest Selection Summary')
# Out:
# === RF - Val Set ===
# RF_n200_d3_half       temp_val_AUC=0.6819  rand_val_AUC=0.6914  val_AUC_drop=0.0095
# RF_n200_d5_leaf20     temp_val_AUC=0.6812  rand_val_AUC=0.6936  val_AUC_drop=0.0124
# RF_n200_d5_leaf10     temp_val_AUC=0.6812  rand_val_AUC=0.6939  val_AUC_drop=0.0127
# RF_n200_d5_leaf10_sqrt  temp_val_AUC=0.6812  rand_val_AUC=0.6939  val_AUC_drop=0.0127
# RF_n200_d5_leaf5      temp_val_AUC=0.6811  rand_val_AUC=0.6938  val_AUC_drop=0.0127
# RF_n200_d5_leaf5_sqrt  temp_val_AUC=0.6811  rand_val_AUC=0.6938  val_AUC_drop=0.0127
# RF_n200_d6            temp_val_AUC=0.6809  rand_val_AUC=0.6957  val_AUC_drop=0.0147
# RF_n200_d5_half       temp_val_AUC=0.6809  rand_val_AUC=0.6969  val_AUC_drop=0.0160
# RF_n300_d5            temp_val_AUC=0.6808  rand_val_AUC=0.6934  val_AUC_drop=0.0126
# RF_n200_d5_split10    temp_val_AUC=0.6808  rand_val_AUC=0.6942  val_AUC_drop=0.0134
# RF_n200_d5            temp_val_AUC=0.6807  rand_val_AUC=0.6940  val_AUC_drop=0.0133
# RF_n200_d5_sqrt       temp_val_AUC=0.6807  rand_val_AUC=0.6940  val_AUC_drop=0.0133
# RF_n200_d5_log2       temp_val_AUC=0.6807  rand_val_AUC=0.6940  val_AUC_drop=0.0133
# RF_n200_d5_split5     temp_val_AUC=0.6806  rand_val_AUC=0.6939  val_AUC_drop=0.0133
# RF_n200_d5_split20    temp_val_AUC=0.6806  rand_val_AUC=0.6943  val_AUC_drop=0.0137
# RF_n100_d5            temp_val_AUC=0.6803  rand_val_AUC=0.6936  val_AUC_drop=0.0132
# RF_n50_d5             temp_val_AUC=0.6797  rand_val_AUC=0.6925  val_AUC_drop=0.0128
# RF_n200_d4            temp_val_AUC=0.6789  rand_val_AUC=0.6907  val_AUC_drop=0.0118
# RF_n200_d8            temp_val_AUC=0.6785  rand_val_AUC=0.6988  val_AUC_drop=0.0202
# RF_n100_d3_balanced   temp_val_AUC=0.6785  rand_val_AUC=0.6831  val_AUC_drop=0.0046
# RF_n100_d5_balanced   temp_val_AUC=0.6784  rand_val_AUC=0.6831  val_AUC_drop=0.0047
# RF_n200_d3_leaf10     temp_val_AUC=0.6774  rand_val_AUC=0.6885  val_AUC_drop=0.0112
# RF_n200_d3_leaf10_sqrt  temp_val_AUC=0.6774  rand_val_AUC=0.6885  val_AUC_drop=0.0112
# RF_n200_d3_leaf5      temp_val_AUC=0.6771  rand_val_AUC=0.6885  val_AUC_drop=0.0114
# RF_n200_d3_leaf5_sqrt  temp_val_AUC=0.6771  rand_val_AUC=0.6885  val_AUC_drop=0.0114
# RF_n300_d3            temp_val_AUC=0.6770  rand_val_AUC=0.6882  val_AUC_drop=0.0112
# RF_n200_d3_leaf20     temp_val_AUC=0.6770  rand_val_AUC=0.6885  val_AUC_drop=0.0115
# RF_n200_d3            temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_sqrt       temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_log2       temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_split5     temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_split20    temp_val_AUC=0.6768  rand_val_AUC=0.6885  val_AUC_drop=0.0117
# RF_n200_d3_split10    temp_val_AUC=0.6768  rand_val_AUC=0.6885  val_AUC_drop=0.0117
# RF_n100_d3            temp_val_AUC=0.6763  rand_val_AUC=0.6880  val_AUC_drop=0.0117
# RF_n50_d3             temp_val_AUC=0.6744  rand_val_AUC=0.6843  val_AUC_drop=0.0099
# RF_n200_d12           temp_val_AUC=0.6680  rand_val_AUC=0.7020  val_AUC_drop=0.0341
#
# === RF - Val Robustness ===
# RF_n100_d3_balanced   temp_val_AUC=0.6785  rand_val_AUC=0.6831  val_AUC_drop=0.0046
# RF_n100_d5_balanced   temp_val_AUC=0.6784  rand_val_AUC=0.6831  val_AUC_drop=0.0047
# RF_n200_d3_half       temp_val_AUC=0.6819  rand_val_AUC=0.6914  val_AUC_drop=0.0095
# RF_n50_d3             temp_val_AUC=0.6744  rand_val_AUC=0.6843  val_AUC_drop=0.0099
# RF_n200_d3_leaf10     temp_val_AUC=0.6774  rand_val_AUC=0.6885  val_AUC_drop=0.0112
# RF_n200_d3_leaf10_sqrt  temp_val_AUC=0.6774  rand_val_AUC=0.6885  val_AUC_drop=0.0112
# RF_n300_d3            temp_val_AUC=0.6770  rand_val_AUC=0.6882  val_AUC_drop=0.0112
# RF_n200_d3_leaf5      temp_val_AUC=0.6771  rand_val_AUC=0.6885  val_AUC_drop=0.0114
# RF_n200_d3_leaf5_sqrt  temp_val_AUC=0.6771  rand_val_AUC=0.6885  val_AUC_drop=0.0114
# RF_n200_d3_leaf20     temp_val_AUC=0.6770  rand_val_AUC=0.6885  val_AUC_drop=0.0115
# RF_n200_d3            temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_sqrt       temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_log2       temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_split5     temp_val_AUC=0.6769  rand_val_AUC=0.6885  val_AUC_drop=0.0116
# RF_n200_d3_split20    temp_val_AUC=0.6768  rand_val_AUC=0.6885  val_AUC_drop=0.0117
# RF_n200_d3_split10    temp_val_AUC=0.6768  rand_val_AUC=0.6885  val_AUC_drop=0.0117
# RF_n100_d3            temp_val_AUC=0.6763  rand_val_AUC=0.6880  val_AUC_drop=0.0117
# RF_n200_d4            temp_val_AUC=0.6789  rand_val_AUC=0.6907  val_AUC_drop=0.0118
# RF_n200_d5_leaf20     temp_val_AUC=0.6812  rand_val_AUC=0.6936  val_AUC_drop=0.0124
# RF_n300_d5            temp_val_AUC=0.6808  rand_val_AUC=0.6934  val_AUC_drop=0.0126
# RF_n200_d5_leaf10     temp_val_AUC=0.6812  rand_val_AUC=0.6939  val_AUC_drop=0.0127
# RF_n200_d5_leaf10_sqrt  temp_val_AUC=0.6812  rand_val_AUC=0.6939  val_AUC_drop=0.0127
# RF_n200_d5_leaf5      temp_val_AUC=0.6811  rand_val_AUC=0.6938  val_AUC_drop=0.0127
# RF_n200_d5_leaf5_sqrt  temp_val_AUC=0.6811  rand_val_AUC=0.6938  val_AUC_drop=0.0127
# RF_n50_d5             temp_val_AUC=0.6797  rand_val_AUC=0.6925  val_AUC_drop=0.0128
# RF_n100_d5            temp_val_AUC=0.6803  rand_val_AUC=0.6936  val_AUC_drop=0.0132
# RF_n200_d5_split5     temp_val_AUC=0.6806  rand_val_AUC=0.6939  val_AUC_drop=0.0133
# RF_n200_d5            temp_val_AUC=0.6807  rand_val_AUC=0.6940  val_AUC_drop=0.0133
# RF_n200_d5_sqrt       temp_val_AUC=0.6807  rand_val_AUC=0.6940  val_AUC_drop=0.0133
# RF_n200_d5_log2       temp_val_AUC=0.6807  rand_val_AUC=0.6940  val_AUC_drop=0.0133
# RF_n200_d5_split10    temp_val_AUC=0.6808  rand_val_AUC=0.6942  val_AUC_drop=0.0134
# RF_n200_d5_split20    temp_val_AUC=0.6806  rand_val_AUC=0.6943  val_AUC_drop=0.0137
# RF_n200_d6            temp_val_AUC=0.6809  rand_val_AUC=0.6957  val_AUC_drop=0.0147
# RF_n200_d5_half       temp_val_AUC=0.6809  rand_val_AUC=0.6969  val_AUC_drop=0.0160
# RF_n200_d8            temp_val_AUC=0.6785  rand_val_AUC=0.6988  val_AUC_drop=0.0202
# RF_n200_d12           temp_val_AUC=0.6680  rand_val_AUC=0.7020  val_AUC_drop=0.0341
#
# === RF - Test Set (Final) ===
# RF_n200_d3_half       temp_test_AUC=0.6828  random_test_AUC=0.6944  test_AUC_drop=0.0116
# RF_n200_d5_leaf20     temp_test_AUC=0.6815  random_test_AUC=0.6985  test_AUC_drop=0.0170
# RF_n200_d5_leaf5      temp_test_AUC=0.6806  random_test_AUC=0.6985  test_AUC_drop=0.0179
# RF_n200_d5_leaf5_sqrt  temp_test_AUC=0.6806  random_test_AUC=0.6985  test_AUC_drop=0.0179
# RF_n200_d5_leaf10     temp_test_AUC=0.6805  random_test_AUC=0.6984  test_AUC_drop=0.0179
# RF_n200_d5_leaf10_sqrt  temp_test_AUC=0.6805  random_test_AUC=0.6984  test_AUC_drop=0.0179
# RF_n200_d4            temp_test_AUC=0.6801  random_test_AUC=0.6957  test_AUC_drop=0.0156
# RF_n100_d3_balanced   temp_test_AUC=0.6798  random_test_AUC=0.6891  test_AUC_drop=0.0093
# RF_n100_d5_balanced   temp_test_AUC=0.6797  random_test_AUC=0.6891  test_AUC_drop=0.0094
# RF_n300_d5            temp_test_AUC=0.6794  random_test_AUC=0.6982  test_AUC_drop=0.0188
# RF_n200_d5            temp_test_AUC=0.6794  random_test_AUC=0.6985  test_AUC_drop=0.0191
# RF_n200_d5_sqrt       temp_test_AUC=0.6794  random_test_AUC=0.6985  test_AUC_drop=0.0191
# RF_n200_d5_log2       temp_test_AUC=0.6794  random_test_AUC=0.6985  test_AUC_drop=0.0191
# RF_n200_d5_half       temp_test_AUC=0.6789  random_test_AUC=0.7021  test_AUC_drop=0.0232
# RF_n100_d5            temp_test_AUC=0.6786  random_test_AUC=0.6982  test_AUC_drop=0.0196
# RF_n200_d5_split5     temp_test_AUC=0.6786  random_test_AUC=0.6983  test_AUC_drop=0.0198
# RF_n200_d3_leaf10     temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0141
# RF_n200_d3_leaf10_sqrt  temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0141
# RF_n200_d3            temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_sqrt       temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_log2       temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d5_split10    temp_test_AUC=0.6785  random_test_AUC=0.6985  test_AUC_drop=0.0200
# RF_n200_d3_leaf5      temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_leaf5_sqrt  temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_split5     temp_test_AUC=0.6784  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n300_d3            temp_test_AUC=0.6784  random_test_AUC=0.6927  test_AUC_drop=0.0143
# RF_n50_d5             temp_test_AUC=0.6784  random_test_AUC=0.6967  test_AUC_drop=0.0183
# RF_n200_d3_leaf20     temp_test_AUC=0.6783  random_test_AUC=0.6927  test_AUC_drop=0.0143
# RF_n200_d3_split20    temp_test_AUC=0.6782  random_test_AUC=0.6927  test_AUC_drop=0.0144
# RF_n200_d3_split10    temp_test_AUC=0.6782  random_test_AUC=0.6927  test_AUC_drop=0.0144
# RF_n100_d3            temp_test_AUC=0.6778  random_test_AUC=0.6923  test_AUC_drop=0.0145
# RF_n200_d5_split20    temp_test_AUC=0.6776  random_test_AUC=0.6984  test_AUC_drop=0.0208
# RF_n50_d3             temp_test_AUC=0.6774  random_test_AUC=0.6898  test_AUC_drop=0.0125
# RF_n200_d6            temp_test_AUC=0.6771  random_test_AUC=0.7005  test_AUC_drop=0.0234
# RF_n200_d8            temp_test_AUC=0.6732  random_test_AUC=0.7037  test_AUC_drop=0.0305
# RF_n200_d12           temp_test_AUC=0.6615  random_test_AUC=0.7066  test_AUC_drop=0.0451
#
# === RF - Test Robustness (Final) ===
# RF_n100_d3_balanced   temp_test_AUC=0.6798  random_test_AUC=0.6891  test_AUC_drop=0.0093
# RF_n100_d5_balanced   temp_test_AUC=0.6797  random_test_AUC=0.6891  test_AUC_drop=0.0094
# RF_n200_d3_half       temp_test_AUC=0.6828  random_test_AUC=0.6944  test_AUC_drop=0.0116
# RF_n50_d3             temp_test_AUC=0.6774  random_test_AUC=0.6898  test_AUC_drop=0.0125
# RF_n200_d3_leaf10     temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0141
# RF_n200_d3_leaf10_sqrt  temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0141
# RF_n200_d3            temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_sqrt       temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_log2       temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_leaf5      temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_leaf5_sqrt  temp_test_AUC=0.6785  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n200_d3_split5     temp_test_AUC=0.6784  random_test_AUC=0.6927  test_AUC_drop=0.0142
# RF_n300_d3            temp_test_AUC=0.6784  random_test_AUC=0.6927  test_AUC_drop=0.0143
# RF_n200_d3_leaf20     temp_test_AUC=0.6783  random_test_AUC=0.6927  test_AUC_drop=0.0143
# RF_n200_d3_split20    temp_test_AUC=0.6782  random_test_AUC=0.6927  test_AUC_drop=0.0144
# RF_n200_d3_split10    temp_test_AUC=0.6782  random_test_AUC=0.6927  test_AUC_drop=0.0144
# RF_n100_d3            temp_test_AUC=0.6778  random_test_AUC=0.6923  test_AUC_drop=0.0145
# RF_n200_d4            temp_test_AUC=0.6801  random_test_AUC=0.6957  test_AUC_drop=0.0156
# RF_n200_d5_leaf20     temp_test_AUC=0.6815  random_test_AUC=0.6985  test_AUC_drop=0.0170
# RF_n200_d5_leaf10     temp_test_AUC=0.6805  random_test_AUC=0.6984  test_AUC_drop=0.0179
# RF_n200_d5_leaf10_sqrt  temp_test_AUC=0.6805  random_test_AUC=0.6984  test_AUC_drop=0.0179
# RF_n200_d5_leaf5      temp_test_AUC=0.6806  random_test_AUC=0.6985  test_AUC_drop=0.0179
# RF_n200_d5_leaf5_sqrt  temp_test_AUC=0.6806  random_test_AUC=0.6985  test_AUC_drop=0.0179
# RF_n50_d5             temp_test_AUC=0.6784  random_test_AUC=0.6967  test_AUC_drop=0.0183
# RF_n300_d5            temp_test_AUC=0.6794  random_test_AUC=0.6982  test_AUC_drop=0.0188
# RF_n200_d5            temp_test_AUC=0.6794  random_test_AUC=0.6985  test_AUC_drop=0.0191
# RF_n200_d5_sqrt       temp_test_AUC=0.6794  random_test_AUC=0.6985  test_AUC_drop=0.0191
# RF_n200_d5_log2       temp_test_AUC=0.6794  random_test_AUC=0.6985  test_AUC_drop=0.0191
# RF_n100_d5            temp_test_AUC=0.6786  random_test_AUC=0.6982  test_AUC_drop=0.0196
# RF_n200_d5_split5     temp_test_AUC=0.6786  random_test_AUC=0.6983  test_AUC_drop=0.0198
# RF_n200_d5_split10    temp_test_AUC=0.6785  random_test_AUC=0.6985  test_AUC_drop=0.0200
# RF_n200_d5_split20    temp_test_AUC=0.6776  random_test_AUC=0.6984  test_AUC_drop=0.0208
# RF_n200_d5_half       temp_test_AUC=0.6789  random_test_AUC=0.7021  test_AUC_drop=0.0232
# RF_n200_d6            temp_test_AUC=0.6771  random_test_AUC=0.7005  test_AUC_drop=0.0234
# RF_n200_d8            temp_test_AUC=0.6732  random_test_AUC=0.7037  test_AUC_drop=0.0305
# RF_n200_d12           temp_test_AUC=0.6615  random_test_AUC=0.7066  test_AUC_drop=0.0451
# === Random Forest Selection Summary ===
# Best by temporal val AUC: RF_n200_d3_half
#   val_AUC=0.6819  test_AUC=0.6828  AUC_drop=0.0116
#
# Best by robustness (smallest AUC drop): RF_n100_d3_balanced
#   val_AUC=0.6785  test_AUC=0.6798  AUC_drop=0.0093
#
# Best balanced (val_AUC - AUC_drop): RF_n200_d3_half
#   val_AUC=0.6819  test_AUC=0.6828  AUC_drop=0.0116

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 200),
        'max_depth': trial.suggest_int('max_depth', 3, 5),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 0.5]),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced', 'balanced_subsample']),
    }

    model = RandomForestClassifier(**params, random_state=42, n_jobs=-1)
    model.fit(X_train_t, y_train_t)
    model_r = RandomForestClassifier(**params, random_state=42, n_jobs=-1)
    model_r.fit(X_rand_tr, y_rand_tr)

    val_auc = roc_auc_score(y_val_t, model.predict_proba(X_val_t)[:, 1])
    rand_auc = roc_auc_score(y_rand_val, model_r.predict_proba(X_rand_val)[:, 1])
    auc_drop = rand_auc - val_auc

    y_prob_val = model.predict_proba(X_val_t)[:, 1]
    thresholds = np.arange(0.05, 0.50, 0.01)
    best_thr = max(thresholds, key=lambda t: f1_score(y_val_t, (y_prob_val >= t).astype(int), zero_division=0))
    val_f1 = f1_score(y_val_t, (y_prob_val >= best_thr).astype(int), zero_division=0)

    return w_performance * val_auc - w_robustness * auc_drop + w_f1 * val_f1

study_rf = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_rf.optimize(objective_rf, n_trials=50, show_progress_bar=True)
# Out:
# [I 2026-05-07 02:47:57,348] A new study created in memory with name: no-name-b3170e11-f102-4793-b178-9a18db1c2434
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-05-07 02:48:13,162] Trial 0 finished with value: 0.2892589921456738 and parameters: {'n_estimators': 106, 'max_depth': 5, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.2892589921456738.
# [I 2026-05-07 02:48:28,823] Trial 1 finished with value: 0.28722263277586957 and parameters: {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 0 with value: 0.2892589921456738.
# [I 2026-05-07 02:48:47,725] Trial 2 finished with value: 0.28893288835062386 and parameters: {'n_estimators': 95, 'max_depth': 4, 'min_samples_leaf': 9, 'max_features': 0.5, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.2892589921456738.
# [I 2026-05-07 02:49:13,015] Trial 3 finished with value: 0.2883559541398166 and parameters: {'n_estimators': 118, 'max_depth': 5, 'min_samples_leaf': 4, 'max_features': 0.5, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.2892589921456738.
# [I 2026-05-07 02:49:19,561] Trial 4 finished with value: 0.2893248045586513 and parameters: {'n_estimators': 59, 'max_depth': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:49:24,626] Trial 5 finished with value: 0.2877950623064786 and parameters: {'n_estimators': 68, 'max_depth': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:49:47,792] Trial 6 finished with value: 0.28829034475786486 and parameters: {'n_estimators': 132, 'max_depth': 3, 'min_samples_leaf': 20, 'max_features': 0.5, 'class_weight': 'balanced_subsample'}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:49:55,673] Trial 7 finished with value: 0.288341360409121 and parameters: {'n_estimators': 63, 'max_depth': 3, 'min_samples_leaf': 1, 'max_features': 0.5, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:50:04,961] Trial 8 finished with value: 0.2858832624858922 and parameters: {'n_estimators': 92, 'max_depth': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:50:14,990] Trial 9 finished with value: 0.28785444619313416 and parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 15, 'max_features': 0.5, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:50:36,979] Trial 10 finished with value: 0.2890713001539784 and parameters: {'n_estimators': 192, 'max_depth': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.2893248045586513.
# [I 2026-05-07 02:51:01,826] Trial 11 finished with value: 0.2893560353479749 and parameters: {'n_estimators': 169, 'max_depth': 5, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.2893560353479749.
# [I 2026-05-07 02:51:25,386] Trial 12 finished with value: 0.28943561913249527 and parameters: {'n_estimators': 172, 'max_depth': 5, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 12 with value: 0.28943561913249527.
# [I 2026-05-07 02:51:48,376] Trial 13 finished with value: 0.28932273314034823 and parameters: {'n_estimators': 170, 'max_depth': 4, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 12 with value: 0.28943561913249527.
# [I 2026-05-07 02:52:07,932] Trial 14 finished with value: 0.28923055812632503 and parameters: {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 12 with value: 0.28943561913249527.
# [I 2026-05-07 02:52:34,450] Trial 15 finished with value: 0.2888646097159782 and parameters: {'n_estimators': 199, 'max_depth': 5, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 12 with value: 0.28943561913249527.
# [I 2026-05-07 02:52:59,778] Trial 16 finished with value: 0.2895298319078379 and parameters: {'n_estimators': 170, 'max_depth': 5, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 16 with value: 0.2895298319078379.
# [I 2026-05-07 02:53:18,060] Trial 17 finished with value: 0.2898072953972702 and parameters: {'n_estimators': 150, 'max_depth': 4, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.2898072953972702.
# [I 2026-05-07 02:53:34,043] Trial 18 finished with value: 0.29014377678457365 and parameters: {'n_estimators': 151, 'max_depth': 3, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 18 with value: 0.29014377678457365.
# [I 2026-05-07 02:53:49,816] Trial 19 finished with value: 0.29041143473604514 and parameters: {'n_estimators': 149, 'max_depth': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 19 with value: 0.29041143473604514.
# [I 2026-05-07 02:53:57,535] Trial 20 finished with value: 0.2863424958322909 and parameters: {'n_estimators': 125, 'max_depth': 3, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 19 with value: 0.29041143473604514.
# [I 2026-05-07 02:54:13,688] Trial 21 finished with value: 0.29029978611195556 and parameters: {'n_estimators': 150, 'max_depth': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 19 with value: 0.29041143473604514.
# [I 2026-05-07 02:54:29,582] Trial 22 finished with value: 0.29041143473604514 and parameters: {'n_estimators': 149, 'max_depth': 3, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 19 with value: 0.29041143473604514.
# [I 2026-05-07 02:54:45,031] Trial 23 finished with value: 0.29043341764615144 and parameters: {'n_estimators': 143, 'max_depth': 3, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.29043341764615144.
# [I 2026-05-07 02:54:59,909] Trial 24 finished with value: 0.2905084398621314 and parameters: {'n_estimators': 136, 'max_depth': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 24 with value: 0.2905084398621314.
# [I 2026-05-07 02:55:12,770] Trial 25 finished with value: 0.29090792816418426 and parameters: {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 25 with value: 0.29090792816418426.
# [I 2026-05-07 02:55:30,585] Trial 26 finished with value: 0.2882150080842379 and parameters: {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 5, 'max_features': 0.5, 'class_weight': 'balanced_subsample'}. Best is trial 25 with value: 0.29090792816418426.
# [I 2026-05-07 02:55:42,934] Trial 27 finished with value: 0.2905309123923619 and parameters: {'n_estimators': 128, 'max_depth': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 25 with value: 0.29090792816418426.
# [I 2026-05-07 02:55:49,720] Trial 28 finished with value: 0.2856164315813614 and parameters: {'n_estimators': 82, 'max_depth': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 25 with value: 0.29090792816418426.
# [I 2026-05-07 02:56:00,769] Trial 29 finished with value: 0.2909540736402992 and parameters: {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 29 with value: 0.2909540736402992.
# [I 2026-05-07 02:56:10,987] Trial 30 finished with value: 0.29098628146391614 and parameters: {'n_estimators': 105, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 30 with value: 0.29098628146391614.
# [I 2026-05-07 02:56:23,565] Trial 31 finished with value: 0.29108235022899454 and parameters: {'n_estimators': 109, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:56:34,706] Trial 32 finished with value: 0.29101302630771775 and parameters: {'n_estimators': 108, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:56:44,371] Trial 33 finished with value: 0.29089587758262386 and parameters: {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:56:54,574] Trial 34 finished with value: 0.2891219277400439 and parameters: {'n_estimators': 81, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:57:15,074] Trial 35 finished with value: 0.28885852232987164 and parameters: {'n_estimators': 105, 'max_depth': 4, 'min_samples_leaf': 2, 'max_features': 0.5, 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:57:22,976] Trial 36 finished with value: 0.2866933469060755 and parameters: {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:57:31,009] Trial 37 finished with value: 0.2901419468028213 and parameters: {'n_estimators': 90, 'max_depth': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:57:51,170] Trial 38 finished with value: 0.2887555432324779 and parameters: {'n_estimators': 102, 'max_depth': 4, 'min_samples_leaf': 1, 'max_features': 0.5, 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:57:59,548] Trial 39 finished with value: 0.289038570169028 and parameters: {'n_estimators': 79, 'max_depth': 3, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:58:15,244] Trial 40 finished with value: 0.288322768927443 and parameters: {'n_estimators': 121, 'max_depth': 3, 'min_samples_leaf': 4, 'max_features': 0.5, 'class_weight': 'balanced'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:58:26,903] Trial 41 finished with value: 0.29100537851889663 and parameters: {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:58:39,605] Trial 42 finished with value: 0.2908456017842031 and parameters: {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:58:47,886] Trial 43 finished with value: 0.29018590500733044 and parameters: {'n_estimators': 93, 'max_depth': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:58:59,137] Trial 44 finished with value: 0.290924526560123 and parameters: {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:59:07,638] Trial 45 finished with value: 0.2863809733743309 and parameters: {'n_estimators': 109, 'max_depth': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'class_weight': None}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:59:18,057] Trial 46 finished with value: 0.2893601027080816 and parameters: {'n_estimators': 87, 'max_depth': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:59:23,880] Trial 47 finished with value: 0.2894485516975573 and parameters: {'n_estimators': 71, 'max_depth': 3, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 02:59:37,189] Trial 48 finished with value: 0.29048322377731356 and parameters: {'n_estimators': 131, 'max_depth': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.
# [I 2026-05-07 03:00:03,902] Trial 49 finished with value: 0.2886562795401274 and parameters: {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 1, 'max_features': 0.5, 'class_weight': 'balanced_subsample'}. Best is trial 31 with value: 0.29108235022899454.

# %%
# ── best 10 => RF_OPTUNA_CONFIGS ──────────────────────────────
top_trials_rf = sorted(study_rf.trials, key=lambda t: t.value if t.value else -999, reverse=True)[:10]

RF_MODEL_CONFIGS = {}
for i, t in enumerate(top_trials_rf):
    name = f'RF_optuna_{i+1}'
    RF_MODEL_CONFIGS[name] = (
        RandomForestClassifier(**t.params, random_state=42, n_jobs=-1), 'raw'
    )

# ── evaluation ────────────────────────────────────────────────
rf_results = evaluate_model_configs(RF_MODEL_CONFIGS)

# (val set)
print_selection_table(rf_results, sort_key='val_auc', reverse=True, title='RF - Val Set', mode='val')
print_selection_table(rf_results, sort_key='val_auc_drop', reverse=False, title='RF - Val Robustness', mode='val')
print_selection_table(rf_results, sort_key='val_recall', reverse=True, title='RF - Val Recall', mode='val')

# (test set)
print_selection_table(rf_results, sort_key='test_auc', reverse=True, title='RF - Test Set (Final)', mode='test')
print_selection_table(rf_results, sort_key='test_auc_drop', reverse=False, title='RF - Test Robustness (Final)', mode='test')
print_selection_table(rf_results, sort_key='recall', reverse=True, title='RF - Test Recall (Final)', mode='test')

# (best summary)
print_best_summary(rf_results, prefix='RF_', title='Random Forest Selection Summary')

# ── Hyperparameter print ──────────────────────────────────────
print_optuna_results(study_rf, top_trials_rf, title='RF Optuna Hyperparameter Results')
# Out:
# === RF - Val Set ===
# RF_optuna_4           temp_val_AUC=0.6786  rand_val_AUC=0.6817  val_AUC_drop=0.0031  val_Recall=0.6316  val_Precision=0.2723  val_F1=0.3806  threshold=0.49
# RF_optuna_5           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0030  val_Recall=0.6284  val_Precision=0.2728  val_F1=0.3805  threshold=0.49
# RF_optuna_2           temp_val_AUC=0.6785  rand_val_AUC=0.6815  val_AUC_drop=0.0030  val_Recall=0.6302  val_Precision=0.2726  val_F1=0.3805  threshold=0.49
# RF_optuna_8           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6261  val_Precision=0.2736  val_F1=0.3808  threshold=0.49
# RF_optuna_6           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6262  val_Precision=0.2737  val_F1=0.3809  threshold=0.49
# RF_optuna_1           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6286  val_Precision=0.2732  val_F1=0.3808  threshold=0.49
# RF_optuna_3           temp_val_AUC=0.6784  rand_val_AUC=0.6815  val_AUC_drop=0.0031  val_Recall=0.6295  val_Precision=0.2728  val_F1=0.3806  threshold=0.49
# RF_optuna_7           temp_val_AUC=0.6784  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6292  val_Precision=0.2727  val_F1=0.3805  threshold=0.49
# RF_optuna_9           temp_val_AUC=0.6783  rand_val_AUC=0.6812  val_AUC_drop=0.0029  val_Recall=0.6307  val_Precision=0.2721  val_F1=0.3802  threshold=0.49
# RF_optuna_10          temp_val_AUC=0.6782  rand_val_AUC=0.6819  val_AUC_drop=0.0037  val_Recall=0.6267  val_Precision=0.2729  val_F1=0.3802  threshold=0.49
#
# === RF - Val Robustness ===
# RF_optuna_9           temp_val_AUC=0.6783  rand_val_AUC=0.6812  val_AUC_drop=0.0029  val_Recall=0.6307  val_Precision=0.2721  val_F1=0.3802  threshold=0.49
# RF_optuna_2           temp_val_AUC=0.6785  rand_val_AUC=0.6815  val_AUC_drop=0.0030  val_Recall=0.6302  val_Precision=0.2726  val_F1=0.3805  threshold=0.49
# RF_optuna_5           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0030  val_Recall=0.6284  val_Precision=0.2728  val_F1=0.3805  threshold=0.49
# RF_optuna_3           temp_val_AUC=0.6784  rand_val_AUC=0.6815  val_AUC_drop=0.0031  val_Recall=0.6295  val_Precision=0.2728  val_F1=0.3806  threshold=0.49
# RF_optuna_4           temp_val_AUC=0.6786  rand_val_AUC=0.6817  val_AUC_drop=0.0031  val_Recall=0.6316  val_Precision=0.2723  val_F1=0.3806  threshold=0.49
# RF_optuna_1           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6286  val_Precision=0.2732  val_F1=0.3808  threshold=0.49
# RF_optuna_7           temp_val_AUC=0.6784  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6292  val_Precision=0.2727  val_F1=0.3805  threshold=0.49
# RF_optuna_8           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6261  val_Precision=0.2736  val_F1=0.3808  threshold=0.49
# RF_optuna_6           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6262  val_Precision=0.2737  val_F1=0.3809  threshold=0.49
# RF_optuna_10          temp_val_AUC=0.6782  rand_val_AUC=0.6819  val_AUC_drop=0.0037  val_Recall=0.6267  val_Precision=0.2729  val_F1=0.3802  threshold=0.49
#
# === RF - Val Recall ===
# RF_optuna_4           temp_val_AUC=0.6786  rand_val_AUC=0.6817  val_AUC_drop=0.0031  val_Recall=0.6316  val_Precision=0.2723  val_F1=0.3806  threshold=0.49
# RF_optuna_9           temp_val_AUC=0.6783  rand_val_AUC=0.6812  val_AUC_drop=0.0029  val_Recall=0.6307  val_Precision=0.2721  val_F1=0.3802  threshold=0.49
# RF_optuna_2           temp_val_AUC=0.6785  rand_val_AUC=0.6815  val_AUC_drop=0.0030  val_Recall=0.6302  val_Precision=0.2726  val_F1=0.3805  threshold=0.49
# RF_optuna_3           temp_val_AUC=0.6784  rand_val_AUC=0.6815  val_AUC_drop=0.0031  val_Recall=0.6295  val_Precision=0.2728  val_F1=0.3806  threshold=0.49
# RF_optuna_7           temp_val_AUC=0.6784  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6292  val_Precision=0.2727  val_F1=0.3805  threshold=0.49
# RF_optuna_1           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6286  val_Precision=0.2732  val_F1=0.3808  threshold=0.49
# RF_optuna_5           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0030  val_Recall=0.6284  val_Precision=0.2728  val_F1=0.3805  threshold=0.49
# RF_optuna_10          temp_val_AUC=0.6782  rand_val_AUC=0.6819  val_AUC_drop=0.0037  val_Recall=0.6267  val_Precision=0.2729  val_F1=0.3802  threshold=0.49
# RF_optuna_6           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6262  val_Precision=0.2737  val_F1=0.3809  threshold=0.49
# RF_optuna_8           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6261  val_Precision=0.2736  val_F1=0.3808  threshold=0.49
#
# === RF - Test Set (Final) ===
# RF_optuna_5           temp_test_AUC=0.6801  random_test_AUC=0.6879  test_AUC_drop=0.0078  Recall=0.6051  Precision=0.1387  F1=0.2256  threshold=0.49
# RF_optuna_4           temp_test_AUC=0.6800  random_test_AUC=0.6881  test_AUC_drop=0.0081  Recall=0.6080  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_2           temp_test_AUC=0.6800  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6062  Precision=0.1385  F1=0.2255  threshold=0.49
# RF_optuna_1           temp_test_AUC=0.6799  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6040  Precision=0.1386  F1=0.2254  threshold=0.49
# RF_optuna_7           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0079  Recall=0.6054  Precision=0.1387  F1=0.2257  threshold=0.49
# RF_optuna_9           temp_test_AUC=0.6799  random_test_AUC=0.6876  test_AUC_drop=0.0076  Recall=0.6069  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_3           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0078  Recall=0.6052  Precision=0.1386  F1=0.2255  threshold=0.49
# RF_optuna_8           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6035  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_6           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6036  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_10          temp_test_AUC=0.6795  random_test_AUC=0.6880  test_AUC_drop=0.0085  Recall=0.6034  Precision=0.1388  F1=0.2257  threshold=0.49
#
# === RF - Test Robustness (Final) ===
# RF_optuna_9           temp_test_AUC=0.6799  random_test_AUC=0.6876  test_AUC_drop=0.0076  Recall=0.6069  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_5           temp_test_AUC=0.6801  random_test_AUC=0.6879  test_AUC_drop=0.0078  Recall=0.6051  Precision=0.1387  F1=0.2256  threshold=0.49
# RF_optuna_3           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0078  Recall=0.6052  Precision=0.1386  F1=0.2255  threshold=0.49
# RF_optuna_7           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0079  Recall=0.6054  Precision=0.1387  F1=0.2257  threshold=0.49
# RF_optuna_2           temp_test_AUC=0.6800  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6062  Precision=0.1385  F1=0.2255  threshold=0.49
# RF_optuna_1           temp_test_AUC=0.6799  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6040  Precision=0.1386  F1=0.2254  threshold=0.49
# RF_optuna_4           temp_test_AUC=0.6800  random_test_AUC=0.6881  test_AUC_drop=0.0081  Recall=0.6080  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_10          temp_test_AUC=0.6795  random_test_AUC=0.6880  test_AUC_drop=0.0085  Recall=0.6034  Precision=0.1388  F1=0.2257  threshold=0.49
# RF_optuna_8           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6035  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_6           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6036  Precision=0.1387  F1=0.2255  threshold=0.49
#
# === RF - Test Recall (Final) ===
# RF_optuna_4           temp_test_AUC=0.6800  random_test_AUC=0.6881  test_AUC_drop=0.0081  Recall=0.6080  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_9           temp_test_AUC=0.6799  random_test_AUC=0.6876  test_AUC_drop=0.0076  Recall=0.6069  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_2           temp_test_AUC=0.6800  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6062  Precision=0.1385  F1=0.2255  threshold=0.49
# RF_optuna_7           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0079  Recall=0.6054  Precision=0.1387  F1=0.2257  threshold=0.49
# RF_optuna_3           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0078  Recall=0.6052  Precision=0.1386  F1=0.2255  threshold=0.49
# RF_optuna_5           temp_test_AUC=0.6801  random_test_AUC=0.6879  test_AUC_drop=0.0078  Recall=0.6051  Precision=0.1387  F1=0.2256  threshold=0.49
# RF_optuna_1           temp_test_AUC=0.6799  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6040  Precision=0.1386  F1=0.2254  threshold=0.49
# RF_optuna_6           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6036  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_8           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6035  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_10          temp_test_AUC=0.6795  random_test_AUC=0.6880  test_AUC_drop=0.0085  Recall=0.6034  Precision=0.1388  F1=0.2257  threshold=0.49
# === Random Forest Selection Summary ===
# Best by temporal val AUC: RF_optuna_4
#   val_AUC=0.6786  test_AUC=0.6800  AUC_drop=0.0081
#
# Best by robustness (smallest AUC drop): RF_optuna_9
#   val_AUC=0.6783  test_AUC=0.6799  AUC_drop=0.0076
#
# Best balanced (val_AUC - AUC_drop): RF_optuna_5
#   val_AUC=0.6785  test_AUC=0.6801  AUC_drop=0.0078
#
# === RF Optuna Hyperparameter Results ===
# Best score: 0.2911
#
# Best params:
#   n_estimators        : 109
#   max_depth           : 3
#   min_samples_leaf    : 3
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# === Top 10 Trials ===
#
# [1] score=0.2911
#   n_estimators        : 109
#   max_depth           : 3
#   min_samples_leaf    : 3
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [2] score=0.2910
#   n_estimators        : 108
#   max_depth           : 3
#   min_samples_leaf    : 3
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [3] score=0.2910
#   n_estimators        : 111
#   max_depth           : 3
#   min_samples_leaf    : 2
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [4] score=0.2910
#   n_estimators        : 105
#   max_depth           : 3
#   min_samples_leaf    : 3
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [5] score=0.2910
#   n_estimators        : 110
#   max_depth           : 3
#   min_samples_leaf    : 3
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [6] score=0.2909
#   n_estimators        : 100
#   max_depth           : 3
#   min_samples_leaf    : 1
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [7] score=0.2909
#   n_estimators        : 114
#   max_depth           : 3
#   min_samples_leaf    : 5
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [8] score=0.2909
#   n_estimators        : 100
#   max_depth           : 3
#   min_samples_leaf    : 3
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [9] score=0.2908
#   n_estimators        : 112
#   max_depth           : 3
#   min_samples_leaf    : 2
#   max_features        : sqrt
#   class_weight        : balanced_subsample
#
# [10] score=0.2905
#   n_estimators        : 128
#   max_depth           : 3
#   min_samples_leaf    : 5
#   max_features        : sqrt
#   class_weight        : balanced_subsample

# %% [markdown]
# ## 4. Training & Temporal / Random AUC calculation

# %%
all_results = {}
all_results.update(xgb_results)
all_results.update(lr_results)
all_results.update(dt_results)
all_results.update(rf_results)

print(f'Total combined model configs: {len(all_results)}')
# Out:
# Total combined model configs: 40

# %%
# (val set)
print_selection_table(all_results, sort_key='val_auc', reverse=True, title='All Models - Val Set', mode='val')
print_selection_table(all_results, sort_key='val_auc_drop', reverse=False, title='All Models - Val Robustness', mode='val')

# (test set)
print_selection_table(all_results, sort_key='test_auc', reverse=True, title='All Models - Test Set (Final)', mode='test')
print_selection_table(all_results, sort_key='test_auc_drop', reverse=False, title='All Models - Test Robustness (Final)', mode='test')

# (best summary)
print_best_summary(all_results, title='Best Model')
# Out:
# === All Models - Val Set ===
# LR_optuna_1           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5876  val_Precision=0.2848  val_F1=0.3837  threshold=0.25
# LR_optuna_4           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6020  val_Precision=0.2804  val_F1=0.3826  threshold=0.25
# LR_optuna_6           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6075  val_Precision=0.2794  val_F1=0.3827  threshold=0.25
# LR_optuna_2           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5764  val_Precision=0.2871  val_F1=0.3833  threshold=0.25
# LR_optuna_3           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6162  val_Precision=0.2774  val_F1=0.3825  threshold=0.25
# LR_optuna_9           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.6148  val_Precision=0.2775  val_F1=0.3824  threshold=0.24
# LR_optuna_7           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5954  val_Precision=0.2820  val_F1=0.3827  threshold=0.24
# LR_optuna_5           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5838  val_Precision=0.2862  val_F1=0.3841  threshold=0.26
# LR_optuna_8           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5829  val_Precision=0.2856  val_F1=0.3834  threshold=0.24
# LR_optuna_10          temp_val_AUC=0.6856  rand_val_AUC=0.6879  val_AUC_drop=0.0023  val_Recall=0.5785  val_Precision=0.2856  val_F1=0.3824  threshold=0.22
# XGB_optuna_10         temp_val_AUC=0.6827  rand_val_AUC=0.6991  val_AUC_drop=0.0164  val_Recall=0.6268  val_Precision=0.2734  val_F1=0.3807  threshold=0.15
# XGB_optuna_7          temp_val_AUC=0.6826  rand_val_AUC=0.6990  val_AUC_drop=0.0163  val_Recall=0.6277  val_Precision=0.2738  val_F1=0.3812  threshold=0.15
# XGB_optuna_1          temp_val_AUC=0.6824  rand_val_AUC=0.6976  val_AUC_drop=0.0153  val_Recall=0.6270  val_Precision=0.2744  val_F1=0.3817  threshold=0.15
# XGB_optuna_5          temp_val_AUC=0.6823  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6272  val_Precision=0.2739  val_F1=0.3813  threshold=0.15
# XGB_optuna_2          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6253  val_Precision=0.2748  val_F1=0.3818  threshold=0.15
# XGB_optuna_4          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6240  val_Precision=0.2741  val_F1=0.3809  threshold=0.15
# XGB_optuna_6          temp_val_AUC=0.6822  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6229  val_Precision=0.2746  val_F1=0.3812  threshold=0.15
# XGB_optuna_3          temp_val_AUC=0.6821  rand_val_AUC=0.6969  val_AUC_drop=0.0149  val_Recall=0.6206  val_Precision=0.2748  val_F1=0.3809  threshold=0.15
# XGB_optuna_9          temp_val_AUC=0.6819  rand_val_AUC=0.6971  val_AUC_drop=0.0152  val_Recall=0.6231  val_Precision=0.2737  val_F1=0.3803  threshold=0.15
# XGB_optuna_8          temp_val_AUC=0.6816  rand_val_AUC=0.6967  val_AUC_drop=0.0150  val_Recall=0.6220  val_Precision=0.2739  val_F1=0.3803  threshold=0.15
# RF_optuna_4           temp_val_AUC=0.6786  rand_val_AUC=0.6817  val_AUC_drop=0.0031  val_Recall=0.6316  val_Precision=0.2723  val_F1=0.3806  threshold=0.49
# RF_optuna_5           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0030  val_Recall=0.6284  val_Precision=0.2728  val_F1=0.3805  threshold=0.49
# RF_optuna_2           temp_val_AUC=0.6785  rand_val_AUC=0.6815  val_AUC_drop=0.0030  val_Recall=0.6302  val_Precision=0.2726  val_F1=0.3805  threshold=0.49
# RF_optuna_8           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6261  val_Precision=0.2736  val_F1=0.3808  threshold=0.49
# RF_optuna_6           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6262  val_Precision=0.2737  val_F1=0.3809  threshold=0.49
# RF_optuna_1           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6286  val_Precision=0.2732  val_F1=0.3808  threshold=0.49
# RF_optuna_3           temp_val_AUC=0.6784  rand_val_AUC=0.6815  val_AUC_drop=0.0031  val_Recall=0.6295  val_Precision=0.2728  val_F1=0.3806  threshold=0.49
# RF_optuna_7           temp_val_AUC=0.6784  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6292  val_Precision=0.2727  val_F1=0.3805  threshold=0.49
# RF_optuna_9           temp_val_AUC=0.6783  rand_val_AUC=0.6812  val_AUC_drop=0.0029  val_Recall=0.6307  val_Precision=0.2721  val_F1=0.3802  threshold=0.49
# RF_optuna_10          temp_val_AUC=0.6782  rand_val_AUC=0.6819  val_AUC_drop=0.0037  val_Recall=0.6267  val_Precision=0.2729  val_F1=0.3802  threshold=0.49
# DTree_optuna_1        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_2        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_3        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_4        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_5        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_6        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_7        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_8        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_9        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_10       temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
#
# === All Models - Val Robustness ===
# LR_optuna_3           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6162  val_Precision=0.2774  val_F1=0.3825  threshold=0.25
# LR_optuna_6           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6075  val_Precision=0.2794  val_F1=0.3827  threshold=0.25
# LR_optuna_4           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0020  val_Recall=0.6020  val_Precision=0.2804  val_F1=0.3826  threshold=0.25
# LR_optuna_1           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5876  val_Precision=0.2848  val_F1=0.3837  threshold=0.25
# LR_optuna_2           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5764  val_Precision=0.2871  val_F1=0.3833  threshold=0.25
# LR_optuna_5           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5838  val_Precision=0.2862  val_F1=0.3841  threshold=0.26
# LR_optuna_9           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.6148  val_Precision=0.2775  val_F1=0.3824  threshold=0.24
# LR_optuna_7           temp_val_AUC=0.6859  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5954  val_Precision=0.2820  val_F1=0.3827  threshold=0.24
# LR_optuna_8           temp_val_AUC=0.6858  rand_val_AUC=0.6879  val_AUC_drop=0.0021  val_Recall=0.5829  val_Precision=0.2856  val_F1=0.3834  threshold=0.24
# LR_optuna_10          temp_val_AUC=0.6856  rand_val_AUC=0.6879  val_AUC_drop=0.0023  val_Recall=0.5785  val_Precision=0.2856  val_F1=0.3824  threshold=0.22
# RF_optuna_9           temp_val_AUC=0.6783  rand_val_AUC=0.6812  val_AUC_drop=0.0029  val_Recall=0.6307  val_Precision=0.2721  val_F1=0.3802  threshold=0.49
# RF_optuna_2           temp_val_AUC=0.6785  rand_val_AUC=0.6815  val_AUC_drop=0.0030  val_Recall=0.6302  val_Precision=0.2726  val_F1=0.3805  threshold=0.49
# RF_optuna_5           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0030  val_Recall=0.6284  val_Precision=0.2728  val_F1=0.3805  threshold=0.49
# RF_optuna_3           temp_val_AUC=0.6784  rand_val_AUC=0.6815  val_AUC_drop=0.0031  val_Recall=0.6295  val_Precision=0.2728  val_F1=0.3806  threshold=0.49
# RF_optuna_4           temp_val_AUC=0.6786  rand_val_AUC=0.6817  val_AUC_drop=0.0031  val_Recall=0.6316  val_Precision=0.2723  val_F1=0.3806  threshold=0.49
# RF_optuna_1           temp_val_AUC=0.6785  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6286  val_Precision=0.2732  val_F1=0.3808  threshold=0.49
# RF_optuna_7           temp_val_AUC=0.6784  rand_val_AUC=0.6816  val_AUC_drop=0.0032  val_Recall=0.6292  val_Precision=0.2727  val_F1=0.3805  threshold=0.49
# RF_optuna_8           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6261  val_Precision=0.2736  val_F1=0.3808  threshold=0.49
# RF_optuna_6           temp_val_AUC=0.6785  rand_val_AUC=0.6822  val_AUC_drop=0.0037  val_Recall=0.6262  val_Precision=0.2737  val_F1=0.3809  threshold=0.49
# RF_optuna_10          temp_val_AUC=0.6782  rand_val_AUC=0.6819  val_AUC_drop=0.0037  val_Recall=0.6267  val_Precision=0.2729  val_F1=0.3802  threshold=0.49
# DTree_optuna_1        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_2        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_3        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_4        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_5        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_6        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_7        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_8        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_9        temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# DTree_optuna_10       temp_val_AUC=0.6702  rand_val_AUC=0.6795  val_AUC_drop=0.0094  val_Recall=0.5963  val_Precision=0.2733  val_F1=0.3748  threshold=0.48
# XGB_optuna_3          temp_val_AUC=0.6821  rand_val_AUC=0.6969  val_AUC_drop=0.0149  val_Recall=0.6206  val_Precision=0.2748  val_F1=0.3809  threshold=0.15
# XGB_optuna_8          temp_val_AUC=0.6816  rand_val_AUC=0.6967  val_AUC_drop=0.0150  val_Recall=0.6220  val_Precision=0.2739  val_F1=0.3803  threshold=0.15
# XGB_optuna_9          temp_val_AUC=0.6819  rand_val_AUC=0.6971  val_AUC_drop=0.0152  val_Recall=0.6231  val_Precision=0.2737  val_F1=0.3803  threshold=0.15
# XGB_optuna_1          temp_val_AUC=0.6824  rand_val_AUC=0.6976  val_AUC_drop=0.0153  val_Recall=0.6270  val_Precision=0.2744  val_F1=0.3817  threshold=0.15
# XGB_optuna_2          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6253  val_Precision=0.2748  val_F1=0.3818  threshold=0.15
# XGB_optuna_4          temp_val_AUC=0.6822  rand_val_AUC=0.6975  val_AUC_drop=0.0153  val_Recall=0.6240  val_Precision=0.2741  val_F1=0.3809  threshold=0.15
# XGB_optuna_5          temp_val_AUC=0.6823  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6272  val_Precision=0.2739  val_F1=0.3813  threshold=0.15
# XGB_optuna_6          temp_val_AUC=0.6822  rand_val_AUC=0.6981  val_AUC_drop=0.0159  val_Recall=0.6229  val_Precision=0.2746  val_F1=0.3812  threshold=0.15
# XGB_optuna_7          temp_val_AUC=0.6826  rand_val_AUC=0.6990  val_AUC_drop=0.0163  val_Recall=0.6277  val_Precision=0.2738  val_F1=0.3812  threshold=0.15
# XGB_optuna_10         temp_val_AUC=0.6827  rand_val_AUC=0.6991  val_AUC_drop=0.0164  val_Recall=0.6268  val_Precision=0.2734  val_F1=0.3807  threshold=0.15
#
# === All Models - Test Set (Final) ===
# LR_optuna_5           temp_test_AUC=0.6834  random_test_AUC=0.6891  test_AUC_drop=0.0057  Recall=0.5713  Precision=0.1409  F1=0.2261  threshold=0.26
# LR_optuna_3           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.6048  Precision=0.1381  F1=0.2249  threshold=0.25
# LR_optuna_6           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5959  Precision=0.1387  F1=0.2250  threshold=0.25
# LR_optuna_4           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5905  Precision=0.1390  F1=0.2251  threshold=0.25
# LR_optuna_1           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5757  Precision=0.1404  F1=0.2257  threshold=0.25
# LR_optuna_2           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5659  Precision=0.1415  F1=0.2264  threshold=0.25
# LR_optuna_9           temp_test_AUC=0.6831  random_test_AUC=0.6891  test_AUC_drop=0.0060  Recall=0.6040  Precision=0.1380  F1=0.2247  threshold=0.24
# LR_optuna_7           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5846  Precision=0.1395  F1=0.2253  threshold=0.24
# LR_optuna_8           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5712  Precision=0.1406  F1=0.2256  threshold=0.24
# LR_optuna_10          temp_test_AUC=0.6823  random_test_AUC=0.6891  test_AUC_drop=0.0068  Recall=0.5694  Precision=0.1407  F1=0.2256  threshold=0.22
# XGB_optuna_10         temp_test_AUC=0.6813  random_test_AUC=0.7036  test_AUC_drop=0.0223  Recall=0.6090  Precision=0.1364  F1=0.2229  threshold=0.15
# XGB_optuna_7          temp_test_AUC=0.6812  random_test_AUC=0.7034  test_AUC_drop=0.0221  Recall=0.6087  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_5          temp_test_AUC=0.6810  random_test_AUC=0.7015  test_AUC_drop=0.0205  Recall=0.6090  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_1          temp_test_AUC=0.6810  random_test_AUC=0.7017  test_AUC_drop=0.0207  Recall=0.6093  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_3          temp_test_AUC=0.6810  random_test_AUC=0.7000  test_AUC_drop=0.0190  Recall=0.6017  Precision=0.1370  F1=0.2231  threshold=0.15
# XGB_optuna_2          temp_test_AUC=0.6810  random_test_AUC=0.7012  test_AUC_drop=0.0203  Recall=0.6057  Precision=0.1367  F1=0.2230  threshold=0.15
# XGB_optuna_6          temp_test_AUC=0.6809  random_test_AUC=0.7014  test_AUC_drop=0.0206  Recall=0.6074  Precision=0.1371  F1=0.2237  threshold=0.15
# XGB_optuna_4          temp_test_AUC=0.6808  random_test_AUC=0.7006  test_AUC_drop=0.0197  Recall=0.6063  Precision=0.1366  F1=0.2229  threshold=0.15
# XGB_optuna_9          temp_test_AUC=0.6808  random_test_AUC=0.6998  test_AUC_drop=0.0189  Recall=0.6068  Precision=0.1364  F1=0.2228  threshold=0.15
# XGB_optuna_8          temp_test_AUC=0.6806  random_test_AUC=0.6996  test_AUC_drop=0.0190  Recall=0.6059  Precision=0.1367  F1=0.2231  threshold=0.15
# RF_optuna_5           temp_test_AUC=0.6801  random_test_AUC=0.6879  test_AUC_drop=0.0078  Recall=0.6051  Precision=0.1387  F1=0.2256  threshold=0.49
# RF_optuna_4           temp_test_AUC=0.6800  random_test_AUC=0.6881  test_AUC_drop=0.0081  Recall=0.6080  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_2           temp_test_AUC=0.6800  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6062  Precision=0.1385  F1=0.2255  threshold=0.49
# RF_optuna_1           temp_test_AUC=0.6799  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6040  Precision=0.1386  F1=0.2254  threshold=0.49
# RF_optuna_7           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0079  Recall=0.6054  Precision=0.1387  F1=0.2257  threshold=0.49
# RF_optuna_9           temp_test_AUC=0.6799  random_test_AUC=0.6876  test_AUC_drop=0.0076  Recall=0.6069  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_3           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0078  Recall=0.6052  Precision=0.1386  F1=0.2255  threshold=0.49
# RF_optuna_8           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6035  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_6           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6036  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_10          temp_test_AUC=0.6795  random_test_AUC=0.6880  test_AUC_drop=0.0085  Recall=0.6034  Precision=0.1388  F1=0.2257  threshold=0.49
# DTree_optuna_1        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_2        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_3        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_4        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_5        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_6        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_7        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_8        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_9        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_10       temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
#
# === All Models - Test Robustness (Final) ===
# LR_optuna_5           temp_test_AUC=0.6834  random_test_AUC=0.6891  test_AUC_drop=0.0057  Recall=0.5713  Precision=0.1409  F1=0.2261  threshold=0.26
# LR_optuna_3           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.6048  Precision=0.1381  F1=0.2249  threshold=0.25
# LR_optuna_6           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5959  Precision=0.1387  F1=0.2250  threshold=0.25
# LR_optuna_4           temp_test_AUC=0.6833  random_test_AUC=0.6891  test_AUC_drop=0.0058  Recall=0.5905  Precision=0.1390  F1=0.2251  threshold=0.25
# LR_optuna_1           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5757  Precision=0.1404  F1=0.2257  threshold=0.25
# LR_optuna_2           temp_test_AUC=0.6832  random_test_AUC=0.6891  test_AUC_drop=0.0059  Recall=0.5659  Precision=0.1415  F1=0.2264  threshold=0.25
# LR_optuna_9           temp_test_AUC=0.6831  random_test_AUC=0.6891  test_AUC_drop=0.0060  Recall=0.6040  Precision=0.1380  F1=0.2247  threshold=0.24
# LR_optuna_7           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5846  Precision=0.1395  F1=0.2253  threshold=0.24
# LR_optuna_8           temp_test_AUC=0.6830  random_test_AUC=0.6891  test_AUC_drop=0.0061  Recall=0.5712  Precision=0.1406  F1=0.2256  threshold=0.24
# LR_optuna_10          temp_test_AUC=0.6823  random_test_AUC=0.6891  test_AUC_drop=0.0068  Recall=0.5694  Precision=0.1407  F1=0.2256  threshold=0.22
# RF_optuna_9           temp_test_AUC=0.6799  random_test_AUC=0.6876  test_AUC_drop=0.0076  Recall=0.6069  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_5           temp_test_AUC=0.6801  random_test_AUC=0.6879  test_AUC_drop=0.0078  Recall=0.6051  Precision=0.1387  F1=0.2256  threshold=0.49
# RF_optuna_3           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0078  Recall=0.6052  Precision=0.1386  F1=0.2255  threshold=0.49
# RF_optuna_7           temp_test_AUC=0.6799  random_test_AUC=0.6878  test_AUC_drop=0.0079  Recall=0.6054  Precision=0.1387  F1=0.2257  threshold=0.49
# RF_optuna_2           temp_test_AUC=0.6800  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6062  Precision=0.1385  F1=0.2255  threshold=0.49
# RF_optuna_1           temp_test_AUC=0.6799  random_test_AUC=0.6879  test_AUC_drop=0.0079  Recall=0.6040  Precision=0.1386  F1=0.2254  threshold=0.49
# RF_optuna_4           temp_test_AUC=0.6800  random_test_AUC=0.6881  test_AUC_drop=0.0081  Recall=0.6080  Precision=0.1385  F1=0.2256  threshold=0.49
# RF_optuna_10          temp_test_AUC=0.6795  random_test_AUC=0.6880  test_AUC_drop=0.0085  Recall=0.6034  Precision=0.1388  F1=0.2257  threshold=0.49
# RF_optuna_8           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6035  Precision=0.1387  F1=0.2255  threshold=0.49
# RF_optuna_6           temp_test_AUC=0.6799  random_test_AUC=0.6885  test_AUC_drop=0.0086  Recall=0.6036  Precision=0.1387  F1=0.2255  threshold=0.49
# DTree_optuna_1        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_2        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_3        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_4        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_5        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_6        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_7        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_8        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_9        temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# DTree_optuna_10       temp_test_AUC=0.6675  random_test_AUC=0.6828  test_AUC_drop=0.0153  Recall=0.5739  Precision=0.1368  F1=0.2210  threshold=0.48
# XGB_optuna_9          temp_test_AUC=0.6808  random_test_AUC=0.6998  test_AUC_drop=0.0189  Recall=0.6068  Precision=0.1364  F1=0.2228  threshold=0.15
# XGB_optuna_8          temp_test_AUC=0.6806  random_test_AUC=0.6996  test_AUC_drop=0.0190  Recall=0.6059  Precision=0.1367  F1=0.2231  threshold=0.15
# XGB_optuna_3          temp_test_AUC=0.6810  random_test_AUC=0.7000  test_AUC_drop=0.0190  Recall=0.6017  Precision=0.1370  F1=0.2231  threshold=0.15
# XGB_optuna_4          temp_test_AUC=0.6808  random_test_AUC=0.7006  test_AUC_drop=0.0197  Recall=0.6063  Precision=0.1366  F1=0.2229  threshold=0.15
# XGB_optuna_2          temp_test_AUC=0.6810  random_test_AUC=0.7012  test_AUC_drop=0.0203  Recall=0.6057  Precision=0.1367  F1=0.2230  threshold=0.15
# XGB_optuna_5          temp_test_AUC=0.6810  random_test_AUC=0.7015  test_AUC_drop=0.0205  Recall=0.6090  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_6          temp_test_AUC=0.6809  random_test_AUC=0.7014  test_AUC_drop=0.0206  Recall=0.6074  Precision=0.1371  F1=0.2237  threshold=0.15
# XGB_optuna_1          temp_test_AUC=0.6810  random_test_AUC=0.7017  test_AUC_drop=0.0207  Recall=0.6093  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_7          temp_test_AUC=0.6812  random_test_AUC=0.7034  test_AUC_drop=0.0221  Recall=0.6087  Precision=0.1365  F1=0.2230  threshold=0.15
# XGB_optuna_10         temp_test_AUC=0.6813  random_test_AUC=0.7036  test_AUC_drop=0.0223  Recall=0.6090  Precision=0.1364  F1=0.2229  threshold=0.15
# === Best Model ===
# Best by temporal val AUC: LR_optuna_1
#   val_AUC=0.6859  test_AUC=0.6832  AUC_drop=0.0059
#
# Best by robustness (smallest AUC drop): LR_optuna_5
#   val_AUC=0.6858  test_AUC=0.6834  AUC_drop=0.0057
#
# Best balanced (val_AUC - AUC_drop): LR_optuna_5
#   val_AUC=0.6858  test_AUC=0.6834  AUC_drop=0.0057

# %% [markdown]
# ## 5. Fairness Calculation Function

# %%
def compute_group_metrics_at_threshold(y_true, y_prob, groups, group_col, threshold=0.5):
    """Threshold-aware group metrics including positive prediction rate."""
    records = []
    y_true = np.asarray(y_true)
    y_prob = np.asarray(y_prob)
    y_pred = (y_prob >= threshold).astype(int)

    for g in groups:
        mask = (group_col == g).values
        yt = y_true[mask]
        yp = y_pred[mask]
        ypr = y_prob[mask]

        if len(yt) == 0:
            continue

        tp = ((yp == 1) & (yt == 1)).sum()
        fp = ((yp == 1) & (yt == 0)).sum()
        tn = ((yp == 0) & (yt == 0)).sum()
        fn = ((yp == 0) & (yt == 1)).sum()

        fpr = fp / (fp + tn) if (fp + tn) > 0 else np.nan
        tpr = tp / (tp + fn) if (tp + fn) > 0 else np.nan
        ppr = yp.mean()
        auc = roc_auc_score(yt, ypr) if yt.min() != yt.max() else np.nan

        records.append({
            'group': g,
            'threshold': threshold,
            'FPR': fpr,
            'TPR': tpr,
            'PPR': ppr,
            'AUC': auc,
            'n': mask.sum(),
        })
    return pd.DataFrame(records)

def compute_threshold_sweep(y_true, y_prob, groups, group_col, thresholds):
    records = []
    for thr in thresholds:
        df_thr = compute_group_metrics_at_threshold(y_true, y_prob, groups, group_col, threshold=thr)
        if len(df_thr) == 0:
            continue
        records.append({
            'threshold': thr,
            'FPR_disp': df_thr['FPR'].max() - df_thr['FPR'].min(),
            'TPR_disp': df_thr['TPR'].max() - df_thr['TPR'].min(),
            'PPR_disp': df_thr['PPR'].max() - df_thr['PPR'].min(),
            'avg_PPR': df_thr['PPR'].mean(),
        })
    return pd.DataFrame(records)

FAIRNESS_THRESHOLDS = [0.3, 0.4, 0.5, 0.6, 0.7]
EXPERIMENT_RESULTS = all_results
FAIRNESS_MODELS = list(EXPERIMENT_RESULTS.keys())
fairness_results = {}
val_meta = val_t.copy()  # test_meta → val_meta, test_t → val_t

for name in FAIRNESS_MODELS:
    y_prob_t = EXPERIMENT_RESULTS[name]['temporal']['val_y_prob']  # y_prob → val_y_prob

    fairness_results[name] = {
        'credit': compute_group_metrics_at_threshold(
            y_val_t, y_prob_t, ['short', 'mid', 'long'], val_meta['credit_group'], threshold=0.5),
        'income': compute_group_metrics_at_threshold(
            y_val_t, y_prob_t, ['low', 'mid', 'high'], val_meta['income_group'], threshold=0.5),
        'credit_sweep': compute_threshold_sweep(
            y_val_t, y_prob_t, ['short', 'mid', 'long'], val_meta['credit_group'], FAIRNESS_THRESHOLDS),
        'income_sweep': compute_threshold_sweep(
            y_val_t, y_prob_t, ['low', 'mid', 'high'], val_meta['income_group'], FAIRNESS_THRESHOLDS),
    }

print('Fairness computed for:', list(fairness_results.keys()))
print('Thresholds:', FAIRNESS_THRESHOLDS)
# Out:
# Fairness computed for: ['XGB_optuna_1', 'XGB_optuna_2', 'XGB_optuna_3', 'XGB_optuna_4', 'XGB_optuna_5', 'XGB_optuna_6', 'XGB_optuna_7', 'XGB_optuna_8', 'XGB_optuna_9', 'XGB_optuna_10', 'LR_optuna_1', 'LR_optuna_2', 'LR_optuna_3', 'LR_optuna_4', 'LR_optuna_5', 'LR_optuna_6', 'LR_optuna_7', 'LR_optuna_8', 'LR_optuna_9', 'LR_optuna_10', 'DTree_optuna_1', 'DTree_optuna_2', 'DTree_optuna_3', 'DTree_optuna_4', 'DTree_optuna_5', 'DTree_optuna_6', 'DTree_optuna_7', 'DTree_optuna_8', 'DTree_optuna_9', 'DTree_optuna_10', 'RF_optuna_1', 'RF_optuna_2', 'RF_optuna_3', 'RF_optuna_4', 'RF_optuna_5', 'RF_optuna_6', 'RF_optuna_7', 'RF_optuna_8', 'RF_optuna_9', 'RF_optuna_10']
# Thresholds: [0.3, 0.4, 0.5, 0.6, 0.7]

# %%
rows = []
for name in FAIRNESS_MODELS:
    credit_df = fairness_results[name]['credit']
    income_df = fairness_results[name]['income']
    credit_sweep = fairness_results[name]['credit_sweep']
    income_sweep = fairness_results[name]['income_sweep']
    rows.append({
        'Model':                 name,
        'Temporal Val AUC':      round(EXPERIMENT_RESULTS[name]['temporal']['val_auc'], 4),
        'Val Accuracy':          round(EXPERIMENT_RESULTS[name]['temporal']['val_acc'], 4),
        'Val AUC Drop':          round(EXPERIMENT_RESULTS[name]['val_auc_drop'], 4),
        'Val Recall':            round(EXPERIMENT_RESULTS[name]['temporal']['val_recall'], 4),
        'Val Precision':         round(EXPERIMENT_RESULTS[name]['temporal']['val_precision'], 4),
        'Val F1':                round(EXPERIMENT_RESULTS[name]['temporal']['val_f1'], 4),
        'Temporal AUC':          round(EXPERIMENT_RESULTS[name]['temporal']['auc'], 4),
        'Accuracy':              round(EXPERIMENT_RESULTS[name]['temporal']['acc'], 4),
        'AUC Drop':              round(EXPERIMENT_RESULTS[name]['auc_drop'], 4),
        'Recall':                round(EXPERIMENT_RESULTS[name]['temporal']['recall'], 4),
        'Precision':             round(EXPERIMENT_RESULTS[name]['temporal']['precision'], 4),
        'F1':                    round(EXPERIMENT_RESULTS[name]['temporal']['f1'], 4),
        'Credit FPR_disp@0.5':   round(credit_df['FPR'].max() - credit_df['FPR'].min(), 4),
        'Credit TPR_disp@0.5':   round(credit_df['TPR'].max() - credit_df['TPR'].min(), 4),
        'Credit PPR_disp@0.5':   round(credit_df['PPR'].max() - credit_df['PPR'].min(), 4),
        'Credit AUC_disp':       round(credit_df['AUC'].max() - credit_df['AUC'].min(), 4),
        'Income FPR_disp@0.5':   round(income_df['FPR'].max() - income_df['FPR'].min(), 4),
        'Income TPR_disp@0.5':   round(income_df['TPR'].max() - income_df['TPR'].min(), 4),
        'Income PPR_disp@0.5':   round(income_df['PPR'].max() - income_df['PPR'].min(), 4),
        'Income AUC_disp':       round(income_df['AUC'].max() - income_df['AUC'].min(), 4),
        'Worst Credit FPR_disp': round(credit_sweep['FPR_disp'].max(), 4),
        'Worst Credit TPR_disp': round(credit_sweep['TPR_disp'].max(), 4),
        'Worst Credit PPR_disp': round(credit_sweep['PPR_disp'].max(), 4),
        'Worst Income FPR_disp': round(income_sweep['FPR_disp'].max(), 4),
        'Worst Income TPR_disp': round(income_sweep['TPR_disp'].max(), 4),
        'Worst Income PPR_disp': round(income_sweep['PPR_disp'].max(), 4),
    })

df_fairness_summary = pd.DataFrame(rows).sort_values('Temporal Val AUC', ascending=False)
print('\n=== Threshold-Aware Fairness Summary ===')
print(df_fairness_summary.to_string(index=False))
# Out:
# === Threshold-Aware Fairness Summary ===
#           Model  Temporal Val AUC  Val Accuracy  Val AUC Drop  Val Recall  Val Precision  Val F1  Temporal AUC  Accuracy  AUC Drop  Recall  Precision     F1  Credit FPR_disp@0.5  Credit TPR_disp@0.5  Credit PPR_disp@0.5  Credit AUC_disp  Income FPR_disp@0.5  Income TPR_disp@0.5  Income PPR_disp@0.5  Income AUC_disp  Worst Credit FPR_disp  Worst Credit TPR_disp  Worst Credit PPR_disp  Worst Income FPR_disp  Worst Income TPR_disp  Worst Income PPR_disp
#     LR_optuna_3            0.6859        0.6415        0.0020      0.6162         0.2774  0.3825        0.6833    0.6488    0.0058  0.6048     0.1381 0.2249               0.0000               0.0000               0.0000           0.0222               0.0000               0.0000               0.0000           0.0410                 0.0555                 0.0773                 0.0673                 0.0847                 0.1120                 0.0993
#     LR_optuna_9            0.6859        0.6422        0.0021      0.6148         0.2775  0.3824        0.6831    0.6489    0.0060  0.6040     0.1380 0.2247               0.0000               0.0000               0.0000           0.0223               0.0000               0.0000               0.0000           0.0405                 0.0454                 0.0761                 0.0581                 0.0704                 0.0943                 0.0835
#     LR_optuna_7            0.6859        0.6539        0.0021      0.5954         0.2820  0.3827        0.6830    0.6613    0.0061  0.5846     0.1395 0.2253               0.0000               0.0003               0.0001           0.0223               0.0000               0.0003               0.0001           0.0404                 0.0457                 0.0726                 0.0574                 0.0668                 0.0914                 0.0798
#     LR_optuna_6            0.6859        0.6469        0.0020      0.6075         0.2794  0.3827        0.6833    0.6543    0.0058  0.5959     0.1387 0.2250               0.0000               0.0000               0.0000           0.0222               0.0000               0.0000               0.0000           0.0409                 0.0527                 0.0764                 0.0647                 0.0827                 0.1096                 0.0972
#     LR_optuna_1            0.6859        0.6598        0.0021      0.5876         0.2848  0.3837        0.6832    0.6673    0.0059  0.5757     0.1404 0.2257               0.0000               0.0000               0.0000           0.0223               0.0000               0.0000               0.0000           0.0408                 0.0508                 0.0779                 0.0632                 0.0795                 0.1042                 0.0932
#     LR_optuna_4            0.6859        0.6499        0.0020      0.6020         0.2804  0.3826        0.6833    0.6575    0.0058  0.5905     0.1390 0.2251               0.0000               0.0000               0.0000           0.0222               0.0000               0.0000               0.0000           0.0409                 0.0520                 0.0791                 0.0646                 0.0814                 0.1087                 0.0958
#     LR_optuna_2            0.6859        0.6657        0.0021      0.5764         0.2871  0.3833        0.6832    0.6742    0.0059  0.5659     0.1415 0.2264               0.0000               0.0000               0.0000           0.0223               0.0000               0.0000               0.0000           0.0407                 0.0500                 0.0773                 0.0623                 0.0769                 0.0998                 0.0901
#     LR_optuna_5            0.6858        0.6626        0.0021      0.5838         0.2862  0.3841        0.6834    0.6705    0.0057  0.5713     0.1409 0.2261               0.0000               0.0000               0.0000           0.0222               0.0000               0.0000               0.0000           0.0412                 0.0601                 0.0790                 0.0719                 0.0919                 0.1175                 0.1069
#     LR_optuna_8            0.6858        0.6621        0.0021      0.5829         0.2856  0.3834        0.6830    0.6697    0.0061  0.5712     0.1406 0.2256               0.0000               0.0003               0.0001           0.0223               0.0000               0.0003               0.0001           0.0403                 0.0443                 0.0727                 0.0560                 0.0646                 0.0890                 0.0773
#    LR_optuna_10            0.6856        0.6632        0.0023      0.5785         0.2856  0.3824        0.6823    0.6707    0.0068  0.5694     0.1407 0.2256               0.0000               0.0003               0.0001           0.0224               0.0000               0.0003               0.0001           0.0389                 0.0355                 0.0576                 0.0448                 0.0468                 0.0766                 0.0588
#   XGB_optuna_10            0.6827        0.6326        0.0164      0.6268         0.2734  0.3807        0.6813    0.6423    0.0223  0.6090     0.1364 0.2229               0.0000               0.0000               0.0000           0.0240               0.0000               0.0000               0.0000           0.0434                 0.0137                 0.0340                 0.0193                 0.0336                 0.0937                 0.0464
#    XGB_optuna_7            0.6826        0.6328        0.0163      0.6277         0.2738  0.3812        0.6812    0.6427    0.0221  0.6087     0.1365 0.2230               0.0000               0.0000               0.0000           0.0242               0.0000               0.0000               0.0000           0.0436                 0.0112                 0.0330                 0.0172                 0.0293                 0.0841                 0.0411
#    XGB_optuna_1            0.6824        0.6340        0.0153      0.6270         0.2744  0.3817        0.6810    0.6424    0.0207  0.6093     0.1365 0.2230               0.0000               0.0000               0.0000           0.0235               0.0000               0.0000               0.0000           0.0435                 0.0051                 0.0151                 0.0079                 0.0161                 0.0513                 0.0234
#    XGB_optuna_5            0.6823        0.6331        0.0159      0.6272         0.2739  0.3813        0.6810    0.6425    0.0205  0.6090     0.1365 0.2230               0.0000               0.0000               0.0000           0.0239               0.0000               0.0000               0.0000           0.0438                 0.0043                 0.0151                 0.0072                 0.0129                 0.0477                 0.0202
#    XGB_optuna_2            0.6822        0.6350        0.0153      0.6253         0.2748  0.3818        0.6810    0.6445    0.0203  0.6057     0.1367 0.2230               0.0000               0.0000               0.0000           0.0237               0.0000               0.0000               0.0000           0.0434                 0.0051                 0.0148                 0.0078                 0.0144                 0.0503                 0.0219
#    XGB_optuna_6            0.6822        0.6356        0.0159      0.6229         0.2746  0.3812        0.6809    0.6449    0.0206  0.6074     0.1371 0.2237               0.0000               0.0000               0.0000           0.0238               0.0000               0.0000               0.0000           0.0436                 0.0045                 0.0127                 0.0068                 0.0125                 0.0433                 0.0189
#    XGB_optuna_4            0.6822        0.6345        0.0153      0.6240         0.2741  0.3809        0.6808    0.6439    0.0197  0.6063     0.1366 0.2229               0.0000               0.0000               0.0000           0.0239               0.0000               0.0000               0.0000           0.0437                 0.0029                 0.0121                 0.0053                 0.0091                 0.0356                 0.0147
#    XGB_optuna_3            0.6821        0.6365        0.0149      0.6206         0.2748  0.3809        0.6810    0.6471    0.0190  0.6017     0.1370 0.2231               0.0000               0.0000               0.0000           0.0238               0.0000               0.0000               0.0000           0.0436                 0.0003                 0.0016                 0.0005                 0.0016                 0.0075                 0.0028
#    XGB_optuna_9            0.6819        0.6341        0.0152      0.6231         0.2737  0.3803        0.6808    0.6433    0.0189  0.6068     0.1364 0.2228               0.0000               0.0000               0.0000           0.0239               0.0000               0.0000               0.0000           0.0439                 0.0001                 0.0012                 0.0004                 0.0007                 0.0034                 0.0012
#    XGB_optuna_8            0.6816        0.6347        0.0150      0.6220         0.2739  0.3803        0.6806    0.6446    0.0190  0.6059     0.1367 0.2231               0.0000               0.0000               0.0000           0.0235               0.0000               0.0000               0.0000           0.0434                 0.0009                 0.0022                 0.0009                 0.0027                 0.0106                 0.0044
#     RF_optuna_4            0.6786        0.6295        0.0031      0.6316         0.2723  0.3806        0.6800    0.6483    0.0081  0.6080     0.1385 0.2256               0.1214               0.1187               0.1321           0.0217               0.2157               0.1584               0.2196           0.0437                 0.1214                 0.1187                 0.1321                 0.2157                 0.1584                 0.2196
#     RF_optuna_2            0.6785        0.6303        0.0030      0.6302         0.2726  0.3805        0.6800    0.6493    0.0079  0.6062     0.1385 0.2255               0.1225               0.1177               0.1328           0.0218               0.2190               0.1613               0.2228           0.0438                 0.1225                 0.1177                 0.1328                 0.2190                 0.1613                 0.2228
#     RF_optuna_1            0.6785        0.6317        0.0032      0.6286         0.2732  0.3808        0.6799    0.6503    0.0079  0.6040     0.1386 0.2254               0.1221               0.1194               0.1328           0.0218               0.2181               0.1604               0.2219           0.0439                 0.1221                 0.1194                 0.1328                 0.2181                 0.1604                 0.2219
#     RF_optuna_5            0.6785        0.6312        0.0030      0.6284         0.2728  0.3805        0.6801    0.6501    0.0078  0.6051     0.1387 0.2256               0.1223               0.1198               0.1330           0.0218               0.2176               0.1590               0.2211           0.0440                 0.1223                 0.1198                 0.1330                 0.2176                 0.1590                 0.2211
#     RF_optuna_8            0.6785        0.6331        0.0037      0.6261         0.2736  0.3808        0.6799    0.6508    0.0086  0.6035     0.1387 0.2255               0.1210               0.1193               0.1319           0.0216               0.2122               0.1555               0.2161           0.0441                 0.1210                 0.1193                 0.1319                 0.2122                 0.1555                 0.2161
#     RF_optuna_6            0.6785        0.6331        0.0037      0.6262         0.2737  0.3809        0.6799    0.6508    0.0086  0.6036     0.1387 0.2255               0.1211               0.1193               0.1319           0.0216               0.2123               0.1555               0.2162           0.0441                 0.1211                 0.1193                 0.1319                 0.2123                 0.1555                 0.2162
#     RF_optuna_7            0.6784        0.6308        0.0032      0.6292         0.2727  0.3805        0.6799    0.6501    0.0079  0.6054     0.1387 0.2257               0.1239               0.1184               0.1341           0.0219               0.2222               0.1675               0.2265           0.0439                 0.1239                 0.1184                 0.1341                 0.2222                 0.1675                 0.2265
#     RF_optuna_3            0.6784        0.6308        0.0031      0.6295         0.2728  0.3806        0.6799    0.6499    0.0078  0.6052     0.1386 0.2255               0.1230               0.1180               0.1333           0.0218               0.2181               0.1617               0.2221           0.0438                 0.1230                 0.1180                 0.1333                 0.2181                 0.1617                 0.2221
#     RF_optuna_9            0.6783        0.6294        0.0029      0.6307         0.2721  0.3802        0.6799    0.6490    0.0076  0.6069     0.1385 0.2256               0.1236               0.1168               0.1335           0.0219               0.2194               0.1630               0.2234           0.0438                 0.1236                 0.1168                 0.1335                 0.2194                 0.1630                 0.2234
#    RF_optuna_10            0.6782        0.6318        0.0037      0.6267         0.2729  0.3802        0.6795    0.6512    0.0085  0.6034     0.1388 0.2257               0.1240               0.1164               0.1337           0.0218               0.2242               0.1695               0.2283           0.0436                 0.1240                 0.1164                 0.1337                 0.2242                 0.1695                 0.2283
#  DTree_optuna_2            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_1            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_4            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_3            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_9            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
# DTree_optuna_10            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_6            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_5            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_7            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442
#  DTree_optuna_8            0.6702        0.6415        0.0094      0.5963         0.2733  0.3748        0.6675    0.6591    0.0153  0.5739     0.1368 0.2210               0.1869               0.1577               0.1923           0.0232               0.4407               0.3884               0.4442           0.0422                 0.1869                 0.1577                 0.1923                 0.4407                 0.3884                 0.4442

# %%
# Inspect threshold-sweep fairness for the top overall models
candidate_models = df_fairness_summary.head(3)['Model'].tolist()

for model_name in candidate_models:
    print(f'\n=== {model_name} : Credit Threshold Sweep ===')
    print(fairness_results[model_name]['credit_sweep'].to_string(index=False))
    print(f'\n=== {model_name} : Income Threshold Sweep ===')
    print(fairness_results[model_name]['income_sweep'].to_string(index=False))
# Out:
# === LR_optuna_3 : Credit Threshold Sweep ===
#  threshold  FPR_disp  TPR_disp  PPR_disp  avg_PPR
#        0.3  0.055482  0.077308  0.067294 0.156235
#        0.4  0.006064  0.017753  0.009063 0.009935
#        0.5  0.000000  0.000000  0.000000 0.000000
#        0.6  0.000000  0.000000  0.000000 0.000000
#        0.7  0.000000  0.000000  0.000000 0.000000
#
# === LR_optuna_3 : Income Threshold Sweep ===
#  threshold  FPR_disp  TPR_disp  PPR_disp  avg_PPR
#        0.3  0.084667  0.111985  0.099253 0.153953
#        0.4  0.004303  0.008154  0.006085 0.009432
#        0.5  0.000000  0.000000  0.000000 0.000000
#        0.6  0.000000  0.000000  0.000000 0.000000
#        0.7  0.000000  0.000000  0.000000 0.000000
#
# === LR_optuna_9 : Credit Threshold Sweep ===
#  threshold  FPR_disp  TPR_disp  PPR_disp  avg_PPR
#        0.3  0.045432  0.076114  0.058061 0.131609
#        0.4  0.005338  0.017486  0.008336 0.008898
#        0.5  0.000000  0.000000  0.000000 0.000000
#        0.6  0.000000  0.000000  0.000000 0.000000
#        0.7  0.000000  0.000000  0.000000 0.000000
#
# === LR_optuna_9 : Income Threshold Sweep ===
#  threshold  FPR_disp  TPR_disp  PPR_disp  avg_PPR
#        0.3  0.070386  0.094343  0.083486 0.129541
#        0.4  0.003947  0.009822  0.005938 0.008445
#        0.5  0.000000  0.000000  0.000000 0.000000
#        0.6  0.000000  0.000000  0.000000 0.000000
#        0.7  0.000000  0.000000  0.000000 0.000000
#
# === LR_optuna_7 : Credit Threshold Sweep ===
#  threshold  FPR_disp  TPR_disp  PPR_disp  avg_PPR
#        0.3  0.045706  0.072564  0.057385 0.125377
#        0.4  0.005353  0.016832  0.008217 0.008733
#        0.5  0.000000  0.000279  0.000051 0.000017
#        0.6  0.000000  0.000000  0.000000 0.000000
#        0.7  0.000000  0.000000  0.000000 0.000000
#
# === LR_optuna_7 : Income Threshold Sweep ===
#  threshold  FPR_disp  TPR_disp  PPR_disp  avg_PPR
#        0.3  0.066805  0.091444  0.079797 0.123232
#        0.4  0.003675  0.009871  0.005715 0.008283
#        0.5  0.000000  0.000300  0.000056 0.000019
#        0.6  0.000000  0.000000  0.000000 0.000000
#        0.7  0.000000  0.000000  0.000000 0.000000

# %% [markdown]
# ## 6. Final Model Selection

# %%
df = df_fairness_summary.copy()

def minmax(col):
    return (col - col.min()) / (col.max() - col.min() + 1e-9)

df['_auc_drop_norm'] = minmax(df['Val AUC Drop'])
df['_auc_perf_norm'] = minmax(-df['Temporal Val AUC'])
df['_f1_norm'] = minmax(-df['Val F1'])

df['_credit_fpr_norm'] = minmax(df['Worst Credit FPR_disp'])
df['_income_fpr_norm'] = minmax(df['Worst Income FPR_disp'])
df['_credit_tpr_norm'] = minmax(df['Worst Credit TPR_disp'])
df['_income_tpr_norm'] = minmax(df['Worst Income TPR_disp'])
df['_credit_ppr_norm'] = minmax(df['Worst Credit PPR_disp'])
df['_income_ppr_norm'] = minmax(df['Worst Income PPR_disp'])

df['_fair_norm'] = (
    df['_credit_fpr_norm'] + df['_income_fpr_norm'] +
    df['_credit_tpr_norm'] + df['_income_tpr_norm'] +
    df['_credit_ppr_norm'] + df['_income_ppr_norm']
) / 6

w_robustness = 0.20
w_performance = 0.30
w_f1 = 0.30
w_fairness = 0.20

df['composite_score'] = (
    w_robustness * df['_auc_drop_norm'] +
    w_performance * df['_auc_perf_norm'] +
    w_f1 * df['_f1_norm'] +
    w_fairness * df['_fair_norm']
)

df_ranked = df[[
    'Model', 'Temporal Val AUC', 'Val AUC Drop', 'Val F1',
    'Temporal AUC', 'Accuracy', 'AUC Drop', 'F1',
    'Worst Credit FPR_disp', 'Worst Income FPR_disp',
    'Worst Credit TPR_disp', 'Worst Income TPR_disp',
    'Worst Credit PPR_disp', 'Worst Income PPR_disp',
    '_fair_norm', 'composite_score'
]].sort_values('composite_score')

print('=== Best Model Ranking (lower score = better) ===')
print(df_ranked.to_string(index=False))
print(f'\n★ Best Model: {df_ranked.iloc[0]["Model"]}')
# Out:
# === Best Model Ranking (lower score = better) ===
#           Model  Temporal Val AUC  Val AUC Drop  Val F1  Temporal AUC  Accuracy  AUC Drop     F1  Worst Credit FPR_disp  Worst Income FPR_disp  Worst Credit TPR_disp  Worst Income TPR_disp  Worst Credit PPR_disp  Worst Income PPR_disp  _fair_norm  composite_score
#     LR_optuna_5            0.6858        0.0021  0.3841        0.6834    0.6705    0.0057 0.2261                 0.0601                 0.0919                 0.0790                 0.1175                 0.0719                 0.1069    0.322192         0.067738
#     LR_optuna_1            0.6859        0.0021  0.3837        0.6832    0.6673    0.0059 0.2257                 0.0508                 0.0795                 0.0779                 0.1042                 0.0632                 0.0932    0.289558         0.072204
#     LR_optuna_8            0.6858        0.0021  0.3834        0.6830    0.6697    0.0061 0.2256                 0.0443                 0.0646                 0.0727                 0.0890                 0.0560                 0.0773    0.253761         0.076633
#     LR_optuna_2            0.6859        0.0021  0.3833        0.6832    0.6742    0.0059 0.2264                 0.0500                 0.0769                 0.0773                 0.0998                 0.0623                 0.0901    0.283368         0.083869
#     LR_optuna_7            0.6859        0.0021  0.3827        0.6830    0.6613    0.0061 0.2253                 0.0457                 0.0668                 0.0726                 0.0914                 0.0574                 0.0798    0.258933         0.098337
#     LR_optuna_6            0.6859        0.0020  0.3827        0.6833    0.6543    0.0058 0.2250                 0.0527                 0.0827                 0.0764                 0.1096                 0.0647                 0.0972    0.296013         0.104364
#    LR_optuna_10            0.6856        0.0023  0.3824        0.6823    0.6707    0.0068 0.2256                 0.0355                 0.0468                 0.0576                 0.0766                 0.0448                 0.0588    0.201031         0.104944
#     LR_optuna_4            0.6859        0.0020  0.3826        0.6833    0.6575    0.0058 0.2251                 0.0520                 0.0814                 0.0791                 0.1087                 0.0646                 0.0958    0.296768         0.107741
#     LR_optuna_9            0.6859        0.0021  0.3824        0.6831    0.6489    0.0060 0.2247                 0.0454                 0.0704                 0.0761                 0.0943                 0.0581                 0.0835    0.267011         0.109630
#     LR_optuna_3            0.6859        0.0020  0.3825        0.6833    0.6488    0.0058 0.2249                 0.0555                 0.0847                 0.0773                 0.1120                 0.0673                 0.0993    0.304314         0.112476
#    XGB_optuna_1            0.6824        0.0153  0.3817        0.6810    0.6424    0.0207 0.2230                 0.0051                 0.0161                 0.0151                 0.0513                 0.0079                 0.0234    0.060699         0.341160
#    XGB_optuna_2            0.6822        0.0153  0.3818        0.6810    0.6445    0.0203 0.2230                 0.0051                 0.0144                 0.0148                 0.0503                 0.0078                 0.0219    0.058652         0.341347
#    XGB_optuna_3            0.6821        0.0149  0.3809        0.6810    0.6471    0.0190 0.2231                 0.0003                 0.0016                 0.0016                 0.0075                 0.0005                 0.0028    0.003409         0.355686
#    XGB_optuna_5            0.6823        0.0159  0.3813        0.6810    0.6425    0.0205 0.2230                 0.0043                 0.0129                 0.0151                 0.0477                 0.0072                 0.0202    0.055403         0.363249
#    XGB_optuna_4            0.6822        0.0153  0.3809        0.6808    0.6439    0.0197 0.2229                 0.0029                 0.0091                 0.0121                 0.0356                 0.0053                 0.0147    0.040562         0.366761
#    XGB_optuna_6            0.6822        0.0159  0.3812        0.6809    0.6449    0.0206 0.2237                 0.0045                 0.0125                 0.0127                 0.0433                 0.0068                 0.0189    0.050133         0.367331
#    XGB_optuna_7            0.6826        0.0163  0.3812        0.6812    0.6427    0.0221 0.2230                 0.0112                 0.0293                 0.0330                 0.0841                 0.0172                 0.0411    0.119140         0.379045
#     RF_optuna_1            0.6785        0.0032  0.3808        0.6799    0.6503    0.0079 0.2254                 0.1221                 0.2181                 0.1194                 0.1604                 0.1328                 0.2219    0.583066         0.381133
#    XGB_optuna_9            0.6819        0.0152  0.3803        0.6808    0.6433    0.0189 0.2228                 0.0001                 0.0007                 0.0012                 0.0034                 0.0004                 0.0012    0.000000         0.382347
#     RF_optuna_6            0.6785        0.0037  0.3809        0.6799    0.6508    0.0086 0.2255                 0.1211                 0.2123                 0.1193                 0.1555                 0.1319                 0.2162    0.574823         0.383203
#     RF_optuna_4            0.6786        0.0031  0.3806        0.6800    0.6483    0.0081 0.2256                 0.1214                 0.2157                 0.1187                 0.1584                 0.1321                 0.2196    0.578448         0.383361
#     RF_optuna_8            0.6785        0.0037  0.3808        0.6799    0.6508    0.0086 0.2255                 0.1210                 0.2122                 0.1193                 0.1555                 0.1319                 0.2161    0.574658         0.386396
#    XGB_optuna_8            0.6816        0.0150  0.3803        0.6806    0.6446    0.0190 0.2231                 0.0009                 0.0027                 0.0022                 0.0106                 0.0009                 0.0044    0.007291         0.386760
#     RF_optuna_2            0.6785        0.0030  0.3805        0.6800    0.6493    0.0079 0.2255                 0.1225                 0.2190                 0.1177                 0.1613                 0.1328                 0.2228    0.582682         0.387956
#     RF_optuna_5            0.6785        0.0030  0.3805        0.6801    0.6501    0.0078 0.2256                 0.1223                 0.2176                 0.1198                 0.1590                 0.1330                 0.2211    0.582748         0.387969
#     RF_optuna_3            0.6784        0.0031  0.3806        0.6799    0.6499    0.0078 0.2255                 0.1230                 0.2181                 0.1180                 0.1617                 0.1333                 0.2221    0.583450         0.388183
#     RF_optuna_7            0.6784        0.0032  0.3805        0.6799    0.6501    0.0079 0.2257                 0.1239                 0.2222                 0.1184                 0.1675                 0.1341                 0.2265    0.591093         0.394326
#   XGB_optuna_10            0.6827        0.0164  0.3807        0.6813    0.6423    0.0223 0.2229                 0.0137                 0.0336                 0.0340                 0.0937                 0.0193                 0.0464    0.132038         0.397231
#     RF_optuna_9            0.6783        0.0029  0.3802        0.6799    0.6490    0.0076 0.2256                 0.1236                 0.2194                 0.1168                 0.1630                 0.1335                 0.2234    0.584426         0.400415
#    RF_optuna_10            0.6782        0.0037  0.3802        0.6795    0.6512    0.0085 0.2257                 0.1240                 0.2242                 0.1164                 0.1695                 0.1337                 0.2283    0.591006         0.414752
#  DTree_optuna_2            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_1            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_4            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_3            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_9            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
# DTree_optuna_10            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_6            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_5            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_7            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#  DTree_optuna_8            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#
# ★ Best Model: LR_optuna_5

# %%
# Overall model comparison table from the combined experiment set
result_rows = []
for name, res in all_results.items():
    result_rows.append({
        'Model': name,
        'Temporal Val AUC': round(res['temporal']['val_auc'], 4),
        'Temporal AUC': round(res['temporal']['auc'], 4),
        'Random AUC': round(res['random']['auc'], 4),
        'AUC Drop': round(res['auc_drop'], 4),
        'Accuracy': round(res['temporal']['acc'], 4),
        'Brier Score': round(res['temporal']['brier'], 4),
    })

df_results = pd.DataFrame(result_rows).sort_values('Temporal Val AUC', ascending=False)

FAMILY_PREFIXES = {
    'Logistic Regression': ['LR_'],
    'Decision Tree': ['DTree_'],
    'Random Forest': ['RF_'],
    'XGBoost': ['XGB_'],
}

def infer_family(model_name):
    for family, prefixes in FAMILY_PREFIXES.items():
        if any(model_name.startswith(prefix) for prefix in prefixes):
            return family
    return 'Other'

REPRESENTATIVE_MODELS = []
representative_rows = []
for family, prefixes in FAMILY_PREFIXES.items():
    subset = df_ranked[df_ranked['Model'].apply(lambda m: any(m.startswith(prefix) for prefix in prefixes))].copy()
    if not subset.empty:
        best_model = subset.iloc[0]['Model']
        REPRESENTATIVE_MODELS.append(best_model)
        representative_rows.append({'Family': family, 'Model': best_model})

df_representatives = df_results[df_results['Model'].isin(REPRESENTATIVE_MODELS)].copy()
df_representatives['Family'] = df_representatives['Model'].apply(infer_family)
df_representatives['Model'] = pd.Categorical(df_representatives['Model'], categories=REPRESENTATIVE_MODELS, ordered=True)
df_representatives = df_representatives.sort_values('Model')
representative_lookup = pd.DataFrame(representative_rows)

print('=== Full Model Comparison Table ===')
print(df_results.to_string(index=False))
print('\nRepresentative models for plotting:', REPRESENTATIVE_MODELS)
print('\nBest representative by family:')
print(representative_lookup.to_string(index=False))
# Out:
# === Full Model Comparison Table ===
#           Model  Temporal Val AUC  Temporal AUC  Random AUC  AUC Drop  Accuracy  Brier Score
#     LR_optuna_3            0.6859        0.6833      0.6891    0.0058    0.6488       0.0990
#     LR_optuna_9            0.6859        0.6831      0.6891    0.0060    0.6489       0.0962
#     LR_optuna_7            0.6859        0.6830      0.6891    0.0061    0.6613       0.0954
#     LR_optuna_6            0.6859        0.6833      0.6891    0.0058    0.6543       0.0986
#     LR_optuna_1            0.6859        0.6832      0.6891    0.0059    0.6673       0.0978
#     LR_optuna_4            0.6859        0.6833      0.6891    0.0058    0.6575       0.0984
#     LR_optuna_2            0.6859        0.6832      0.6891    0.0059    0.6742       0.0973
#     LR_optuna_5            0.6858        0.6834      0.6891    0.0057    0.6705       0.1005
#     LR_optuna_8            0.6858        0.6830      0.6891    0.0061    0.6697       0.0949
#    LR_optuna_10            0.6856        0.6823      0.6891    0.0068    0.6707       0.0901
#   XGB_optuna_10            0.6827        0.6813      0.7036    0.0223    0.6423       0.0783
#    XGB_optuna_7            0.6826        0.6812      0.7034    0.0221    0.6427       0.0783
#    XGB_optuna_1            0.6824        0.6810      0.7017    0.0207    0.6424       0.0782
#    XGB_optuna_5            0.6823        0.6810      0.7015    0.0205    0.6425       0.0782
#    XGB_optuna_2            0.6822        0.6810      0.7012    0.0203    0.6445       0.0782
#    XGB_optuna_6            0.6822        0.6809      0.7014    0.0206    0.6449       0.0781
#    XGB_optuna_4            0.6822        0.6808      0.7006    0.0197    0.6439       0.0782
#    XGB_optuna_3            0.6821        0.6810      0.7000    0.0190    0.6471       0.0781
#    XGB_optuna_9            0.6819        0.6808      0.6998    0.0189    0.6433       0.0781
#    XGB_optuna_8            0.6816        0.6806      0.6996    0.0190    0.6446       0.0781
#     RF_optuna_4            0.6786        0.6800      0.6881    0.0081    0.6483       0.2196
#     RF_optuna_2            0.6785        0.6800      0.6879    0.0079    0.6493       0.2194
#     RF_optuna_1            0.6785        0.6799      0.6879    0.0079    0.6503       0.2192
#     RF_optuna_5            0.6785        0.6801      0.6879    0.0078    0.6501       0.2193
#     RF_optuna_8            0.6785        0.6799      0.6885    0.0086    0.6508       0.2194
#     RF_optuna_6            0.6785        0.6799      0.6885    0.0086    0.6508       0.2194
#     RF_optuna_7            0.6784        0.6799      0.6878    0.0079    0.6501       0.2193
#     RF_optuna_3            0.6784        0.6799      0.6878    0.0078    0.6499       0.2194
#     RF_optuna_9            0.6783        0.6799      0.6876    0.0076    0.6490       0.2196
#    RF_optuna_10            0.6782        0.6795      0.6880    0.0085    0.6512       0.2192
#  DTree_optuna_2            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_1            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_4            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_3            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_9            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
# DTree_optuna_10            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_6            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_5            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_7            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#  DTree_optuna_8            0.6702        0.6675      0.6828    0.0153    0.6591       0.2088
#
# Representative models for plotting: ['LR_optuna_5', 'DTree_optuna_2', 'RF_optuna_1', 'XGB_optuna_1']
#
# Best representative by family:
#              Family          Model
# Logistic Regression    LR_optuna_5
#       Decision Tree DTree_optuna_2
#       Random Forest    RF_optuna_1
#             XGBoost   XGB_optuna_1

# %% [markdown]
# ## 7. Visualization

# %%
fig, ax = plt.subplots(figsize=(14, 5))

model_names = df_results['Model'].tolist()
t_aucs = df_results['Temporal AUC'].tolist()
r_aucs = df_results['Random AUC'].tolist()

family_colors = {
    'Logistic Regression': ('steelblue', 'lightsteelblue'),
    'Decision Tree': ('darkorange', 'moccasin'),
    'Random Forest': ('seagreen', 'lightgreen'),
    'XGBoost': ('firebrick', 'lightsalmon'),
}

x = np.arange(len(model_names))
for i, name in enumerate(model_names):
    family = infer_family(name)
    c1, c2 = family_colors.get(family, ('gray', 'lightgray'))
    ax.bar(x[i] - 0.2, t_aucs[i], width=0.35, color=c1)
    ax.bar(x[i] + 0.2, r_aucs[i], width=0.35, color=c2)

# 범례
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='steelblue',  label='LR Temporal'),
    Patch(facecolor='lightsteelblue', label='LR Random'),
    Patch(facecolor='darkorange', label='DTree Temporal'),
    Patch(facecolor='moccasin',   label='DTree Random'),
    Patch(facecolor='seagreen',   label='RF Temporal'),
    Patch(facecolor='lightgreen', label='RF Random'),
    Patch(facecolor='firebrick',  label='XGB Temporal'),
    Patch(facecolor='lightsalmon',label='XGB Random'),
]
ax.legend(handles=legend_elements, fontsize=8, ncol=4)

ax.set_xticks(x)
ax.set_xticklabels(model_names, rotation=30, ha='right', fontsize=9)
ax.set_ylim(0.60, 0.80)
ax.set_ylabel('AUC')
ax.set_title('Fig 1. Temporal vs Random AUC — All Models')
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))
plt.tight_layout()
plt.savefig('/content/fig1_auc_comparison.png', dpi=150)
plt.show()

# %%
# ═══════════════════════════════════════════════════════════════════════
# Figure 2: AUC Drop (Temporal how much decrease)
# ═══════════════════════════════════════════════════════════════════════
fig, ax = plt.subplots(figsize=(14, 4))

drops = df_results['AUC Drop'].tolist()
colors = ['tomato' if d > 0 else 'seagreen' for d in drops]

ax.bar(model_names, drops, color=colors)
ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
ax.set_xticks(np.arange(len(model_names)))
ax.set_xticklabels(model_names, rotation=30, ha='right', fontsize=9)
ax.set_ylabel('AUC Drop (Random − Temporal)')
ax.set_title('Fig 2. AUC Drop per Model\n(The higher the value, the more vulnerable it is to temporal shifts.)')
plt.tight_layout()
plt.savefig('/content/fig2_auc_drop.png', dpi=150)
plt.show()

# %%
# ── Fig 3 ──────────────────────────────────────────────────────────────
family_order = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'XGBoost']
family_display = {
    'Logistic Regression': 'Logistic Regression',
    'Decision Tree': 'Decision Tree',
    'Random Forest': 'Random Forest',
    'XGBoost': 'XGBoost',
}
family_colors = {
    'Logistic Regression': '#1f77b4',
    'Decision Tree': '#ff7f0e',
    'Random Forest': '#2ca02c',
    'XGBoost': '#d62728',
}

plot_df = df_representatives.copy()
plot_df['Family'] = plot_df['Model'].apply(infer_family)
plot_df['Family'] = pd.Categorical(plot_df['Family'], categories=family_order, ordered=True)
plot_df = plot_df.sort_values('Family').copy()
plot_df['Display'] = plot_df['Family'].map(family_display)

FAIR_MODELS_PLOT = plot_df['Model'].tolist()
FAIR_FAMILIES_PLOT = plot_df['Family'].astype(str).tolist()
FAIR_LABELS_PLOT = plot_df['Display'].tolist()
colors_fair = [family_colors.get(f, '#9467bd') for f in FAIR_FAMILIES_PLOT]

x = np.arange(len(plot_df))
width = 0.35
fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(x - width/2, plot_df['Temporal AUC'], width=width, label='Temporal Test AUC', color='#1f77b4')
ax.bar(x + width/2, plot_df['Random AUC'], width=width, label='Random Test AUC', color='#ff7f0e')
ax.set_xticks(x)
ax.set_xticklabels(plot_df['Display'], rotation=20, ha='right')
ax.set_ylabel('AUC')
ax.set_title('Fig 3. Temporal vs Random Test AUC')
ax.legend()
plt.tight_layout()
plt.savefig('/content/fig3_auc_comparison.png', dpi=150)
plt.show()

# %%
# ── Fig 4 ──────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(plot_df['Display'], plot_df['AUC Drop'], color=[family_colors.get(f, '#2ca02c') for f in plot_df['Family'].astype(str)])
ax.set_ylabel('Random AUC - Temporal AUC')
ax.set_title('Fig 4. Temporal Robustness (AUC Drop)')
ax.tick_params(axis='x', rotation=20)
plt.tight_layout()
plt.savefig('/content/fig4_auc_drop.png', dpi=150)
plt.show()

# %%
# ── Fig 5 ──────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(12, 5))
for mname, family_label in zip(FAIR_MODELS_PLOT, FAIR_LABELS_PLOT):
    year_map = all_results[mname]['yearly']
    years = sorted(year_map.keys())
    vals = [year_map[y] for y in years]
    ax.plot(years, vals, marker='o', label=family_label)
ax.set_xlabel('Issue Year')
ax.set_ylabel('Temporal AUC')
ax.set_title('Fig 5. Annual Temporal AUC Trend')
ax.legend(fontsize=8)
plt.tight_layout()
plt.savefig('/content/fig5_auc_over_time.png', dpi=150)
plt.show()

# %%
# ── Fig 5 ──────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(12, 5))
fig4_df = df_representatives.sort_values('Temporal Val AUC', ascending=False).copy()
fig4_df['Family'] = fig4_df['Model'].apply(infer_family)
fig4_df['Display'] = fig4_df['Family'].map(family_display)
ax.bar(fig4_df['Display'], fig4_df['Temporal Val AUC'], color=[family_colors.get(f, '#9467bd') for f in fig4_df['Family']])
ax.set_ylabel('Temporal Validation AUC')
ax.set_title('Fig 6. Best Temporal Validation AUC by Model Family')
ax.tick_params(axis='x', rotation=20)
plt.tight_layout()
plt.savefig('/content/fig6_validation_auc.png', dpi=150)
plt.show()

# %%
# ── Fig 7 ──────────────────────────────────────────────────────────────
FAIR_MODELS_PLOT = REPRESENTATIVE_MODELS.copy()
family_map = dict(zip(representative_lookup['Model'], representative_lookup['Family']))
FAIR_LABELS_PLOT = [family_display.get(family_map.get(m, ''), m) for m in FAIR_MODELS_PLOT]
colors_fair = [family_colors.get(family_map.get(m, ''), '#9467bd') for m in FAIR_MODELS_PLOT]

credit_groups = ['short', 'mid', 'long']
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
metrics = ['FPR', 'TPR', 'PPR']
for ax_i, metric in enumerate(metrics):
    x = np.arange(len(credit_groups))
    width = 0.14
    for j, (mname, family_label, col) in enumerate(zip(FAIR_MODELS_PLOT, FAIR_LABELS_PLOT, colors_fair)):
        df_f = fairness_results.get(mname, {}).get('credit', pd.DataFrame(columns=['group'] + metrics))
        vals = df_f.set_index('group').reindex(credit_groups)[metric].fillna(0).tolist()
        offset = (j - len(FAIR_MODELS_PLOT) / 2) * width
        bars = axes[ax_i].bar(x + offset, vals, width=width, label=family_label, color=col)
        for bar, val in zip(bars, vals):
            axes[ax_i].text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.002,
                f'{val:.3f}',
                ha='center',
                va='bottom',
                fontsize=6,
                rotation=90
            )
    axes[ax_i].set_xticks(x)
    axes[ax_i].set_xticklabels(credit_groups)
    axes[ax_i].set_title(f'Fig 5{chr(97+ax_i)}. {metric} by Credit Group')
    axes[ax_i].set_ylabel(metric)
    if ax_i == 0:
        axes[ax_i].legend(fontsize=7)
plt.tight_layout()
plt.savefig('/content/fig7_fairness_credit.png', dpi=150)
plt.show()

# %%
# Figure 4 alternate view: sorted high-to-low with a careful zoomed y-axis
fig4_alt_df = df_representatives.copy()
fig4_alt_df['Family'] = fig4_alt_df['Model'].apply(infer_family)
fig4_alt_df['Display'] = fig4_alt_df['Family'].map(family_display)
fig4_alt_df = fig4_alt_df.sort_values('Temporal Val AUC', ascending=False).copy()

ymin = max(0.0, fig4_alt_df['Temporal Val AUC'].min() - 0.01)
ymax = min(1.0, fig4_alt_df['Temporal Val AUC'].max() + 0.01)

fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(
    fig4_alt_df['Display'],
    fig4_alt_df['Temporal Val AUC'],
    color=[family_colors.get(f, '#9467bd') for f in fig4_alt_df['Family']]
)
ax.set_ylabel('Temporal Validation AUC')
ax.set_title('Fig 4. Best Validation AUC by Model Family - diff view')
ax.set_ylim(ymin, ymax)
ax.tick_params(axis='x', rotation=20)

for bar, val in zip(bars, fig4_alt_df['Temporal Val AUC']):
    ax.text(bar.get_x() + bar.get_width() / 2, val + 0.001, f'{val:.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Figure 6: Fairness by income group at threshold 0.5
FAIR_MODELS_PLOT = REPRESENTATIVE_MODELS.copy()
family_map = dict(zip(representative_lookup['Model'], representative_lookup['Family']))
FAIR_LABELS_PLOT = [family_display.get(family_map.get(m, ''), m) for m in FAIR_MODELS_PLOT]
colors_fair = [family_colors.get(family_map.get(m, ''), '#9467bd') for m in FAIR_MODELS_PLOT]

income_groups = ['low', 'mid', 'high']
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for ax_i, metric in enumerate(metrics):
    x = np.arange(len(income_groups))
    width = 0.14
    for j, (mname, family_label, col) in enumerate(zip(FAIR_MODELS_PLOT, FAIR_LABELS_PLOT, colors_fair)):
        df_f = fairness_results.get(mname, {}).get('income', pd.DataFrame(columns=['group'] + metrics))
        vals = df_f.set_index('group').reindex(income_groups)[metric].fillna(0).tolist()
        offset = (j - len(FAIR_MODELS_PLOT) / 2) * width
        bars = axes[ax_i].bar(x + offset, vals, width=width, label=family_label, color=col)
        for bar, val in zip(bars, vals):
            axes[ax_i].text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.002,
                f'{val:.3f}',
                ha='center',
                va='bottom',
                fontsize=6,
                rotation=90
            )
    axes[ax_i].set_xticks(x)
    axes[ax_i].set_xticklabels(income_groups)
    axes[ax_i].set_title(f'Fig 6{chr(97+ax_i)}. {metric} by Income Group')
    axes[ax_i].set_ylabel(metric)
    if ax_i == 0:
        axes[ax_i].legend(fontsize=7)
plt.tight_layout()
plt.savefig('/content/fig6_fairness_income.png', dpi=150)
plt.show()

# %%
# Figure 7: Robustness vs worst-case fairness disparity
FAIR_MODELS_PLOT = REPRESENTATIVE_MODELS.copy()
family_map = dict(zip(representative_lookup['Model'], representative_lookup['Family']))
FAIR_LABELS_PLOT = [family_display.get(family_map.get(m, ''), m) for m in FAIR_MODELS_PLOT]
colors_fair = [family_colors.get(family_map.get(m, ''), '#9467bd') for m in FAIR_MODELS_PLOT]

tradeoff_df = df_fairness_summary[df_fairness_summary['Model'].isin(FAIR_MODELS_PLOT)].copy()
tradeoff_df['Worst Credit Overall_disp'] = tradeoff_df[['Worst Credit FPR_disp', 'Worst Credit TPR_disp', 'Worst Credit PPR_disp']].max(axis=1)
tradeoff_df['Worst Income Overall_disp'] = tradeoff_df[['Worst Income FPR_disp', 'Worst Income TPR_disp', 'Worst Income PPR_disp']].max(axis=1)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax_i, (y_col, title_suffix) in enumerate([
    ('Worst Credit Overall_disp', 'credit group'),
    ('Worst Income Overall_disp', 'income group'),
]):
    for mname, family_label, col in zip(FAIR_MODELS_PLOT, FAIR_LABELS_PLOT, colors_fair):
        row = tradeoff_df[tradeoff_df['Model'] == mname].iloc[0]
        x_val = row['AUC Drop']
        y_val = row[y_col]
        axes[ax_i].scatter(x_val, y_val, color=col, s=100, label=family_label, zorder=3)
        axes[ax_i].annotate(family_label, (x_val, y_val), textcoords='offset points', xytext=(5, 3), fontsize=8)
    axes[ax_i].set_xlabel('AUC Drop (Random - Temporal)')
    axes[ax_i].set_ylabel('Worst-case disparity across thresholds\n(max of FPR, TPR, PPR)')
    axes[ax_i].set_title(f'Fig 7{chr(97+ax_i)}. Robustness vs Worst-case Fairness\n({title_suffix})')
    axes[ax_i].axhline(0, color='gray', linestyle='--', linewidth=0.7)
    axes[ax_i].axvline(0, color='gray', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('/content/fig7_tradeoff.png', dpi=150)
plt.show()

# %%
# ════════════════════════════════════════════════════════════════════════════════
# SLIDE PLOT ① : Best Model per Family — Final Comparison
# 필요한 변수: df_representatives, df_ranked, REPRESENTATIVE_MODELS, representative_lookup
# ════════════════════════════════════════════════════════════════════════════════
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

family_colors_bar = {
    'Logistic Regression': '#1f77b4',
    'Decision Tree':       '#ff7f0e',
    'Random Forest':       '#2ca02c',
    'XGBoost':             '#d62728',
}

# representative 모델들의 composite score, fairness norm 포함한 df 만들기
plot_df = df_ranked[df_ranked['Model'].isin(REPRESENTATIVE_MODELS)].copy()
plot_df['Family'] = plot_df['Model'].apply(infer_family)
plot_df['Model']  = pd.Categorical(plot_df['Model'], categories=REPRESENTATIVE_MODELS, ordered=True)
plot_df = plot_df.sort_values('Model')

bar_colors = [family_colors_bar.get(f, '#9467bd') for f in plot_df['Family']]
x_labels   = plot_df['Model'].astype(str).tolist()

fig, axes = plt.subplots(1, 4, figsize=(18, 4.5))
fig.suptitle('Best Model per Family — Final Comparison', fontsize=13, fontweight='bold')

metrics = [
    ('Temporal Val AUC', 'Val AUC ↑',       True,  '%.4f'),
    ('AUC Drop',         'AUC Drop ↓',       False, '%.4f'),
    ('_fair_norm',       'Fairness Norm ↓',  False, '%.4f'),
    ('composite_score',  'Composite Score ↓',False, '%.4f'),
]

for ax, (col, title, higher_better, fmt) in zip(axes, metrics):
    vals = plot_df[col].tolist()
    bars = ax.bar(x_labels, vals, color=bar_colors, edgecolor='white', linewidth=0.5)
    for bar, v in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width()/2,
                bar.get_height() + max(vals)*0.01,
                f'{v:.4f}', ha='center', va='bottom', fontsize=7.5)
    ax.set_title(title, fontsize=10, fontweight='bold')
    ax.set_xticks(range(len(x_labels)))
    ax.set_xticklabels(x_labels, rotation=20, ha='right', fontsize=8)
    ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.3f'))
    ax.set_ylim(0, max(vals) * 1.18)

plt.tight_layout()
plt.savefig('/content/slide_fig1_best_model_per_family.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: slide_fig1_best_model_per_family.png')
# Out:
# Saved: slide_fig1_best_model_per_family.png

# %%
import matplotlib.pyplot as plt

family_colors_scatter = {
    'Random Forest': '#2ca02c',
    'Logistic Regression': '#1f77b4',
    'Decision Tree': '#ff7f0e',
    'XGBoost': '#d62728',
}

df_all = df_ranked.copy()
df_all['Family'] = df_all['Model'].apply(infer_family)

fig, ax = plt.subplots(figsize=(8, 6))

for family, grp in df_all.groupby('Family'):
    color = family_colors_scatter.get(family, '#9467bd')
    ax.scatter(grp['AUC Drop'], grp['_fair_norm'],
               color=color, s=80, alpha=0.85, label=family, zorder=3)

# ── Best Model 강조 (composite_score 기준 1등)
best_row = df_ranked.iloc[0]
ax.scatter(best_row['AUC Drop'], best_row['_fair_norm'],
           s=220, facecolors='none', edgecolors='black', linewidths=2, zorder=5)
ax.annotate(f'★ {best_row["Model"]}',
            xy=(best_row['AUC Drop'], best_row['_fair_norm']),
            xytext=(best_row['AUC Drop'] + 0.002, best_row['_fair_norm'] + 0.03),
            fontsize=8, color='black',
            arrowprops=dict(arrowstyle='->', color='black', lw=1))

ax.set_xlabel('AUC Drop  (lower = more robust →)', fontsize=10)
ax.set_ylabel('Fairness Norm  (lower = more fair →)', fontsize=10)
ax.set_title('Robustness vs Fairness Trade-off', fontsize=12, fontweight='bold')
ax.legend(title='Model Family', fontsize=8, title_fontsize=9)
ax.grid(True, linestyle='--', alpha=0.4)

plt.tight_layout()
plt.savefig('/content/slide_fig2_tradeoff_scatter_v2.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: slide_fig2_tradeoff_scatter_v2.png')
# Out:
# Saved: slide_fig2_tradeoff_scatter_v2.png

# %%
import matplotlib.pyplot as plt
import numpy as np

family_colors_radar = {
    'Logistic Regression': '#1f77b4',
    'Decision Tree': '#ff7f0e',
    'Random Forest': '#2ca02c',
    'XGBoost': '#d62728',
}

labels = ['Credit\nFPR', 'Income\nFPR', 'Credit\nTPR',
          'Income\nTPR', 'Credit\nPPR', 'Income\nPPR']
N = len(labels)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]

disp_cols = [
    'Worst Credit FPR_disp', 'Worst Income FPR_disp',
    'Worst Credit TPR_disp', 'Worst Income TPR_disp',
    'Worst Credit PPR_disp', 'Worst Income PPR_disp',
]

ZERO_THRESHOLD = 1e-4

# 하드코딩 제거 → REPRESENTATIVE_MODELS 그대로 사용
PLOT_MODELS = REPRESENTATIVE_MODELS.copy()
print("Plot models:", PLOT_MODELS)

# 값 수집
model_vals = {}
for m in PLOT_MODELS:
    rows = df_ranked[df_ranked['Model'] == m]
    if rows.empty:
        continue
    row = rows.iloc[0]
    model_vals[m] = [row[col] for col in disp_cols]

PLOT_MODELS = [m for m in PLOT_MODELS if m in model_vals]

global_max = max([max(v) for v in model_vals.values()])
y_max_global = global_max * 1.4
yticks = np.linspace(0, y_max_global, 4)[1:]

def radar_area(values):
    r = np.array(values)
    return 0.5 * abs(sum(
        r[i] * r[(i+1) % N] * np.sin(angles[(i+1) % N] - angles[i])
        for i in range(N)
    ))

fig, axes = plt.subplots(1, len(PLOT_MODELS),
                         figsize=(4.5 * len(PLOT_MODELS), 5.0),
                         subplot_kw=dict(polar=True))
fig.suptitle('Fairness Profile — Representative Models\n(smaller area = more fair  |  worst-case across threshold 0.3–0.7)',
             fontsize=12, fontweight='bold', y=1.02)

for ax, model_name in zip(axes, PLOT_MODELS):
    family = infer_family(model_name)
    color = family_colors_radar.get(family, '#9467bd')
    values = model_vals[model_name]
    is_zero = max(values) < ZERO_THRESHOLD
    area = radar_area(values)
    closed = values + [values[0]]

    if is_zero:
        ax.scatter([0], [0], s=120, color=color, zorder=5)
        ax.text(0, y_max_global * 0.1, '≈ 0',
                ha='center', va='bottom', fontsize=11,
                color=color, fontweight='bold')
    else:
        ax.plot(angles, closed, color=color, linewidth=2.2, zorder=3)
        ax.fill(angles, closed, color=color, alpha=0.30, zorder=2)
        for ang, val in zip(angles[:-1], values):
            ax.text(ang, val + y_max_global * 0.06, f'{val:.3f}',
                    ha='center', va='center', fontsize=7,
                    color=color, fontweight='bold')

    ax.set_ylim(0, y_max_global)
    ax.set_yticks(yticks)
    ax.set_yticklabels([f'{v:.3f}' for v in yticks], fontsize=6, color='gray')
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels, fontsize=9)
    ax.grid(True, linestyle='--', alpha=0.45)

    title_suffix = '(≈ perfectly fair)' if is_zero else f'(area={area:.5f})'
    ax.set_title(f'{model_name}\n{title_suffix}',
                 fontsize=9.5, fontweight='bold', color=color, pad=16)

plt.tight_layout()
plt.savefig('/content/slide_fig3_fairness_radar_v8.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved: slide_fig3_fairness_radar_v8.png')
# Out:
# Plot models: ['LR_optuna_5', 'DTree_optuna_2', 'RF_optuna_1', 'XGB_optuna_1']
# Saved: slide_fig3_fairness_radar_v8.png

# %% [markdown]
# ## 8. Output Final Summary Table (For Presentation)

# %%
# Representative summary table aligned with the current pipeline
df_summary = df_ranked[df_ranked['Model'].isin(REPRESENTATIVE_MODELS)].copy()
df_summary['Model'] = pd.Categorical(df_summary['Model'], categories=REPRESENTATIVE_MODELS, ordered=True)
df_summary = df_summary.sort_values('Model')
print('=== Summary Table (Representative Models) ===')
print(df_summary.to_string(index=False))

df_summary.to_csv('/content/prefinal_summary.csv', index=False)
df_results.to_csv('/content/prefinal_full_results.csv', index=False)
print('\nCSV saved: prefinal_summary.csv, prefinal_full_results.csv')
# Out:
# === Summary Table (Representative Models) ===
#          Model  Temporal Val AUC  Val AUC Drop  Val F1  Temporal AUC  Accuracy  AUC Drop     F1  Worst Credit FPR_disp  Worst Income FPR_disp  Worst Credit TPR_disp  Worst Income TPR_disp  Worst Credit PPR_disp  Worst Income PPR_disp  _fair_norm  composite_score
#    LR_optuna_5            0.6858        0.0021  0.3841        0.6834    0.6705    0.0057 0.2261                 0.0601                 0.0919                 0.0790                 0.1175                 0.0719                 0.1069    0.322192         0.067738
# DTree_optuna_2            0.6702        0.0094  0.3748        0.6675    0.6591    0.0153 0.2210                 0.1869                 0.4407                 0.1577                 0.3884                 0.1923                 0.4442    1.000000         0.902778
#    RF_optuna_1            0.6785        0.0032  0.3808        0.6799    0.6503    0.0079 0.2254                 0.1221                 0.2181                 0.1194                 0.1604                 0.1328                 0.2219    0.583066         0.381133
#   XGB_optuna_1            0.6824        0.0153  0.3817        0.6810    0.6424    0.0207 0.2230                 0.0051                 0.0161                 0.0151                 0.0513                 0.0079                 0.0234    0.060699         0.341160
#
# CSV saved: prefinal_summary.csv, prefinal_full_results.csv

# %% [markdown]
# ## 9. Save Files (Google Drive)
# Save Resulting PNG + CSV to Drive

# %%
# import shutil, os

# SAVE_DIR = '/content/drive/MyDrive/Colab Notebooks/CSCI567'
# os.makedirs(SAVE_DIR, exist_ok=True)

# files_to_save = [
#     '/content/fig1_auc_comparison.png',
#     '/content/fig2_auc_drop.png',
#     '/content/fig3_auc_over_time.png',
#     '/content/fig4_validation_auc.png',
#     '/content/fig5_fairness_credit.png',
#     '/content/fig6_fairness_income.png',
#     '/content/fig7_tradeoff.png',
#     '/content/prefinal_summary.csv',
#     '/content/prefinal_full_results.csv',
# ]

# for f in files_to_save:
#     if os.path.exists(f):
#         shutil.copy(f, SAVE_DIR)
#         print(f'Saved: {os.path.basename(f)}')
#     else:
#         print(f'NOT FOUND: {f}')
# Out:
# Saved: fig1_auc_comparison.png
# Saved: fig2_auc_drop.png
# Saved: fig3_auc_over_time.png
# Saved: fig4_validation_auc.png
# Saved: fig5_fairness_credit.png
# Saved: fig6_fairness_income.png
# Saved: fig7_tradeoff.png
# Saved: prefinal_summary.csv
# Saved: prefinal_full_results.csv
